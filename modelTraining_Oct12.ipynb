# %%
# Import Libraries
import pandas as pd
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import seaborn as sns
import gzip
import pickle

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)

# Sklearn and Imbalanced-learn Libraries
from sklearn.model_selection import StratifiedKFold, train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import RFECV, VarianceThreshold, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, balanced_accuracy_score,
    classification_report
)
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.utils import resample
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE




from sklearn.base import BaseEstimator, TransformerMixin

# Additional Libraries
from sklearn.base import clone
from sklearn.exceptions import NotFittedError
import warnings
warnings.filterwarnings('ignore')

# Machine Learning Libraries with GPU Support
import xgboost as xgb
import lightgbm as lgb

# For SHAP values
import shap

# Statistical Tests
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp

# For progress monitoring
from tqdm import tqdm
from kneed import KneeLocator


import warnings

# Suppress warnings to reduce clutter
warnings.filterwarnings('ignore')

from sklearn.exceptions import ConvergenceWarning

# Suppress ConvergenceWarning
warnings.filterwarnings('ignore', category=ConvergenceWarning)

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

from joblib import Parallel, delayed
from sklearn.base import BaseEstimator, TransformerMixin
from scipy.stats import mannwhitneyu
import numpy as np
import pandas as pd

# Necessary imports
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import cross_val_score
from sklearn.utils.validation import check_X_y, check_array
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

# %%
# File paths for clinical, extracted features and radiomics features
clinical_data_path = '/Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/Clinical_and_Other_Features_final_comb.xlsx'
features_path = '/Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/features_extracted_VGG16_tumor_mid10_5_augmented_bal_1.pkl.gz'
imaging_features_path = '/Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/Imaging_Features.xlsx'

# %%
#Function: Load and Process Clinical and Extracted Features Data
def load_clinical_data(clinical_data_path):
    """
    Loads and preprocesses clinical data from an Excel file.

    Parameters:
    - clinical_data_path (str): Path to the clinical data Excel file.

    Returns:
    - pd.DataFrame: Preprocessed clinical data.
    """
    print("Loading clinical data...")
    clinical_data = pd.read_excel(clinical_data_path)

    # Rename columns for consistency
    clinical_data.columns = [col.replace(' ', '_') for col in clinical_data.columns]
    clinical_data = clinical_data.rename(
        columns={
            'Patient_ID': 'patient_id',
            'Pathologic_Response_to_Neoadjuvant_Therapy': 'response'
        }
    )

    # Convert 'Breast_MRI_001' to '001' in the patient_id column
    clinical_data['patient_id'] = clinical_data['patient_id'].apply(
        lambda x: x.split('_')[-1] if isinstance(x, str) else x
    )

    # Convert response to binary: 1 means pCR, else non-pCR
    clinical_data['response'] = clinical_data['response'].apply(
        lambda x: 1 if x == 1 else 0
    )

    # Preprocess clinical data
    clinical_data['patient_id'] = clinical_data['patient_id'].astype(str)

    # Separate numerical and categorical columns
    patient_id_cols = ["patient_id"]
    response_cols = ["response"]
    numerical_cols = ["Date_of_Birth"]  # Consider converting to 'Age at Diagnosis'
    categorical_cols = clinical_data.columns[
        (clinical_data.columns != "Date_of_Birth") &
        (clinical_data.columns != "patient_id") &
        (clinical_data.columns != "response")
    ]

    numerical_df = clinical_data[numerical_cols]
    patient_id_df = clinical_data[patient_id_cols]
    response_df = clinical_data[response_cols]

    # One-hot encode categorical columns
    clinical_data[categorical_cols] = clinical_data[categorical_cols].astype('category')
    categorical_df = pd.get_dummies(clinical_data[categorical_cols], drop_first=True)
    categorical_df = categorical_df.astype(int)

    # Concatenate all dataframes
    encoded_df = pd.concat(
        [patient_id_df, numerical_df, categorical_df, response_df],
        axis=1
    )

    print("Clinical data loaded and processed.")
    return encoded_df

def load_image_features(features_path):
    """
    Loads and processes image features from a compressed pickle file.

    Parameters:
    - features_path (str): Path to the compressed pickle file containing image features.

    Returns:
    - pd.DataFrame: Processed image features.
    """
    print("Loading image features...")
    with gzip.open(features_path, 'rb') as f:
        features_dict = pickle.load(f)

    # Extract patient IDs and features
    features_data = {
        'patient_id': [key.split('-')[0] for key in features_dict.keys()],
        **{
            f'feature_{i}': [features_dict[key][i] for key in features_dict.keys()]
            for i in range(len(next(iter(features_dict.values()))))
        }
    }

    # Create a DataFrame
    features_df = pd.DataFrame(features_data)
    features_df['patient_id'] = features_df['patient_id'].astype(str)
    print("Image features loaded.")
    return features_df



def load_and_preprocess_data(clinical_data_path, features_path):
    clinical_data_processed = load_clinical_data(clinical_data_path)
    features_df = load_image_features(features_path)
    clinical_data_processed['patient_id'] = clinical_data_processed['patient_id'].astype(str)
    features_df['patient_id'] = features_df['patient_id'].astype(str)

    # Prepare three variations of the dataset
    print("Preparing dataset variations...")

    datasets = {}

    # Handle missing data in image features
    print("Imputing missing values in image features...")
    imputer = SimpleImputer(strategy='mean')
    features_df_imputed = imputer.fit_transform(features_df.drop(columns=['patient_id']))

    # Feature scaling
    print("Scaling image features...")
    scaler = MinMaxScaler()
    features_df_scaled = scaler.fit_transform(features_df_imputed)

    # Create a DataFrame for scaled features
    features_scaled_df = pd.DataFrame(features_df_scaled, columns=[f'feature_{i}' for i in range(features_df_scaled.shape[1])])
    features_scaled_df['patient_id'] = features_df['patient_id'].values

    # Now, merge scaled image features with clinical data
    data_scaled = features_scaled_df.merge(
        clinical_data_processed,
        on='patient_id',
        how='inner'
    ).reset_index(drop=True)

    # 1. Image Features (Scaled)
    image_feature_columns = [col for col in data_scaled.columns if 'feature_' in col]

    X_image = data_scaled[image_feature_columns]
    y_image = data_scaled['response'].astype(int)
    groups_image = data_scaled['patient_id']

    # 2. Clinical Features
    # Subset clinical data to include only patients present in data_scaled
    patient_ids_in_data_scaled = clinical_data_processed['patient_id'].isin(data_scaled['patient_id'])
    clinical_data_in_data_scaled = clinical_data_processed[patient_ids_in_data_scaled].reset_index(drop=True)

    X_clinical = clinical_data_in_data_scaled.drop(columns=['patient_id', 'response'])
    y_clinical = clinical_data_in_data_scaled['response'].astype(int)
    groups_clinical = clinical_data_in_data_scaled['patient_id']

    # 3. Combined Features (Scaled image features + clinical data)
    # Exclude 'patient_id' and 'response' from features
    exclude_columns = ['patient_id', 'response']
    X_combined = data_scaled.drop(columns=exclude_columns)
    y_combined = data_scaled['response'].astype(int)
    groups_combined = data_scaled['patient_id']

    # Preprocess each dataset variation
    def preprocess_data(X):
        # Remove features with zero variance
        variance_threshold = VarianceThreshold(threshold=0)
        X_var = variance_threshold.fit_transform(X)
        feature_names = X.columns[variance_threshold.get_support(indices=True)]
        X = pd.DataFrame(X_var, columns=feature_names)
        return X

    X_combined = preprocess_data(X_combined)
    X_clinical = preprocess_data(X_clinical)
    X_image = preprocess_data(X_image)

    datasets['Combined'] = (X_combined, y_combined, groups_combined)
    datasets['Clinical'] = (X_clinical, y_clinical, groups_clinical)
    datasets['Image'] = (X_image, y_image, groups_image)

    return datasets

# %%
# Make Clinical, Image and Combined Data in data variations
data_variations = load_and_preprocess_data(clinical_data_path, features_path)
# Out:
# Loading clinical data...
# Clinical data loaded and processed.
# Loading image features...
# Image features loaded.
# Preparing dataset variations...
# Imputing missing values in image features...
# Scaling image features...

# %%
#Function: Load additional imaging features from radiomics Imaging_Features.xlsx

def load_additional_imaging_features(imaging_features_path):
    print("Loading additional imaging features...")
    imaging_features_df = pd.read_excel(imaging_features_path)
    
    # Rename the 'Patient ID' column to 'patient_id'
    imaging_features_df = imaging_features_df.rename(columns={'Patient ID': 'patient_id'})
    
    # Convert 'Breast_MRI_001' to '001' in the patient_id column
    imaging_features_df['patient_id'] = imaging_features_df['patient_id'].apply(
        lambda x: x.split('_')[-1] if isinstance(x, str) else x
    )
    
    # Ensure patient_id is string type
    imaging_features_df['patient_id'] = imaging_features_df['patient_id'].astype(str)
    
    # Clean up feature names by replacing spaces and special characters
    imaging_features_df.columns = [col.replace(' ', '_')
                                     .replace('(', '')
                                     .replace(')', '')
                                     .replace(',', '_')
                                     .replace('.', '_') for col in imaging_features_df.columns]
    
    print("Additional imaging features loaded.")
    return imaging_features_df

# Load the additional imaging features
additional_imaging_features_df = load_additional_imaging_features(imaging_features_path)
# Out:
# Loading additional imaging features...
# Additional imaging features loaded.

# %%
# Prepare new datasets with the radiomics imaging features

print("Preparing new datasets with additional imaging features...")

clinical_data_processed = load_clinical_data(clinical_data_path)
# Ensure patient IDs are strings
additional_imaging_features_df['patient_id'] = additional_imaging_features_df['patient_id'].astype(str)
clinical_data_processed['patient_id'] = clinical_data_processed['patient_id'].astype(str)

# Imaging Only Dataset (from Imaging_Features.xlsx)
# Merge the imaging features with the response variable from clinical data
imaging_only_df = additional_imaging_features_df.merge(
    clinical_data_processed[['patient_id', 'response']],
    on='patient_id',
    how='inner'
)

# Create X and y for Imaging Only dataset
X_imaging_only = imaging_only_df.drop(columns=['patient_id', 'response'])
y_imaging_only = imaging_only_df['response'].astype(int)
groups_imaging_only = imaging_only_df['patient_id']

# Clinical + Imaging Dataset
# Merge imaging features with clinical data
clinical_imaging_df = additional_imaging_features_df.merge(
    clinical_data_processed,
    on='patient_id',
    how='inner'
)

# Create X and y for Clinical + Imaging dataset
X_clinical_imaging = clinical_imaging_df.drop(columns=['patient_id', 'response'])
y_clinical_imaging = clinical_imaging_df['response'].astype(int)
groups_clinical_imaging = clinical_imaging_df['patient_id']

# Combined Existing Dataset + Imaging Features (Extracted Features + Clinical + Imaging)
# Get existing combined dataset
X_combined_existing, y_combined_existing, groups_combined_existing = data_variations['Combined']

# Ensure patient IDs are strings
X_combined_existing = X_combined_existing.copy()
X_combined_existing['patient_id'] = groups_combined_existing.astype(str)

# Merge with additional imaging features
combined_with_imaging_df = X_combined_existing.merge(
    additional_imaging_features_df,
    on='patient_id',
    how='inner'
)

# Ensure response variable is included
combined_with_imaging_df = combined_with_imaging_df.merge(
    clinical_data_processed[['patient_id', 'response']],
    on='patient_id',
    how='left'
)

# Create X and y for Combined with Imaging dataset
X_combined_with_imaging = combined_with_imaging_df.drop(columns=['patient_id', 'response'])
y_combined_with_imaging = combined_with_imaging_df['response'].astype(int)
groups_combined_with_imaging = combined_with_imaging_df['patient_id']

# Add new datasets to data_variations
data_variations['RadiomicsOnly'] = (X_imaging_only, y_imaging_only, groups_imaging_only)
data_variations['ClinicalRadiomics'] = (X_clinical_imaging, y_clinical_imaging, groups_clinical_imaging)
data_variations['CombinedRadiomics'] = (X_combined_with_imaging, y_combined_with_imaging, groups_combined_with_imaging)

print("New datasets added to data_variations.")
# Out:
# Preparing new datasets with additional imaging features...
# Loading clinical data...
# Clinical data loaded and processed.
# New datasets added to data_variations.

# %%
#Data Train Test Split
def stratified_group_split(X, y, groups, test_size=0.2, random_state=None):
    # Create a DataFrame with groups and their corresponding class labels
    group_df = pd.DataFrame({'group': groups, 'label': y})
    group_df = group_df.drop_duplicates()

    # Perform stratified split on groups
    stratify = group_df['label']
    group_train, group_test = train_test_split(
        group_df['group'], test_size=test_size, random_state=random_state, stratify=stratify
    )

    # Select samples based on group splits
    train_idx = X[groups.isin(group_train)].index
    test_idx = X[groups.isin(group_test)].index

    return train_idx, test_idx

# Usage
data_splits = {}

for dataset_name, (X_full, y_full, groups) in data_variations.items():
    print(f"\nProcessing {dataset_name} Dataset")

    # Ensure groups is a pandas Series with reset index
    groups = pd.Series(groups).reset_index(drop=True)
    y_full_series = pd.Series(y_full).reset_index(drop=True)
    X_full = X_full.reset_index(drop=True)

    train_idx, test_idx = stratified_group_split(X_full, y_full_series, groups, test_size=0.2, random_state=42)

    X_train_full = X_full.loc[train_idx].reset_index(drop=True)
    y_train_full = y_full_series.loc[train_idx].reset_index(drop=True)
    X_test_full = X_full.loc[test_idx].reset_index(drop=True)
    y_test = y_full_series.loc[test_idx].reset_index(drop=True)

    # Retrieve patient IDs for train and test sets
    patient_ids_train = groups.loc[train_idx].reset_index(drop=True)
    patient_ids_test = groups.loc[test_idx].reset_index(drop=True)

    data_splits[dataset_name] = {
        'X_train_full': X_train_full,
        'X_test_full': X_test_full,
        'y_train_full': y_train_full,
        'y_test': y_test,
        'patient_ids_train': patient_ids_train,
        'patient_ids_test': patient_ids_test
    }

    # Verify class distribution
    print("Training set class distribution:")
    print(y_train_full.value_counts(normalize=True))
    print("Test set class distribution:")
    print(y_test.value_counts(normalize=True))
# Out:
# Processing Combined Dataset
# Training set class distribution:
# response
# 1    0.543028
# 0    0.456972
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 1    0.538976
# 0    0.461024
# Name: proportion, dtype: float64
#
# Processing Clinical Dataset
# Training set class distribution:
# response
# 0    0.770335
# 1    0.229665
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773585
# 1    0.226415
# Name: proportion, dtype: float64
#
# Processing Image Dataset
# Training set class distribution:
# response
# 1    0.543028
# 0    0.456972
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 1    0.538976
# 0    0.461024
# Name: proportion, dtype: float64
#
# Processing RadiomicsOnly Dataset
# Training set class distribution:
# response
# 0    0.766667
# 1    0.233333
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773585
# 1    0.226415
# Name: proportion, dtype: float64
#
# Processing ClinicalRadiomics Dataset
# Training set class distribution:
# response
# 0    0.766667
# 1    0.233333
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773585
# 1    0.226415
# Name: proportion, dtype: float64
#
# Processing CombinedRadiomics Dataset
# Training set class distribution:
# response
# 1    0.543028
# 0    0.456972
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 1    0.538976
# 0    0.461024
# Name: proportion, dtype: float64

# %%
#Function: MannWhitney & RFECV Feature Selection
class MannWhitneyUTestFeatureSelector(BaseEstimator, TransformerMixin):
    """
    Custom transformer for feature selection using the Mann-Whitney U test
    with Bonferroni correction and optional parallelization.
    """
    def __init__(self, alpha=0.05, bonferroni=True, n_jobs=-1):
        """
        Initialize the selector.

        Parameters:
        - alpha (float): The significance level for the Mann-Whitney U test.
        - bonferroni (bool): Whether to apply Bonferroni correction.
        - n_jobs (int): The number of jobs to run in parallel (default is -1, using all available cores).
        """
        self.alpha = alpha
        self.bonferroni = bonferroni
        self.n_jobs = n_jobs
        self.selected_features_ = None

    def _perform_test(self, col, X, y):
        """
        Helper function to perform Mann-Whitney U test on a single feature.
        """
        group0 = X.loc[y == 0, col]
        group1 = X.loc[y == 1, col]
        try:
            _, p = mannwhitneyu(group0, group1, alternative='two-sided')
        except ValueError:
            p = 1  # Assign high p-value if test fails
        return p

    def fit(self, X, y):
        """
        Fit the selector to the data by performing the Mann-Whitney U test for each feature.
        
        Parameters:
        - X (pd.DataFrame): The input feature matrix.
        - y (pd.Series): The target variable.
        
        Returns:
        - self: The fitted selector.
        """
        # Ensure X is a DataFrame and y is a Series with matching indices
        X = pd.DataFrame(X)
        y = pd.Series(y, index=X.index)
        
        # Parallelized Mann-Whitney U tests
        p_values = Parallel(n_jobs=self.n_jobs)(
            delayed(self._perform_test)(col, X, y) for col in X.columns
        )
        
        self.p_values_ = np.array(p_values)
        
        # Apply Bonferroni correction if needed
        if self.bonferroni:
            corrected_alpha = self.alpha / X.shape[1]  # Adjust alpha by number of tests
        else:
            corrected_alpha = self.alpha

        # Select features with p-values below the corrected alpha level
        self.selected_features_ = X.columns[self.p_values_ < corrected_alpha]
        
        return self

    def transform(self, X):
        """
        Transform the data by selecting the features that passed the Mann-Whitney U test.

        Parameters:
        - X (pd.DataFrame): The input feature matrix.

        Returns:
        - pd.DataFrame: The selected feature matrix.
        """
        # Ensure X is a DataFrame
        X = pd.DataFrame(X)
        return X.loc[:, self.selected_features_]
    
def manual_rfecv(X, y, groups, estimator, cv, scoring='f1', min_features_to_select=5, step=0.1, early_stopping_rounds=3):
    """
    Manually performs Recursive Feature Elimination with Cross-Validation (RFECV)
    using the specified estimator and cross-validation strategy.
    
    Parameters:
    - X (pd.DataFrame): Feature matrix.
    - y (pd.Series): Target vector.
    - groups (pd.Series or array-like): Group labels for the samples used while splitting the dataset.
    - estimator: The machine learning estimator to use for feature selection.
    - cv: Cross-validation strategy.
    - scoring (str): Scoring metric (default is 'f1').
    - min_features_to_select (int): Minimum number of features to select.
    - step (float): Proportion of features to remove at each iteration.
    - early_stopping_rounds (int): Number of rounds to wait for improvement before stopping.
    
    Returns:
    - best_features (list): The list of best selected features based on cross-validation score.
    - history (pd.DataFrame): History of number of features and corresponding CV scores.
    """
    
    n_features = X.shape[1]
    step_num = int(max(1, step * n_features))  # Convert the step percentage to an absolute number of features
    
    # History to keep track of scores, feature sets and feature counts
    history = []
    feature_sets = []
    
    # Copy X to avoid modifying the original dataframe
    X_remaining = X.copy()

    # Early stopping tracking
    no_improvement_rounds = 0
    best_score = -np.inf
    
    while X_remaining.shape[1] > min_features_to_select:
        print(f"Evaluating with {X_remaining.shape[1]} features...")
        n_features_remaining = X_remaining.shape[1]
        step_num = int(max(1, step * n_features_remaining)) 
        
        # Custom cross-validation loop
        scores = []
        for train_idx, test_idx in cv.split(X_remaining, y, groups):
            X_train_cv, X_valid_cv = X_remaining.iloc[train_idx], X_remaining.iloc[test_idx]
            y_train_cv, y_valid_cv = y.iloc[train_idx], y.iloc[test_idx]
            estimator.fit(X_train_cv, y_train_cv)
            y_pred_cv = estimator.predict(X_valid_cv)
            score = f1_score(y_valid_cv, y_pred_cv)
            scores.append(score)
        avg_score = np.mean(scores)
        
        # Append results to the history and store the current feature set
        history.append((X_remaining.shape[1], round(avg_score, 2)))  # Round CV score to 2 decimal places
        feature_sets.append(X_remaining.columns.tolist())
        
        # Early stopping check
        if avg_score > best_score:
            best_score = avg_score
            no_improvement_rounds = 0
        else:
            no_improvement_rounds += 1
        
        if no_improvement_rounds >= early_stopping_rounds:
            print("Early stopping, no significant improvement.")
            break
        
        # Train the model and get feature importances
        estimator.fit(X_remaining, y)
        importances = estimator.feature_importances_
        
        # Create a DataFrame of features and importances
        feature_importances = pd.DataFrame({
            'feature': X_remaining.columns,
            'importance': importances
        })
        
        # Sort features by importance (ascending)
        feature_importances.sort_values(by='importance', ascending=True, inplace=True)
        
        # Remove the least important features based on step size
        n_to_remove = min(step_num, X_remaining.shape[1] - min_features_to_select)
        features_to_remove = feature_importances.head(n_to_remove)['feature'].tolist()
        
        # Drop the least important features
        X_remaining.drop(columns=features_to_remove, inplace=True)
    
    # Convert history to a DataFrame for easy access
    history_df = pd.DataFrame(history, columns=['n_features', 'cv_score'])
    
    # Identify the best cross-validation score and the corresponding feature sets with the least number of features
    max_score = history_df['cv_score'].max()
    best_idx = history_df[history_df['cv_score'] == max_score]['n_features'].idxmin()  # Minimize the number of features
    
    # The best selected features correspond to the maximum cross-validation score with the least features
    best_features = feature_sets[best_idx]
    
    return best_features, history_df

# %%
# Feature Selection
selected_features_dict = {}

apply_smote = False  # Set to False if you want to skip SMOTE
apply_mannwhitney = True  # Set to False if you want to skip Mann-Whitney U Test

datasets_to_skip_mannwhitney = ['Clinical', 'RadiomicsOnly', 'ClinicalRadiomics']
#datasets_to_skip_mannwhitney = ['Clinical']
datasets_to_skip_L1 = ['Clinical', 'RadiomicsOnly', 'ClinicalRadiomics']
datasets_for_standard = ['RadiomicsOnly', 'ClinicalRadiomics']

for dataset_name in data_variations.keys():
    
    print(f"\nStarting feature selection for '{dataset_name}' Dataset")
    
    # Retrieve data
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test = data['y_test']
    patient_ids_train = data['patient_ids_train']  # Preserving patient IDs
    patient_ids_test = data['patient_ids_test']
    # Handle Missing Data - Imputation
    print("\nHandling missing data with SimpleImputer...")
    imputer = SimpleImputer(strategy='mean')
    X_train_imputed = imputer.fit_transform(X_train_full)
    X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train_full.columns, index=X_train_full.index)
    # Feature Scaling using MinMaxScaler
    print("\nScaling features with MinMaxScaler...")
    if dataset_name in datasets_for_standard:
        scaler = StandardScaler()
    else:
        scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train_imputed)
    X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_full.columns, index=X_train_full.index)
    # L1-based Feature Selection
    print("\nPerforming L1-based feature selection...")
    if dataset_name in datasets_to_skip_L1:
        l1_selector = SelectFromModel(
            LogisticRegression(penalty='l1', solver='liblinear', random_state=42, max_iter=1000)
        )
    else:
        l1_selector = SelectFromModel(
            LogisticRegression(penalty='l1', solver='liblinear', random_state=42, max_iter=1000),
            max_features=100  # Adjust as needed
        )
    l1_selector.fit(X_train_scaled, y_train_full)
    X_train_l1 = l1_selector.transform(X_train_scaled)
    X_train_l1 = pd.DataFrame(X_train_l1, columns=X_train_scaled.columns[l1_selector.get_support()])
    print(f"Number of features after L1-based selection: {X_train_l1.shape[1]}")
    # Mann-Whitney U Test Feature Selection
    # Replace the Mann-Whitney U Test conditional block with the following
    if apply_mannwhitney and dataset_name not in datasets_to_skip_mannwhitney:
        print("\nPerforming Mann-Whitney U Test feature selection with Bonferroni correction and parallelization...")
        mannwhitney_selector = MannWhitneyUTestFeatureSelector(alpha=0.05, bonferroni=True, n_jobs=-1)
        mannwhitney_selector.fit(X_train_l1, y_train_full)
        X_train_mwu = mannwhitney_selector.transform(X_train_l1)
        print(f"Number of features after Mann-Whitney U Test: {X_train_mwu.shape[1]}")
    else:
        print(f"\nSkipping Mann-Whitney U Test for '{dataset_name}' dataset. Using L1-selected features.")
        X_train_mwu = X_train_l1
    # Manually perform RFECV using a Random Forest Classifier
    print("\nPerforming Recursive Feature Elimination with Cross-Validation (RFECV)...")
    rf_estimator = RandomForestClassifier(random_state=42, n_jobs=-1, n_estimators=50, max_depth=7)
    
    cv_strategy = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
    # Perform manual RFECV, passing groups_train
    best_features, rfecv_history = manual_rfecv(
        X_train_mwu, y_train_full, patient_ids_train, rf_estimator, cv_strategy,
        scoring='f1', min_features_to_select=5, step=0.1, early_stopping_rounds=10
    )
    print(f"\nBest Features Selected: {best_features}")
    print("\nRFECV History:")
    print(rfecv_history)
    # Plot the number of features vs. cross-validation score
    plt.figure(figsize=(10, 6))
    plt.plot(rfecv_history['n_features'], rfecv_history['cv_score'], marker='o')
    plt.xlabel("Number of Features Selected")
    plt.ylabel("Cross-validation F1 Score")
    plt.title(f"Manual RFECV - {dataset_name}")
    plt.gca().invert_xaxis()  # Optional: Invert x-axis to show decreasing number of features
    plt.grid(True)
    plt.show()
    
    # Apply SMOTE **after** feature selection
    if apply_smote:
        print("\nApplying SMOTE to balance the classes after feature selection...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_mwu[best_features], y_train_full)
        X_train_resampled = pd.DataFrame(X_train_resampled, columns=best_features).reset_index(drop=True)
        y_train_resampled = pd.Series(y_train_resampled).reset_index(drop=True)
        print(f"Number of samples after SMOTE: {X_train_resampled.shape[0]}")
        print(f"Class distribution after SMOTE:\n{y_train_resampled.value_counts()}")
    else:
        print("\nSkipping SMOTE. Using original training data.")
        X_train_resampled = X_train_mwu[best_features].reset_index(drop=True)
        y_train_resampled = y_train_full.reset_index(drop=True)
    

    # Ensure that all selected features exist in the test dataset
    missing_in_train = set(best_features) - set(X_train_full.columns)
    missing_in_test = set(best_features) - set(X_test_full.columns)
    if missing_in_train:
        raise ValueError(f"The following selected features are missing in X_train_full: {missing_in_train}")
    if missing_in_test:
        raise ValueError(f"The following selected features are missing in X_test_full: {missing_in_test}")
    # Subset the original X_train_full and X_test_full to include only the selected features
    X_test_final = X_test_full[best_features].copy().reset_index(drop=True)
    y_test_final = y_test.reset_index(drop=True)
    # Store the final datasets with selected features in data_splits
    data_splits[dataset_name] = {
        'X_train_full': X_train_resampled,
        'X_test_full': X_test_final,
        'y_train_full': y_train_resampled,
        'y_test': y_test_final,
        'patient_ids_train': patient_ids_train.reset_index(drop=True),
        'patient_ids_test': patient_ids_test.reset_index(drop=True)
    }

    selected_features_dict[dataset_name] = best_features
    print(f"\nFinal datasets for '{dataset_name}' stored with selected features.")
# Out:
# Starting feature selection for 'Combined' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 100
#
# Performing Mann-Whitney U Test feature selection with Bonferroni correction and parallelization...
# Number of features after Mann-Whitney U Test: 79
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 79 features...
# Evaluating with 72 features...
# Evaluating with 65 features...
# Evaluating with 59 features...
# Evaluating with 54 features...
# Evaluating with 49 features...
# Evaluating with 45 features...
# Evaluating with 41 features...
# Evaluating with 37 features...
# Evaluating with 34 features...
# Evaluating with 31 features...
# Evaluating with 28 features...
# Evaluating with 26 features...
# Evaluating with 24 features...
# Evaluating with 22 features...
# Evaluating with 20 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['feature_276', 'feature_382', 'feature_480', 'feature_3348', 'feature_3552', 'feature_10951', 'feature_11752', 'feature_21846', 'feature_22006', 'feature_23057', 'feature_24852', 'feature_25069', 'PR_"{0_=_neg,\n1_=_pos}"_1']
#
# RFECV History:
#     n_features  cv_score
# 0           79      0.85
# 1           72      0.85
# 2           65      0.85
# 3           59      0.85
# 4           54      0.86
# 5           49      0.85
# 6           45      0.85
# 7           41      0.85
# 8           37      0.85
# 9           34      0.86
# 10          31      0.84
# 11          28      0.85
# 12          26      0.85
# 13          24      0.85
# 14          22      0.85
# 15          20      0.85
# 16          18      0.84
# 17          17      0.84
# 18          16      0.86
# 19          15      0.85
# 20          14      0.86
# 21          13      0.86
# 22          12      0.84
# 23          11      0.85
# 24          10      0.84
# 25           9      0.85
# 26           8      0.85
# 27           7      0.81
# 28           6      0.82
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'Combined' stored with selected features.
#
# Starting feature selection for 'Clinical' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 16
#
# Skipping Mann-Whitney U Test for 'Clinical' dataset. Using L1-selected features.
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['Race_and_Ethnicity_"{0_=_N/A\n1_=_white,\n2_=_black,\n3_=_asian,\n4_=_native,\n5_=_hispanic,\n6_=_multi,\n7_=_hawa,____8_=_amer_indian}"_2', 'PR_"{0_=_neg,\n1_=_pos}"_1', 'HER2_"{0_=_neg,\n1_=_pos,_2_=_borderline}"_1', 'Staging(Metastasis)#(Mx_-replaced_by_-1)[M]_0', 'Tumor_Grade(M)\n(Mitotic)_3', 'Multicentric/Multifocal_{0_=_no,_1_=_yes}_1']
#
# RFECV History:
#     n_features  cv_score
# 0           16      0.19
# 1           15      0.14
# 2           14      0.26
# 3           13      0.14
# 4           12      0.19
# 5           11      0.30
# 6           10      0.32
# 7            9      0.35
# 8            8      0.32
# 9            7      0.34
# 10           6      0.36
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'Clinical' stored with selected features.
#
# Starting feature selection for 'Image' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 100
#
# Performing Mann-Whitney U Test feature selection with Bonferroni correction and parallelization...
# Number of features after Mann-Whitney U Test: 74
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 74 features...
# Evaluating with 67 features...
# Evaluating with 61 features...
# Evaluating with 55 features...
# Evaluating with 50 features...
# Evaluating with 45 features...
# Evaluating with 41 features...
# Evaluating with 37 features...
# Evaluating with 34 features...
# Evaluating with 31 features...
# Evaluating with 28 features...
# Evaluating with 26 features...
# Evaluating with 24 features...
# Evaluating with 22 features...
# Evaluating with 20 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Early stopping, no significant improvement.
#
# Best Features Selected: ['feature_123', 'feature_276', 'feature_382', 'feature_480', 'feature_554', 'feature_594', 'feature_711', 'feature_944', 'feature_3348', 'feature_3552', 'feature_4411', 'feature_5099', 'feature_5781', 'feature_6526', 'feature_8062', 'feature_9329', 'feature_10363', 'feature_10801', 'feature_10951', 'feature_11752', 'feature_12097', 'feature_14315', 'feature_14940', 'feature_16846', 'feature_17384', 'feature_17637', 'feature_18788', 'feature_19143', 'feature_20568', 'feature_21521', 'feature_21703', 'feature_21780', 'feature_21846', 'feature_21984', 'feature_22848', 'feature_22866', 'feature_23016', 'feature_24146', 'feature_24694', 'feature_24852', 'feature_25069']
#
# RFECV History:
#     n_features  cv_score
# 0           74      0.85
# 1           67      0.85
# 2           61      0.85
# 3           55      0.85
# 4           50      0.85
# 5           45      0.85
# 6           41      0.86
# 7           37      0.85
# 8           34      0.85
# 9           31      0.85
# 10          28      0.85
# 11          26      0.85
# 12          24      0.85
# 13          22      0.85
# 14          20      0.85
# 15          18      0.85
# 16          17      0.84
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'Image' stored with selected features.
#
# Starting feature selection for 'RadiomicsOnly' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 88
#
# Skipping Mann-Whitney U Test for 'RadiomicsOnly' dataset. Using L1-selected features.
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 88 features...
# Evaluating with 80 features...
# Evaluating with 72 features...
# Evaluating with 65 features...
# Evaluating with 59 features...
# Evaluating with 54 features...
# Evaluating with 49 features...
# Evaluating with 45 features...
# Evaluating with 41 features...
# Evaluating with 37 features...
# Evaluating with 34 features...
# Evaluating with 31 features...
# Evaluating with 28 features...
# Evaluating with 26 features...
# Evaluating with 24 features...
# Evaluating with 22 features...
# Evaluating with 20 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['Mean_norm_DHOG_max_timepoint_binsize_2_with_filling_Tumor', 'Max_Probability_tissue_PostCon', 'SER_map_mean_tumor', 'SER_map_information_measure_correlation2_tissue_T1', 'SER_Total_tissue_vol_cu_mm_PostCon', 'WashinRate_map_Cluster_Shade_tissue_PostCon', 'WashinRate_map_Sum_of_Squares_variance_tissue_PostCon']
#
# RFECV History:
#     n_features  cv_score
# 0           88      0.04
# 1           80      0.08
# 2           72      0.03
# 3           65      0.03
# 4           59      0.15
# 5           54      0.05
# 6           49      0.07
# 7           45      0.10
# 8           41      0.10
# 9           37      0.06
# 10          34      0.03
# 11          31      0.07
# 12          28      0.15
# 13          26      0.15
# 14          24      0.17
# 15          22      0.15
# 16          20      0.08
# 17          18      0.13
# 18          17      0.15
# 19          16      0.16
# 20          15      0.15
# 21          14      0.12
# 22          13      0.10
# 23          12      0.18
# 24          11      0.21
# 25          10      0.22
# 26           9      0.22
# 27           8      0.24
# 28           7      0.24
# 29           6      0.19
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'RadiomicsOnly' stored with selected features.
#
# Starting feature selection for 'ClinicalRadiomics' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 93
#
# Skipping Mann-Whitney U Test for 'ClinicalRadiomics' dataset. Using L1-selected features.
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 93 features...
# Evaluating with 84 features...
# Evaluating with 76 features...
# Evaluating with 69 features...
# Evaluating with 63 features...
# Evaluating with 57 features...
# Evaluating with 52 features...
# Evaluating with 47 features...
# Evaluating with 43 features...
# Evaluating with 39 features...
# Evaluating with 36 features...
# Evaluating with 33 features...
# Evaluating with 30 features...
# Evaluating with 27 features...
# Evaluating with 25 features...
# Evaluating with 23 features...
# Evaluating with 21 features...
# Evaluating with 19 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['Ratio_Tissue_vol_enhancing_more_than_20percent_from_PostCon_to_Breast_Vol', 'Mean_norm_DHOG_max_timepoint_binsize_2_with_filling_Tumor', 'Mean_norm_DLBP_max_timepoint_binsize_8_with_filling_Tumor', 'Max_Probability_tissue_PostCon', 'PE_map_sum_variance__tissue_PostCon', 'WashinRate_map_Cluster_Shade_tissue_PostCon']
#
# RFECV History:
#     n_features  cv_score
# 0           93      0.06
# 1           84      0.06
# 2           76      0.08
# 3           69      0.09
# 4           63      0.03
# 5           57      0.07
# 6           52      0.04
# 7           47      0.10
# 8           43      0.11
# 9           39      0.09
# 10          36      0.14
# 11          33      0.10
# 12          30      0.19
# 13          27      0.23
# 14          25      0.25
# 15          23      0.26
# 16          21      0.23
# 17          19      0.24
# 18          18      0.26
# 19          17      0.25
# 20          16      0.28
# 21          15      0.20
# 22          14      0.27
# 23          13      0.26
# 24          12      0.24
# 25          11      0.29
# 26          10      0.21
# 27           9      0.29
# 28           8      0.27
# 29           7      0.33
# 30           6      0.41
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'ClinicalRadiomics' stored with selected features.
#
# Starting feature selection for 'CombinedRadiomics' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 100
#
# Performing Mann-Whitney U Test feature selection with Bonferroni correction and parallelization...
# Number of features after Mann-Whitney U Test: 81
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 81 features...
# Evaluating with 73 features...
# Evaluating with 66 features...
# Evaluating with 60 features...
# Evaluating with 54 features...
# Evaluating with 49 features...
# Evaluating with 45 features...
# Evaluating with 41 features...
# Evaluating with 37 features...
# Evaluating with 34 features...
# Evaluating with 31 features...
# Evaluating with 28 features...
# Evaluating with 26 features...
# Evaluating with 24 features...
# Evaluating with 22 features...
# Evaluating with 20 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Early stopping, no significant improvement.
#
# Best Features Selected: ['feature_276', 'feature_382', 'feature_493', 'feature_594', 'feature_2517', 'feature_2673', 'feature_3552', 'feature_7097', 'feature_9329', 'feature_10951', 'feature_11752', 'feature_18196', 'feature_20968', 'feature_21222', 'feature_21703', 'feature_21846', 'feature_22006', 'feature_22866', 'feature_23016', 'feature_23057', 'feature_24845', 'feature_24852', 'feature_25069', 'Date_of_Birth', 'ER_"{0_=_neg,\n1_=_pos}"_1', 'PR_"{0_=_neg,\n1_=_pos}"_1', 'HER2_"{0_=_neg,\n1_=_pos,_2_=_borderline}"_1', 'Tumor_Grade(M)\n(Mitotic)_3', 'BEDR1_Tumor', 'BEDR2_Tumor', 'Cluster_Prominence_Tumor', 'EnhancementClusterNeighborhoodSimilarity_Tumor', 'Max_Probability_tissue_PostCon', 'Change_in_variance_of_Uptake_Tumor', 'Peak_PE_tumor', 'SER_map_Cluster_Prominence_tumor', 'WashinRate_map_kurtosis_tumor', 'SER_Partial_tissue_vol_cu_mm_T1', 'SER_map_information_measure_correlation2_tissue_T1', 'SER_map_skewness_tissue_PostCon', 'PE_map_kurtosis_tissue_PostCon']
#
# RFECV History:
#     n_features  cv_score
# 0           81      0.83
# 1           73      0.83
# 2           66      0.83
# 3           60      0.84
# 4           54      0.84
# 5           49      0.83
# 6           45      0.84
# 7           41      0.84
# 8           37      0.83
# 9           34      0.82
# 10          31      0.83
# 11          28      0.81
# 12          26      0.82
# 13          24      0.82
# 14          22      0.79
# 15          20      0.81
# 16          18      0.80
# 17          17      0.80
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'CombinedRadiomics' stored with selected features.

# %%
# Create a new dataset 'CombinedSelected' that combines the selected features from 'Clinical' and 'Image' datasets

print("\nCreating new dataset 'CombinedSelected' from the selected features of 'Clinical' and 'Image' datasets.")

# Retrieve the selected features for 'Clinical' and 'Image' datasets
clinical_selected_features = selected_features_dict['Clinical']
image_selected_features = selected_features_dict['Image']

# Retrieve full datasets before splitting from data_variations
X_clinical_full, y_clinical_full, groups_clinical = data_variations['Clinical']
X_image_full, y_image_full, groups_image = data_variations['Image']

# Apply the selected features to the full datasets
X_clinical_selected = X_clinical_full[clinical_selected_features].copy()
X_image_selected = X_image_full[image_selected_features].copy()

# Add 'patient_id' to each dataset
X_clinical_selected['patient_id'] = groups_clinical.astype(str)
X_image_selected['patient_id'] = groups_image.astype(str)

# Merge the datasets on 'patient_id'
combined_df = pd.merge(X_clinical_selected, X_image_selected, on='patient_id', how='inner')

clinical_data_processed = load_clinical_data(clinical_data_path)
# Get the response variable
y_combined = combined_df.merge(
    clinical_data_processed[['patient_id', 'response']],
    on='patient_id',
    how='left')['response'].astype(int)


# Extract patient IDs
groups_combined = combined_df['patient_id']

# Drop 'patient_id' from features
X_combined = combined_df.drop(columns=['patient_id'])

# Now perform train-test split for 'CombinedSelected' dataset
train_idx, test_idx = stratified_group_split(X_combined, y_combined, groups_combined, test_size=0.2, random_state=42)

X_train_full = X_combined.loc[train_idx].reset_index(drop=True)
y_train_full = y_combined.loc[train_idx].reset_index(drop=True)
X_test_full = X_combined.loc[test_idx].reset_index(drop=True)
y_test = y_combined.loc[test_idx].reset_index(drop=True)

patient_ids_train = groups_combined.loc[train_idx].reset_index(drop=True)
patient_ids_test = groups_combined.loc[test_idx].reset_index(drop=True)

# Store in data_splits
data_splits['CombinedSelected'] = {
    'X_train_full': X_train_full,
    'X_test_full': X_test_full,
    'y_train_full': y_train_full,
    'y_test': y_test,
    'patient_ids_train': patient_ids_train,
    'patient_ids_test': patient_ids_test
}

print("New dataset 'CombinedSelected' created and added to data_splits.")
# Out:
# Creating new dataset 'CombinedSelected' from the selected features of 'Clinical' and 'Image' datasets.
# Loading clinical data...
# Clinical data loaded and processed.
# New dataset 'CombinedSelected' created and added to data_splits.

# %%
# Define classifiers and param grid to evaluate
classifiers = {
    'Logistic Regression': LogisticRegression(max_iter=1000, solver='liblinear', random_state=42, class_weight='balanced'),
    'Random Forest': RandomForestClassifier(class_weight='balanced', random_state=42, n_jobs=-1),
    #'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(eval_metric='logloss', random_state=42, n_jobs=-1),
    'LightGBM': lgb.LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=-1),
    'SVM': SVC(kernel='rbf', probability=True, random_state=42, max_iter=5000,class_weight='balanced')
}


param_grids = {
    'XGBoost': {
        'classifier__n_estimators': [50, 100, 150, 200],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__max_depth': [3, 5, 7, 10]
    },
    'LightGBM': {
        'classifier__n_estimators': [50, 100, 150, 200],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__num_leaves': [31, 63],
        'classifier__verbose': [-1]
    },
    'Random Forest': {
        'classifier__n_estimators': [50, 100, 150, 200],
        'classifier__max_depth': [None, 10, 20],
        'classifier__min_samples_split': [2, 5],
        'classifier__min_samples_leaf': [1, 2]
    },
    'Gradient Boosting': {
        'classifier__n_estimators': [100, 150],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__max_depth': [3, 5, 7]
    },
    'Logistic Regression': {
        'classifier__C': np.logspace(-4, 4, 10),
        'classifier__penalty': ['l1', 'l2']
    },
    'SVM': {
        'classifier__C': [0.1, 1, 5, 10],
        'classifier__kernel': ['linear', 'rbf']
    }
}

# %%
# Function: Nested Cross Validation for Hyperparameter Tuning

def nested_cv_evaluation(dataset_name, X, y, groups, classifiers, param_grids, outer_splits=3, inner_splits=2):
    """
    Performs nested cross-validation with hyperparameter tuning and group-aware splitting.
    """
    print(f"\nStarting Nested CV for {dataset_name} dataset...")
    outer_cv = StratifiedGroupKFold(n_splits=outer_splits, shuffle=True, random_state=42)
    aggregated_scores = {}
    best_estimators = {}
    nested_scores = {name: [] for name in classifiers.keys()}
    cv_results_all = {name: [] for name in classifiers.keys()}  # To store cv_results_

    for name, base_classifier in classifiers.items():
        print(f"\nEvaluating {name} on {dataset_name} dataset...")
        start_time = time.time()
        scores = {'accuracy': [], 'precision': [], 'recall': [], 'f1': []}
        best_estimators[name] = []
        cv_results_list = []  # To collect cv_results_ from each outer fold

        for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y, groups=groups), 1):
            print(f"  Outer Fold {fold}/{outer_splits}")
            X_train_fold, X_valid = X.iloc[train_idx], X.iloc[test_idx]
            y_train_fold, y_valid = y.iloc[train_idx], y.iloc[test_idx]
            groups_train_fold = groups.iloc[train_idx]

            # Define the inner cross-validation with group awareness
            inner_cv = StratifiedGroupKFold(n_splits=inner_splits, shuffle=True, random_state=42)


            # **Compute scale_pos_weight for XGBoost and LightGBM**
            if name == 'XGBoost' or name == 'LightGBM':
                scale_pos_weight = (y_train_fold == 0).sum() / (y_train_fold == 1).sum()
                print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {name}")
                # Clone the base classifier to avoid modifying the original
                classifier = clone(base_classifier)
                classifier.set_params(scale_pos_weight=scale_pos_weight)
            else:
                classifier = clone(base_classifier)

            # Define the pipeline
            pipeline = ImbPipeline(steps=[
                ('smote', SMOTE(sampling_strategy='minority', random_state=42)),
                ('scaler', MinMaxScaler()),
                ('classifier', classifier)
            ])

            # Hyperparameter tuning with RandomizedSearchCV
            search = RandomizedSearchCV(
                estimator=pipeline,
                param_distributions=param_grids[name],
                scoring='f1',
                n_iter=5,  # Adjusted for efficiency
                cv=inner_cv.split(X_train_fold, y_train_fold, groups=groups_train_fold),
                random_state=42,
                n_jobs=-1
            )

            # Fit the model on the training fold
            search.fit(X_train_fold, y_train_fold)

            # Get the best estimator
            best_model = search.best_estimator_

            # Evaluate on the validation fold
            y_pred = best_model.predict(X_valid)

            # Compute metrics
            accuracy = accuracy_score(y_valid, y_pred)
            precision = precision_score(y_valid, y_pred, zero_division=0)
            recall = recall_score(y_valid, y_pred)
            f1 = f1_score(y_valid, y_pred)

            # Append scores
            scores['accuracy'].append(accuracy)
            scores['precision'].append(precision)
            scores['recall'].append(recall)
            scores['f1'].append(f1)
            nested_scores[name].append(f1)

            # Store the best estimator
            best_estimators[name].append(best_model)

            # Collect cv_results_
            cv_results = pd.DataFrame(search.cv_results_)
            cv_results_list.append(cv_results)

        # Aggregate scores
        aggregated_scores[name] = {metric: (np.mean(scores[metric]), np.std(scores[metric])) for metric in scores}

        # Combine cv_results_ from all outer folds
        cv_results_all[name] = pd.concat(cv_results_list, ignore_index=True)

        elapsed_time = time.time() - start_time
        print(f"{name} - Completed in {elapsed_time:.2f} seconds")
        print(f"Aggregated Scores for {name}: {aggregated_scores[name]}")

    return aggregated_scores, best_estimators, nested_scores, cv_results_all

# %%
# Nested CV for Hyperparameter Tuning

nested_cv_results = {}  # To store nested CV results
for dataset_name in data_splits.keys():
    print(f"\nStarting Nested Cross-Validation for {dataset_name} Dataset")

    # Retrieve data
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    groups_train = data['patient_ids_train']

    # Perform nested cross-validation
    aggregated_scores, best_estimators, nested_scores, cv_results_all = nested_cv_evaluation(
        dataset_name, X_train_full, y_train_full, groups_train, classifiers, param_grids
    )

    # Store the results
    nested_cv_results[dataset_name] = {
        'aggregated_scores': aggregated_scores,
        'best_estimators': best_estimators,
        'nested_scores': nested_scores,
        'cv_results_all': cv_results_all
    }
# Out:
# Starting Nested Cross-Validation for Combined Dataset
#
# Starting Nested CV for Combined dataset...
#
# Evaluating Logistic Regression on Combined dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 2.04 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.8537208199037224), np.float64(0.013775627414721868)), 'precision': (np.float64(0.9091766457689175), np.float64(0.013006984961930318)), 'recall': (np.float64(0.8121788518321633), np.float64(0.01849088054401774)), 'f1': (np.float64(0.857765334504465), np.float64(0.01106043121972267))}
#
# Evaluating Random Forest on Combined dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 3.62 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.8595500726794484), np.float64(0.01578831819334554)), 'precision': (np.float64(0.9197864722502404), np.float64(0.0187699785049889)), 'recall': (np.float64(0.8131169381749411), np.float64(0.015773485692642367)), 'f1': (np.float64(0.8629690909796786), np.float64(0.011030346885115732))}
#
# Evaluating XGBoost on Combined dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8320 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.8807 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.8142 for XGBoost
# XGBoost - Completed in 2.53 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.8607693303317459), np.float64(0.013458113520352633)), 'precision': (np.float64(0.9312616423018317), np.float64(0.011740607391998361)), 'recall': (np.float64(0.8032620323955161), np.float64(0.02255522138796636)), 'f1': (np.float64(0.8622813133153123), np.float64(0.012367036843008702))}
#
# Evaluating LightGBM on Combined dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8320 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.8807 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.8142 for LightGBM
# LightGBM - Completed in 43.24 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.8388741213044231), np.float64(0.019917275902048417)), 'precision': (np.float64(0.8647062497394673), np.float64(0.008689361520415662)), 'recall': (np.float64(0.8341958627073988), np.float64(0.022916741895099756)), 'f1': (np.float64(0.8491030122507164), np.float64(0.015733528351806456))}
#
# Evaluating SVM on Combined dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 4.20 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.8605466177448404), np.float64(0.015559847197953464)), 'precision': (np.float64(0.9501053545770075), np.float64(0.011792712400058402)), 'recall': (np.float64(0.7847070211261425), np.float64(0.019047926703380545)), 'f1': (np.float64(0.8594017296019021), np.float64(0.01374992340335909))}
#
# Starting Nested Cross-Validation for Clinical Dataset
#
# Starting Nested CV for Clinical dataset...
#
# Evaluating Logistic Regression on Clinical dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.31 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.7174603174603175), np.float64(0.035916534917411966)), 'precision': (np.float64(0.4268997668997669), np.float64(0.05803396280859605)), 'recall': (np.float64(0.6436274509803922), np.float64(0.045188528143104006)), 'f1': (np.float64(0.5122562503820527), np.float64(0.05496040864960581))}
#
# Evaluating Random Forest on Clinical dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.11 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7368530020703933), np.float64(0.017570310152610437)), 'precision': (np.float64(0.4335511982570806), np.float64(0.047905519449446675)), 'recall': (np.float64(0.4582516339869281), np.float64(0.014760700298891065)), 'f1': (np.float64(0.44470439691027924), np.float64(0.03026810409350893))}
#
# Evaluating XGBoost on Clinical dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.4839 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.3438 for XGBoost
# XGBoost - Completed in 0.72 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.6409937888198758), np.float64(0.04178605761876806)), 'precision': (np.float64(0.3534495279593319), np.float64(0.043850363794935454)), 'recall': (np.float64(0.6644607843137255), np.float64(0.04619431610540397)), 'f1': (np.float64(0.46073871409028727), np.float64(0.04610102822396836))}
#
# Evaluating LightGBM on Clinical dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.4839 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.3438 for LightGBM
# LightGBM - Completed in 4.95 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.6169772256728778), np.float64(0.05929933368283449)), 'precision': (np.float64(0.3539491872825206), np.float64(0.04500895268349589)), 'recall': (np.float64(0.7677287581699347), np.float64(0.08318333610584912)), 'f1': (np.float64(0.4810598021082846), np.float64(0.04102029228896985))}
#
# Evaluating SVM on Clinical dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 0.37 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6742581090407177), np.float64(0.0733572703390596)), 'precision': (np.float64(0.40771128271128276), np.float64(0.08466052687400252)), 'recall': (np.float64(0.7323529411764707), np.float64(0.0636726779652138)), 'f1': (np.float64(0.5134952766531714), np.float64(0.04887265576850693))}
#
# Starting Nested Cross-Validation for Image Dataset
#
# Starting Nested CV for Image dataset...
#
# Evaluating Logistic Regression on Image dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.66 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.8606880958336247), np.float64(0.005962933535442605)), 'precision': (np.float64(0.9131038446558546), np.float64(0.009533301309426135)), 'recall': (np.float64(0.8217381746098776), np.float64(0.010740233281127849)), 'f1': (np.float64(0.8649029007671668), np.float64(0.003040462547595553))}
#
# Evaluating Random Forest on Image dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 4.16 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.8469087535870455), np.float64(0.00035973595048067704)), 'precision': (np.float64(0.9230928147641574), np.float64(0.021015501689014143)), 'recall': (np.float64(0.783709544935903), np.float64(0.016424538105309132)), 'f1': (np.float64(0.8473238197086522), np.float64(0.004086010000883613))}
#
# Evaluating XGBoost on Image dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8320 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.8807 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.8142 for XGBoost
# XGBoost - Completed in 7.45 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.8469748913756453), np.float64(0.00214091844147723)), 'precision': (np.float64(0.9094770412026509), np.float64(0.0044414927209804325)), 'recall': (np.float64(0.7972511132750074), np.float64(0.007365967445522903)), 'f1': (np.float64(0.8496367493634231), np.float64(0.0029767256800598153))}
#
# Evaluating LightGBM on Image dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8320 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.8807 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.8142 for LightGBM
# LightGBM - Completed in 53.12 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.8428314910831501), np.float64(0.0072060404520735075)), 'precision': (np.float64(0.8829068670150987), np.float64(0.0033340879579819766)), 'recall': (np.float64(0.8190968892885473), np.float64(0.002798190527173922)), 'f1': (np.float64(0.8498048818597188), np.float64(0.002935293052219709))}
#
# Evaluating SVM on Image dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 4.03 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.8713418627323022), np.float64(0.013245624006094208)), 'precision': (np.float64(0.9579551583996992), np.float64(0.009138925722501159)), 'recall': (np.float64(0.7982781498354722), np.float64(0.03338383861072284)), 'f1': (np.float64(0.8702834164193406), np.float64(0.016475207528029834))}
#
# Starting Nested Cross-Validation for RadiomicsOnly Dataset
#
# Starting Nested CV for RadiomicsOnly dataset...
#
# Evaluating Logistic Regression on RadiomicsOnly dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.31 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.40952380952380957), np.float64(0.19564417699213463)), 'precision': (np.float64(0.2762794182231522), np.float64(0.033844975288739906)), 'recall': (np.float64(0.8333333333333334), np.float64(0.23570226039551584)), 'f1': (np.float64(0.40055315055315055), np.float64(0.02234388319815367))}
#
# Evaluating Random Forest on RadiomicsOnly dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.11 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7047619047619048), np.float64(0.05512303287042964)), 'precision': (np.float64(0.35281385281385286), np.float64(0.10421128240009285)), 'recall': (np.float64(0.27788220551378445), np.float64(0.0984895841048541)), 'f1': (np.float64(0.29778747945131645), np.float64(0.0812730678335265))}
#
# Evaluating XGBoost on RadiomicsOnly dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for XGBoost
# XGBoost - Completed in 0.77 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.3523809523809524), np.float64(0.02693740118805896)), 'precision': (np.float64(0.25065950631241757), np.float64(0.036004565337125025)), 'recall': (np.float64(0.8931704260651628), np.float64(0.039010993179285254)), 'f1': (np.float64(0.3907407407407408), np.float64(0.04764696418618004))}
#
# Evaluating LightGBM on RadiomicsOnly dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for LightGBM
# LightGBM - Completed in 4.69 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.5), np.float64(0.030860669992418384)), 'precision': (np.float64(0.2666759053954176), np.float64(0.04294718895992298)), 'recall': (np.float64(0.6655701754385964), np.float64(0.1282566684702168)), 'f1': (np.float64(0.37915189125295506), np.float64(0.05852720605633966))}
#
# Evaluating SVM on RadiomicsOnly dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 0.42 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.638095238095238), np.float64(0.02428104530282275)), 'precision': (np.float64(0.3416538658474142), np.float64(0.055136027724048506)), 'recall': (np.float64(0.5742481203007518), np.float64(0.04033696190577996)), 'f1': (np.float64(0.42386685830525517), np.float64(0.0343799335529733))}
#
# Starting Nested Cross-Validation for ClinicalRadiomics Dataset
#
# Starting Nested CV for ClinicalRadiomics dataset...
#
# Evaluating Logistic Regression on ClinicalRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.30 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.6666666666666666), np.float64(0.0673435029701474)), 'precision': (np.float64(0.37675765095119934), np.float64(0.04140196011846925)), 'recall': (np.float64(0.6427005012531328), np.float64(0.08301975457459097)), 'f1': (np.float64(0.47460317460317464), np.float64(0.053640461107034285))}
#
# Evaluating Random Forest on ClinicalRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.18 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7095238095238096), np.float64(0.04714045207910316)), 'precision': (np.float64(0.3773148148148148), np.float64(0.05389095706862413)), 'recall': (np.float64(0.39724310776942356), np.float64(0.09919557607600651)), 'f1': (np.float64(0.38543417366946775), np.float64(0.07617399722928195))}
#
# Evaluating XGBoost on ClinicalRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for XGBoost
# XGBoost - Completed in 0.82 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.3666666666666667), np.float64(0.09499970163457146)), 'precision': (np.float64(0.23209884621256735), np.float64(0.03141890986767397)), 'recall': (np.float64(0.7322994987468672), np.float64(0.1930822385088027)), 'f1': (np.float64(0.3432645272267914), np.float64(0.03237861064989321))}
#
# Evaluating LightGBM on ClinicalRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for LightGBM
# LightGBM - Completed in 4.70 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.4904761904761905), np.float64(0.01346870059402948)), 'precision': (np.float64(0.2766032417195208), np.float64(0.034999203782491946)), 'recall': (np.float64(0.7337092731829574), np.float64(0.014747621924736607)), 'f1': (np.float64(0.4007004328146166), np.float64(0.03843978319562313))}
#
# Evaluating SVM on ClinicalRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 0.44 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6761904761904761), np.float64(0.059856214714173954)), 'precision': (np.float64(0.3887853692201518), np.float64(0.06590913030677219)), 'recall': (np.float64(0.6364348370927319), np.float64(0.04454849764902186)), 'f1': (np.float64(0.48055119483690917), np.float64(0.0596643207821348))}
#
# Starting Nested Cross-Validation for CombinedRadiomics Dataset
#
# Starting Nested CV for CombinedRadiomics dataset...
#
# Evaluating Logistic Regression on CombinedRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.78 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.8594366343445827), np.float64(0.019950603103477103)), 'precision': (np.float64(0.8725730814475811), np.float64(0.03570033668219494)), 'recall': (np.float64(0.8681748044627051), np.float64(0.02224732246676233)), 'f1': (np.float64(0.8698408009241482), np.float64(0.020510033017635317))}
#
# Evaluating Random Forest on CombinedRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 3.85 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.8195737311593788), np.float64(0.030142092563074898)), 'precision': (np.float64(0.9224396241797308), np.float64(0.006578203959951598)), 'recall': (np.float64(0.7298766123650117), np.float64(0.043784119354568544)), 'f1': (np.float64(0.8143712161587038), np.float64(0.02983585490533293))}
#
# Evaluating XGBoost on CombinedRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8320 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.8807 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.8142 for XGBoost
# XGBoost - Completed in 4.88 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.7774887570465493), np.float64(0.04914266370570162)), 'precision': (np.float64(0.8852523309771757), np.float64(0.024205067747941785)), 'recall': (np.float64(0.6784189424839653), np.float64(0.06907898459775666)), 'f1': (np.float64(0.7670690140973343), np.float64(0.05255083834058578))}
#
# Evaluating LightGBM on CombinedRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8320 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.8807 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.8142 for LightGBM
# LightGBM - Completed in 44.19 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.7706847055675903), np.float64(0.04506395104273337)), 'precision': (np.float64(0.8428252129143555), np.float64(0.05141654137253502)), 'recall': (np.float64(0.7141087424173924), np.float64(0.029980567572886616)), 'f1': (np.float64(0.7727859330461361), np.float64(0.03658111918147341))}
#
# Evaluating SVM on CombinedRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 4.03 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.9117438934817259), np.float64(0.015572248496055359)), 'precision': (np.float64(0.979510479904965), np.float64(0.015040006495848104)), 'recall': (np.float64(0.8558498482236452), np.float64(0.020093501069931567)), 'f1': (np.float64(0.9133562519007263), np.float64(0.013833220670943044))}
#
# Starting Nested Cross-Validation for CombinedSelected Dataset
#
# Starting Nested CV for CombinedSelected dataset...
#
# Evaluating Logistic Regression on CombinedSelected dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.56 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.8476245430943572), np.float64(0.028069736721116872)), 'precision': (np.float64(0.869644182529845), np.float64(0.034743876430935114)), 'recall': (np.float64(0.8464721816810291), np.float64(0.029520947593534092)), 'f1': (np.float64(0.857175064495087), np.float64(0.02097939580343385))}
#
# Evaluating Random Forest on CombinedSelected dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 3.83 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.8455148672453889), np.float64(0.0038474680213228525)), 'precision': (np.float64(0.9057845840696577), np.float64(0.033533859864031075)), 'recall': (np.float64(0.7947044376207696), np.float64(0.01664883756538697)), 'f1': (np.float64(0.846140464819146), np.float64(0.015303494297726216))}
#
# Evaluating XGBoost on CombinedSelected dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8135 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.7435 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.9867 for XGBoost
# XGBoost - Completed in 7.48 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.8506600455689215), np.float64(0.012260561917351046)), 'precision': (np.float64(0.8974845716441641), np.float64(0.01311462544310736)), 'recall': (np.float64(0.816477620578163), np.float64(0.016469329661648463)), 'f1': (np.float64(0.8548304527545825), np.float64(0.005075162062476754))}
#
# Evaluating LightGBM on CombinedSelected dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 0.8135 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 0.7435 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 0.9867 for LightGBM
# LightGBM - Completed in 55.72 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.8364123566599738), np.float64(0.01594665893143139)), 'precision': (np.float64(0.868245943358294), np.float64(0.02117174291619458)), 'recall': (np.float64(0.8226774337698117), np.float64(0.0188987117823327)), 'f1': (np.float64(0.8443799754355532), np.float64(0.002142061546274493))}
#
# Evaluating SVM on CombinedSelected dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
# /Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#   Outer Fold 3/3
# SVM - Completed in 5.51 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.8420498802934523), np.float64(0.0386864326845361)), 'precision': (np.float64(0.9058933052905376), np.float64(0.02257233834048177)), 'recall': (np.float64(0.7953703779623541), np.float64(0.055181190475061044)), 'f1': (np.float64(0.8454607378179387), np.float64(0.027307341860536547))}

# %%
# Retrain Models on Entire Training Set Using Best Hyperparameters and Evaluate on Test Set

from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, confusion_matrix, classification_report)
from sklearn.base import clone

test_results = {}  # To store test set results

for dataset_name in data_splits.keys():
    print(f"\nRetraining and Evaluating Models for {dataset_name} Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test = data['y_test']
    groups_train = data['patient_ids_train']
    groups_test = data['patient_ids_test']
    
    # Reset indices to ensure consistency
    X_train_full = X_train_full.reset_index(drop=True)
    y_train_full = y_train_full.reset_index(drop=True)
    X_test_full = X_test_full.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)
    
    # Get nested CV results for the current dataset
    nested_results = nested_cv_results[dataset_name]
    cv_results_all = nested_results['cv_results_all']
    
    test_results[dataset_name] = {}  # Initialize dictionary to store test results for each classifier
    
    for classifier_name in classifiers.keys():
        print(f"\nRetraining {classifier_name} on {dataset_name} dataset...")
        
        # Get cross-validation results for the current classifier
        cv_results = cv_results_all[classifier_name]
        
        # Find the hyperparameters with the best mean_test_score (which is F1 score)
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier with default parameters
        default_classifier = classifiers[classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)

        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)
        
        # Handle compatibility between solver and penalty for Logistic Regression
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_full, y_train_full)
        
        # Predict on the test set
        y_pred = pipeline.predict(X_test_full)
        
        # Get predicted probabilities if available
        y_proba = pipeline.predict_proba(X_test_full)[:, 1] if hasattr(pipeline, "predict_proba") else None
        
        # Compute performance metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, zero_division=0)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, zero_division=0)
        
        # Store the test results
        test_results[dataset_name][classifier_name] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"{classifier_name} Test Results on {dataset_name} Dataset:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        if roc_auc is not None:
            print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)
# Out:
# Retraining and Evaluating Models for Combined Dataset
#
# Retraining Logistic Regression on Combined dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on Combined Dataset:
# Accuracy: 0.8085
# Precision: 0.8529
# Recall: 0.7789
# F1 Score: 0.8143
# ROC AUC Score: 0.9082
# Confusion Matrix:
# [[349  65]
#  [107 377]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80       414
#            1       0.85      0.78      0.81       484
#
#     accuracy                           0.81       898
#    macro avg       0.81      0.81      0.81       898
# weighted avg       0.81      0.81      0.81       898
#
#
# Retraining Random Forest on Combined dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on Combined Dataset:
# Accuracy: 0.8307
# Precision: 0.8952
# Recall: 0.7769
# F1 Score: 0.8319
# ROC AUC Score: 0.9088
# Confusion Matrix:
# [[370  44]
#  [108 376]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83       414
#            1       0.90      0.78      0.83       484
#
#     accuracy                           0.83       898
#    macro avg       0.83      0.84      0.83       898
# weighted avg       0.84      0.83      0.83       898
#
#
# Retraining XGBoost on Combined dataset...
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on Combined Dataset:
# Accuracy: 0.8274
# Precision: 0.8764
# Recall: 0.7913
# F1 Score: 0.8317
# ROC AUC Score: 0.9074
# Confusion Matrix:
# [[360  54]
#  [101 383]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82       414
#            1       0.88      0.79      0.83       484
#
#     accuracy                           0.83       898
#    macro avg       0.83      0.83      0.83       898
# weighted avg       0.83      0.83      0.83       898
#
#
# Retraining LightGBM on Combined dataset...
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on Combined Dataset:
# Accuracy: 0.8085
# Precision: 0.8305
# Recall: 0.8099
# F1 Score: 0.8201
# ROC AUC Score: 0.8769
# Confusion Matrix:
# [[334  80]
#  [ 92 392]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.80       414
#            1       0.83      0.81      0.82       484
#
#     accuracy                           0.81       898
#    macro avg       0.81      0.81      0.81       898
# weighted avg       0.81      0.81      0.81       898
#
#
# Retraining SVM on Combined dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on Combined Dataset:
# Accuracy: 0.8185
# Precision: 0.9023
# Recall: 0.7438
# F1 Score: 0.8154
# ROC AUC Score: 0.8921
# Confusion Matrix:
# [[375  39]
#  [124 360]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82       414
#            1       0.90      0.74      0.82       484
#
#     accuracy                           0.82       898
#    macro avg       0.83      0.82      0.82       898
# weighted avg       0.83      0.82      0.82       898
#
#
# Retraining and Evaluating Models for Clinical Dataset
#
# Retraining Logistic Regression on Clinical dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on Clinical Dataset:
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.6961
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Retraining Random Forest on Clinical dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on Clinical Dataset:
# Accuracy: 0.7170
# Precision: 0.4000
# Recall: 0.5000
# F1 Score: 0.4444
# ROC AUC Score: 0.6230
# Confusion Matrix:
# [[32  9]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81        41
#            1       0.40      0.50      0.44        12
#
#     accuracy                           0.72        53
#    macro avg       0.62      0.64      0.63        53
# weighted avg       0.74      0.72      0.73        53
#
#
# Retraining XGBoost on Clinical dataset...
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on Clinical Dataset:
# Accuracy: 0.6981
# Precision: 0.3889
# Recall: 0.5833
# F1 Score: 0.4667
# ROC AUC Score: 0.6006
# Confusion Matrix:
# [[30 11]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        41
#            1       0.39      0.58      0.47        12
#
#     accuracy                           0.70        53
#    macro avg       0.62      0.66      0.63        53
# weighted avg       0.75      0.70      0.72        53
#
#
# Retraining LightGBM on Clinical dataset...
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on Clinical Dataset:
# Accuracy: 0.4906
# Precision: 0.2581
# Recall: 0.6667
# F1 Score: 0.3721
# ROC AUC Score: 0.6514
# Confusion Matrix:
# [[18 23]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.44      0.57        41
#            1       0.26      0.67      0.37        12
#
#     accuracy                           0.49        53
#    macro avg       0.54      0.55      0.47        53
# weighted avg       0.69      0.49      0.53        53
#
#
# Retraining SVM on Clinical dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on Clinical Dataset:
# Accuracy: 0.5849
# Precision: 0.3077
# Recall: 0.6667
# F1 Score: 0.4211
# ROC AUC Score: 0.6900
# Confusion Matrix:
# [[23 18]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.56      0.68        41
#            1       0.31      0.67      0.42        12
#
#     accuracy                           0.58        53
#    macro avg       0.58      0.61      0.55        53
# weighted avg       0.73      0.58      0.62        53
#
#
# Retraining and Evaluating Models for Image Dataset
#
# Retraining Logistic Regression on Image dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on Image Dataset:
# Accuracy: 0.8051
# Precision: 0.8759
# Recall: 0.7438
# F1 Score: 0.8045
# ROC AUC Score: 0.8309
# Confusion Matrix:
# [[363  51]
#  [124 360]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81       414
#            1       0.88      0.74      0.80       484
#
#     accuracy                           0.81       898
#    macro avg       0.81      0.81      0.81       898
# weighted avg       0.82      0.81      0.81       898
#
#
# Retraining Random Forest on Image dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on Image Dataset:
# Accuracy: 0.8363
# Precision: 0.9266
# Recall: 0.7562
# F1 Score: 0.8328
# ROC AUC Score: 0.8869
# Confusion Matrix:
# [[385  29]
#  [118 366]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       414
#            1       0.93      0.76      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.85      0.84      0.84       898
# weighted avg       0.85      0.84      0.84       898
#
#
# Retraining XGBoost on Image dataset...
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on Image Dataset:
# Accuracy: 0.8419
# Precision: 0.9275
# Recall: 0.7665
# F1 Score: 0.8394
# ROC AUC Score: 0.8801
# Confusion Matrix:
# [[385  29]
#  [113 371]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       414
#            1       0.93      0.77      0.84       484
#
#     accuracy                           0.84       898
#    macro avg       0.85      0.85      0.84       898
# weighted avg       0.86      0.84      0.84       898
#
#
# Retraining LightGBM on Image dataset...
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on Image Dataset:
# Accuracy: 0.8218
# Precision: 0.8857
# Recall: 0.7686
# F1 Score: 0.8230
# ROC AUC Score: 0.8713
# Confusion Matrix:
# [[366  48]
#  [112 372]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82       414
#            1       0.89      0.77      0.82       484
#
#     accuracy                           0.82       898
#    macro avg       0.83      0.83      0.82       898
# weighted avg       0.83      0.82      0.82       898
#
#
# Retraining SVM on Image dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on Image Dataset:
# Accuracy: 0.8363
# Precision: 0.9469
# Recall: 0.7376
# F1 Score: 0.8293
# ROC AUC Score: 0.8461
# Confusion Matrix:
# [[394  20]
#  [127 357]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.84       414
#            1       0.95      0.74      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.85      0.84      0.84       898
# weighted avg       0.86      0.84      0.84       898
#
#
# Retraining and Evaluating Models for RadiomicsOnly Dataset
#
# Retraining Logistic Regression on RadiomicsOnly dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.2830
# Precision: 0.2292
# Recall: 0.9167
# F1 Score: 0.3667
# ROC AUC Score: 0.5041
# Confusion Matrix:
# [[ 4 37]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.10      0.17        41
#            1       0.23      0.92      0.37        12
#
#     accuracy                           0.28        53
#    macro avg       0.51      0.51      0.27        53
# weighted avg       0.67      0.28      0.22        53
#
#
# Retraining Random Forest on RadiomicsOnly dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.3008
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Retraining XGBoost on RadiomicsOnly dataset...
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining LightGBM on RadiomicsOnly dataset...
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.4583
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining SVM on RadiomicsOnly dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.2264
# Precision: 0.2157
# Recall: 0.9167
# F1 Score: 0.3492
# ROC AUC Score: 0.4705
# Confusion Matrix:
# [[ 1 40]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.05        41
#            1       0.22      0.92      0.35        12
#
#     accuracy                           0.23        53
#    macro avg       0.36      0.47      0.20        53
# weighted avg       0.44      0.23      0.12        53
#
#
# Retraining and Evaluating Models for ClinicalRadiomics Dataset
#
# Retraining Logistic Regression on ClinicalRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining Random Forest on ClinicalRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.4868
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining XGBoost on ClinicalRadiomics dataset...
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining LightGBM on ClinicalRadiomics dataset...
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining SVM on ClinicalRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining and Evaluating Models for CombinedRadiomics Dataset
#
# Retraining Logistic Regression on CombinedRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.5056
# Precision: 1.0000
# Recall: 0.0826
# F1 Score: 0.1527
# ROC AUC Score: 0.5413
# Confusion Matrix:
# [[414   0]
#  [444  40]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.65       414
#            1       1.00      0.08      0.15       484
#
#     accuracy                           0.51       898
#    macro avg       0.74      0.54      0.40       898
# weighted avg       0.76      0.51      0.38       898
#
#
# Retraining Random Forest on CombinedRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.8252
# Precision: 0.9455
# Recall: 0.7169
# F1 Score: 0.8155
# ROC AUC Score: 0.8797
# Confusion Matrix:
# [[394  20]
#  [137 347]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.95      0.83       414
#            1       0.95      0.72      0.82       484
#
#     accuracy                           0.83       898
#    macro avg       0.84      0.83      0.82       898
# weighted avg       0.85      0.83      0.82       898
#
#
# Retraining XGBoost on CombinedRadiomics dataset...
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.6236
# Precision: 0.6008
# Recall: 0.8988
# F1 Score: 0.7202
# ROC AUC Score: 0.8185
# Confusion Matrix:
# [[125 289]
#  [ 49 435]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.30      0.43       414
#            1       0.60      0.90      0.72       484
#
#     accuracy                           0.62       898
#    macro avg       0.66      0.60      0.57       898
# weighted avg       0.66      0.62      0.58       898
#
#
# Retraining LightGBM on CombinedRadiomics dataset...
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.7806
# Precision: 0.7808
# Recall: 0.8244
# F1 Score: 0.8020
# ROC AUC Score: 0.8714
# Confusion Matrix:
# [[302 112]
#  [ 85 399]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.75       414
#            1       0.78      0.82      0.80       484
#
#     accuracy                           0.78       898
#    macro avg       0.78      0.78      0.78       898
# weighted avg       0.78      0.78      0.78       898
#
#
# Retraining SVM on CombinedRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.4610
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[414   0]
#  [484   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63       414
#            1       0.00      0.00      0.00       484
#
#     accuracy                           0.46       898
#    macro avg       0.23      0.50      0.32       898
# weighted avg       0.21      0.46      0.29       898
#
#
# Retraining and Evaluating Models for CombinedSelected Dataset
#
# Retraining Logistic Regression on CombinedSelected dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on CombinedSelected Dataset:
# Accuracy: 0.8603
# Precision: 0.8834
# Recall: 0.8521
# F1 Score: 0.8674
# ROC AUC Score: 0.9416
# Confusion Matrix:
# [[361  54]
#  [ 71 409]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       415
#            1       0.88      0.85      0.87       480
#
#     accuracy                           0.86       895
#    macro avg       0.86      0.86      0.86       895
# weighted avg       0.86      0.86      0.86       895
#
#
# Retraining Random Forest on CombinedSelected dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on CombinedSelected Dataset:
# Accuracy: 0.8570
# Precision: 0.9037
# Recall: 0.8208
# F1 Score: 0.8603
# ROC AUC Score: 0.9058
# Confusion Matrix:
# [[373  42]
#  [ 86 394]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       415
#            1       0.90      0.82      0.86       480
#
#     accuracy                           0.86       895
#    macro avg       0.86      0.86      0.86       895
# weighted avg       0.86      0.86      0.86       895
#
#
# Retraining XGBoost on CombinedSelected dataset...
# Computed scale_pos_weight: 0.8392 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on CombinedSelected Dataset:
# Accuracy: 0.8525
# Precision: 0.9028
# Recall: 0.8125
# F1 Score: 0.8553
# ROC AUC Score: 0.9143
# Confusion Matrix:
# [[373  42]
#  [ 90 390]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       415
#            1       0.90      0.81      0.86       480
#
#     accuracy                           0.85       895
#    macro avg       0.85      0.86      0.85       895
# weighted avg       0.86      0.85      0.85       895
#
#
# Retraining LightGBM on CombinedSelected dataset...
# Computed scale_pos_weight: 0.8392 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on CombinedSelected Dataset:
# Accuracy: 0.8659
# Precision: 0.9186
# Recall: 0.8229
# F1 Score: 0.8681
# ROC AUC Score: 0.9188
# Confusion Matrix:
# [[380  35]
#  [ 85 395]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.86       415
#            1       0.92      0.82      0.87       480
#
#     accuracy                           0.87       895
#    macro avg       0.87      0.87      0.87       895
# weighted avg       0.87      0.87      0.87       895
#
#
# Retraining SVM on CombinedSelected dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on CombinedSelected Dataset:
# Accuracy: 0.8749
# Precision: 0.9163
# Recall: 0.8438
# F1 Score: 0.8785
# ROC AUC Score: 0.9459
# Confusion Matrix:
# [[378  37]
#  [ 75 405]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87       415
#            1       0.92      0.84      0.88       480
#
#     accuracy                           0.87       895
#    macro avg       0.88      0.88      0.87       895
# weighted avg       0.88      0.87      0.88       895

# %%
data_splits['Combined']['patient_ids_test'].unique()
# Out:
# array(['141', '834', '507', '573', '400', '809', '633', '686', '144',
#        '517', '150', '137', '271', '650', '839', '202', '157', '758',
#        '218', '568', '061', '353', '057', '064', '105', '765', '019',
#        '886', '071', '585', '412', '865', '045', '101', '609', '205',
#        '915', '114', '694', '107', '437', '869', '283', '817', '287',
#        '780', '177', '307', '028', '464', '198', '321', '148'],
#       dtype=object)

# %%
# Displaying Comprehensive Performance Metrics for Each Model on Test Set

for dataset_name, classifiers_results in test_results.items():
    print(f"\nTest Results for {dataset_name} Dataset:")
    for classifier_name, metrics in classifiers_results.items():
        print(f"\nClassifier: {classifier_name}")
        print(f"Accuracy: {metrics['accuracy']:.4f}")
        print(f"Precision: {metrics['precision']:.4f}")
        print(f"Recall: {metrics['recall']:.4f}")
        print(f"F1 Score: {metrics['f1']:.4f}")
        if metrics['roc_auc'] is not None:
            print(f"ROC AUC Score: {metrics['roc_auc']:.4f}")
        print("Confusion Matrix:")
        print(metrics['confusion_matrix'])
        print("Classification Report:")
        print(metrics['classification_report'])
# Out:
# Test Results for Combined Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.8085
# Precision: 0.8529
# Recall: 0.7789
# F1 Score: 0.8143
# ROC AUC Score: 0.9082
# Confusion Matrix:
# [[349  65]
#  [107 377]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80       414
#            1       0.85      0.78      0.81       484
#
#     accuracy                           0.81       898
#    macro avg       0.81      0.81      0.81       898
# weighted avg       0.81      0.81      0.81       898
#
#
# Classifier: Random Forest
# Accuracy: 0.8307
# Precision: 0.8952
# Recall: 0.7769
# F1 Score: 0.8319
# ROC AUC Score: 0.9088
# Confusion Matrix:
# [[370  44]
#  [108 376]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83       414
#            1       0.90      0.78      0.83       484
#
#     accuracy                           0.83       898
#    macro avg       0.83      0.84      0.83       898
# weighted avg       0.84      0.83      0.83       898
#
#
# Classifier: XGBoost
# Accuracy: 0.8274
# Precision: 0.8764
# Recall: 0.7913
# F1 Score: 0.8317
# ROC AUC Score: 0.9074
# Confusion Matrix:
# [[360  54]
#  [101 383]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82       414
#            1       0.88      0.79      0.83       484
#
#     accuracy                           0.83       898
#    macro avg       0.83      0.83      0.83       898
# weighted avg       0.83      0.83      0.83       898
#
#
# Classifier: LightGBM
# Accuracy: 0.8085
# Precision: 0.8305
# Recall: 0.8099
# F1 Score: 0.8201
# ROC AUC Score: 0.8769
# Confusion Matrix:
# [[334  80]
#  [ 92 392]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.80       414
#            1       0.83      0.81      0.82       484
#
#     accuracy                           0.81       898
#    macro avg       0.81      0.81      0.81       898
# weighted avg       0.81      0.81      0.81       898
#
#
# Classifier: SVM
# Accuracy: 0.8185
# Precision: 0.9023
# Recall: 0.7438
# F1 Score: 0.8154
# ROC AUC Score: 0.8921
# Confusion Matrix:
# [[375  39]
#  [124 360]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82       414
#            1       0.90      0.74      0.82       484
#
#     accuracy                           0.82       898
#    macro avg       0.83      0.82      0.82       898
# weighted avg       0.83      0.82      0.82       898
#
#
# Test Results for Clinical Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.6961
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Classifier: Random Forest
# Accuracy: 0.7170
# Precision: 0.4000
# Recall: 0.5000
# F1 Score: 0.4444
# ROC AUC Score: 0.6230
# Confusion Matrix:
# [[32  9]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81        41
#            1       0.40      0.50      0.44        12
#
#     accuracy                           0.72        53
#    macro avg       0.62      0.64      0.63        53
# weighted avg       0.74      0.72      0.73        53
#
#
# Classifier: XGBoost
# Accuracy: 0.6981
# Precision: 0.3889
# Recall: 0.5833
# F1 Score: 0.4667
# ROC AUC Score: 0.6006
# Confusion Matrix:
# [[30 11]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        41
#            1       0.39      0.58      0.47        12
#
#     accuracy                           0.70        53
#    macro avg       0.62      0.66      0.63        53
# weighted avg       0.75      0.70      0.72        53
#
#
# Classifier: LightGBM
# Accuracy: 0.4906
# Precision: 0.2581
# Recall: 0.6667
# F1 Score: 0.3721
# ROC AUC Score: 0.6514
# Confusion Matrix:
# [[18 23]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.44      0.57        41
#            1       0.26      0.67      0.37        12
#
#     accuracy                           0.49        53
#    macro avg       0.54      0.55      0.47        53
# weighted avg       0.69      0.49      0.53        53
#
#
# Classifier: SVM
# Accuracy: 0.5849
# Precision: 0.3077
# Recall: 0.6667
# F1 Score: 0.4211
# ROC AUC Score: 0.6900
# Confusion Matrix:
# [[23 18]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.56      0.68        41
#            1       0.31      0.67      0.42        12
#
#     accuracy                           0.58        53
#    macro avg       0.58      0.61      0.55        53
# weighted avg       0.73      0.58      0.62        53
#
#
# Test Results for Image Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.8051
# Precision: 0.8759
# Recall: 0.7438
# F1 Score: 0.8045
# ROC AUC Score: 0.8309
# Confusion Matrix:
# [[363  51]
#  [124 360]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81       414
#            1       0.88      0.74      0.80       484
#
#     accuracy                           0.81       898
#    macro avg       0.81      0.81      0.81       898
# weighted avg       0.82      0.81      0.81       898
#
#
# Classifier: Random Forest
# Accuracy: 0.8363
# Precision: 0.9266
# Recall: 0.7562
# F1 Score: 0.8328
# ROC AUC Score: 0.8869
# Confusion Matrix:
# [[385  29]
#  [118 366]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       414
#            1       0.93      0.76      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.85      0.84      0.84       898
# weighted avg       0.85      0.84      0.84       898
#
#
# Classifier: XGBoost
# Accuracy: 0.8419
# Precision: 0.9275
# Recall: 0.7665
# F1 Score: 0.8394
# ROC AUC Score: 0.8801
# Confusion Matrix:
# [[385  29]
#  [113 371]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       414
#            1       0.93      0.77      0.84       484
#
#     accuracy                           0.84       898
#    macro avg       0.85      0.85      0.84       898
# weighted avg       0.86      0.84      0.84       898
#
#
# Classifier: LightGBM
# Accuracy: 0.8218
# Precision: 0.8857
# Recall: 0.7686
# F1 Score: 0.8230
# ROC AUC Score: 0.8713
# Confusion Matrix:
# [[366  48]
#  [112 372]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82       414
#            1       0.89      0.77      0.82       484
#
#     accuracy                           0.82       898
#    macro avg       0.83      0.83      0.82       898
# weighted avg       0.83      0.82      0.82       898
#
#
# Classifier: SVM
# Accuracy: 0.8363
# Precision: 0.9469
# Recall: 0.7376
# F1 Score: 0.8293
# ROC AUC Score: 0.8461
# Confusion Matrix:
# [[394  20]
#  [127 357]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.95      0.84       414
#            1       0.95      0.74      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.85      0.84      0.84       898
# weighted avg       0.86      0.84      0.84       898
#
#
# Test Results for RadiomicsOnly Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.2830
# Precision: 0.2292
# Recall: 0.9167
# F1 Score: 0.3667
# ROC AUC Score: 0.5041
# Confusion Matrix:
# [[ 4 37]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.10      0.17        41
#            1       0.23      0.92      0.37        12
#
#     accuracy                           0.28        53
#    macro avg       0.51      0.51      0.27        53
# weighted avg       0.67      0.28      0.22        53
#
#
# Classifier: Random Forest
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.3008
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: XGBoost
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Classifier: LightGBM
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.4583
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Classifier: SVM
# Accuracy: 0.2264
# Precision: 0.2157
# Recall: 0.9167
# F1 Score: 0.3492
# ROC AUC Score: 0.4705
# Confusion Matrix:
# [[ 1 40]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.05        41
#            1       0.22      0.92      0.35        12
#
#     accuracy                           0.23        53
#    macro avg       0.36      0.47      0.20        53
# weighted avg       0.44      0.23      0.12        53
#
#
# Test Results for ClinicalRadiomics Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Classifier: Random Forest
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.4868
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Classifier: XGBoost
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Classifier: LightGBM
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Classifier: SVM
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Test Results for CombinedRadiomics Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.5056
# Precision: 1.0000
# Recall: 0.0826
# F1 Score: 0.1527
# ROC AUC Score: 0.5413
# Confusion Matrix:
# [[414   0]
#  [444  40]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.65       414
#            1       1.00      0.08      0.15       484
#
#     accuracy                           0.51       898
#    macro avg       0.74      0.54      0.40       898
# weighted avg       0.76      0.51      0.38       898
#
#
# Classifier: Random Forest
# Accuracy: 0.8252
# Precision: 0.9455
# Recall: 0.7169
# F1 Score: 0.8155
# ROC AUC Score: 0.8797
# Confusion Matrix:
# [[394  20]
#  [137 347]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.95      0.83       414
#            1       0.95      0.72      0.82       484
#
#     accuracy                           0.83       898
#    macro avg       0.84      0.83      0.82       898
# weighted avg       0.85      0.83      0.82       898
#
#
# Classifier: XGBoost
# Accuracy: 0.6236
# Precision: 0.6008
# Recall: 0.8988
# F1 Score: 0.7202
# ROC AUC Score: 0.8185
# Confusion Matrix:
# [[125 289]
#  [ 49 435]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.30      0.43       414
#            1       0.60      0.90      0.72       484
#
#     accuracy                           0.62       898
#    macro avg       0.66      0.60      0.57       898
# weighted avg       0.66      0.62      0.58       898
#
#
# Classifier: LightGBM
# Accuracy: 0.7806
# Precision: 0.7808
# Recall: 0.8244
# F1 Score: 0.8020
# ROC AUC Score: 0.8714
# Confusion Matrix:
# [[302 112]
#  [ 85 399]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.75       414
#            1       0.78      0.82      0.80       484
#
#     accuracy                           0.78       898
#    macro avg       0.78      0.78      0.78       898
# weighted avg       0.78      0.78      0.78       898
#
#
# Classifier: SVM
# Accuracy: 0.4610
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[414   0]
#  [484   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63       414
#            1       0.00      0.00      0.00       484
#
#     accuracy                           0.46       898
#    macro avg       0.23      0.50      0.32       898
# weighted avg       0.21      0.46      0.29       898
#
#
# Test Results for CombinedSelected Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.8603
# Precision: 0.8834
# Recall: 0.8521
# F1 Score: 0.8674
# ROC AUC Score: 0.9416
# Confusion Matrix:
# [[361  54]
#  [ 71 409]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       415
#            1       0.88      0.85      0.87       480
#
#     accuracy                           0.86       895
#    macro avg       0.86      0.86      0.86       895
# weighted avg       0.86      0.86      0.86       895
#
#
# Classifier: Random Forest
# Accuracy: 0.8570
# Precision: 0.9037
# Recall: 0.8208
# F1 Score: 0.8603
# ROC AUC Score: 0.9058
# Confusion Matrix:
# [[373  42]
#  [ 86 394]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       415
#            1       0.90      0.82      0.86       480
#
#     accuracy                           0.86       895
#    macro avg       0.86      0.86      0.86       895
# weighted avg       0.86      0.86      0.86       895
#
#
# Classifier: XGBoost
# Accuracy: 0.8525
# Precision: 0.9028
# Recall: 0.8125
# F1 Score: 0.8553
# ROC AUC Score: 0.9143
# Confusion Matrix:
# [[373  42]
#  [ 90 390]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       415
#            1       0.90      0.81      0.86       480
#
#     accuracy                           0.85       895
#    macro avg       0.85      0.86      0.85       895
# weighted avg       0.86      0.85      0.85       895
#
#
# Classifier: LightGBM
# Accuracy: 0.8659
# Precision: 0.9186
# Recall: 0.8229
# F1 Score: 0.8681
# ROC AUC Score: 0.9188
# Confusion Matrix:
# [[380  35]
#  [ 85 395]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.86       415
#            1       0.92      0.82      0.87       480
#
#     accuracy                           0.87       895
#    macro avg       0.87      0.87      0.87       895
# weighted avg       0.87      0.87      0.87       895
#
#
# Classifier: SVM
# Accuracy: 0.8749
# Precision: 0.9163
# Recall: 0.8438
# F1 Score: 0.8785
# ROC AUC Score: 0.9459
# Confusion Matrix:
# [[378  37]
#  [ 75 405]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87       415
#            1       0.92      0.84      0.88       480
#
#     accuracy                           0.87       895
#    macro avg       0.88      0.88      0.87       895
# weighted avg       0.88      0.87      0.88       895

# %%
# Slice wise Youden's J Threshold prediction

import numpy as np
from sklearn.metrics import roc_curve

# Define a consistent suffix for adjusted classifiers
THRESHOLD_ADJUSTED_SUFFIX = ' (Threshold Adjusted)'

# Helper function to extract the base classifier name by removing any suffix in parentheses
def get_base_classifier_name(name):
    if '(' in name and ')' in name:
        return name.split('(')[0].strip()
    return name

# Function to find optimal threshold using Youden's J-statistic
def find_optimal_threshold(y_true, y_proba):
    fpr, tpr, thresholds = roc_curve(y_true, y_proba)
    J = tpr - fpr
    ix = np.argmax(J)
    optimal_threshold = thresholds[ix]
    print(f"Optimal Threshold (Youden's J): {optimal_threshold:.4f}")
    return optimal_threshold

# Apply threshold adjustment to each classifier on each dataset
for dataset_name in test_results.keys():
    print(f"\nAdjusting Thresholds for {dataset_name} Dataset:")
    classifier_names = list(test_results[dataset_name].keys())  # Get current classifier names
    for classifier_name in classifier_names:
        if THRESHOLD_ADJUSTED_SUFFIX in classifier_name:
            continue  # Skip already adjusted classifiers
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve the pipeline and test data
        data = data_splits[dataset_name]
        X_test_full = data['X_test_full']
        y_test = data['y_test']
        X_train_full = data['X_train_full']
        y_train_full = data['y_train_full']
        
        # Extract base classifier name
        base_classifier_name = get_base_classifier_name(classifier_name)
        
        # Get the best hyperparameters from nested_cv_results
        nested_results = nested_cv_results[dataset_name]
        cv_results_all = nested_results['cv_results_all']
        try:
            cv_results = cv_results_all[base_classifier_name]
        except KeyError:
            print(f"Error: '{base_classifier_name}' not found in cv_results_all for dataset '{dataset_name}'. Skipping threshold adjustment for this classifier.")
            continue
        
        # Find the hyperparameters with the best mean_test_score (F1 score)
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier from the classifiers dictionary
        default_classifier = classifiers[base_classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)
        
        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)

        # Handle compatibility between solver and penalty for Logistic Regression
        if base_classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        

        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Compute predicted probabilities
        y_proba = pipeline.predict_proba(X_test_full)[:, 1] if hasattr(pipeline, "predict_proba") else None
        
        # Check if y_proba is available
        if y_proba is None:
            print("Predicted probabilities not available. Skipping threshold adjustment.")
            continue
        
        # Find optimal threshold
        optimal_threshold = find_optimal_threshold(y_test, y_proba)
        
        # Make predictions with the optimal threshold
        y_pred_optimal = (y_proba >= optimal_threshold).astype(int)
        
        # Evaluate performance
        accuracy = accuracy_score(y_test, y_pred_optimal)
        precision = precision_score(y_test, y_pred_optimal, zero_division=0)
        recall = recall_score(y_test, y_pred_optimal)
        f1 = f1_score(y_test, y_pred_optimal)
        roc_auc = roc_auc_score(y_test, y_proba)
        conf_matrix = confusion_matrix(y_test, y_pred_optimal)
        class_report = classification_report(y_test, y_pred_optimal, zero_division=0)
        
        # Define the adjusted classifier name
        adjusted_classifier_name = f"{base_classifier_name}{THRESHOLD_ADJUSTED_SUFFIX}"
        
        # Update the results with adjusted threshold
        test_results[dataset_name][adjusted_classifier_name] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"Adjusted Threshold Test Results:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)
# Out:
# Adjusting Thresholds for Combined Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.8421
# Adjusted Threshold Test Results:
# Accuracy: 0.8419
# Precision: 0.9886
# Recall: 0.7149
# F1 Score: 0.8297
# ROC AUC Score: 0.9077
# Confusion Matrix:
# [[410   4]
#  [138 346]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.85       414
#            1       0.99      0.71      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.87      0.85      0.84       898
# weighted avg       0.88      0.84      0.84       898
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5906
# Adjusted Threshold Test Results:
# Accuracy: 0.8374
# Precision: 0.9268
# Recall: 0.7583
# F1 Score: 0.8341
# ROC AUC Score: 0.9069
# Confusion Matrix:
# [[385  29]
#  [117 367]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       414
#            1       0.93      0.76      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.85      0.84      0.84       898
# weighted avg       0.85      0.84      0.84       898
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.8924
# Adjusted Threshold Test Results:
# Accuracy: 0.8385
# Precision: 0.9885
# Recall: 0.7087
# F1 Score: 0.8255
# ROC AUC Score: 0.9050
# Confusion Matrix:
# [[410   4]
#  [141 343]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.99      0.85       414
#            1       0.99      0.71      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.87      0.85      0.84       898
# weighted avg       0.88      0.84      0.84       898
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.9947
# Adjusted Threshold Test Results:
# Accuracy: 0.8330
# Precision: 0.9613
# Recall: 0.7190
# F1 Score: 0.8227
# ROC AUC Score: 0.8789
# Confusion Matrix:
# [[400  14]
#  [136 348]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.97      0.84       414
#            1       0.96      0.72      0.82       484
#
#     accuracy                           0.83       898
#    macro avg       0.85      0.84      0.83       898
# weighted avg       0.86      0.83      0.83       898
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.8777
# Adjusted Threshold Test Results:
# Accuracy: 0.8352
# Precision: 0.9641
# Recall: 0.7211
# F1 Score: 0.8251
# ROC AUC Score: 0.8901
# Confusion Matrix:
# [[401  13]
#  [135 349]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.97      0.84       414
#            1       0.96      0.72      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.86      0.84      0.83       898
# weighted avg       0.86      0.84      0.83       898
#
#
# Adjusting Thresholds for Clinical Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.6439
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.7104
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.3328
# Adjusted Threshold Test Results:
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.6433
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7301
# Adjusted Threshold Test Results:
# Accuracy: 0.7547
# Precision: 0.4615
# Recall: 0.5000
# F1 Score: 0.4800
# ROC AUC Score: 0.6087
# Confusion Matrix:
# [[34  7]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        41
#            1       0.46      0.50      0.48        12
#
#     accuracy                           0.75        53
#    macro avg       0.66      0.66      0.66        53
# weighted avg       0.76      0.75      0.76        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7192
# Adjusted Threshold Test Results:
# Accuracy: 0.7358
# Precision: 0.4375
# Recall: 0.5833
# F1 Score: 0.5000
# ROC AUC Score: 0.6433
# Confusion Matrix:
# [[32  9]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        41
#            1       0.44      0.58      0.50        12
#
#     accuracy                           0.74        53
#    macro avg       0.65      0.68      0.66        53
# weighted avg       0.77      0.74      0.75        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.6836
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.6941
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Adjusting Thresholds for Image Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7592
# Adjusted Threshold Test Results:
# Accuracy: 0.8307
# Precision: 0.9663
# Recall: 0.7107
# F1 Score: 0.8190
# ROC AUC Score: 0.8316
# Confusion Matrix:
# [[402  12]
#  [140 344]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84       414
#            1       0.97      0.71      0.82       484
#
#     accuracy                           0.83       898
#    macro avg       0.85      0.84      0.83       898
# weighted avg       0.86      0.83      0.83       898
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7414
# Adjusted Threshold Test Results:
# Accuracy: 0.8486
# Precision: 0.9943
# Recall: 0.7231
# F1 Score: 0.8373
# ROC AUC Score: 0.8803
# Confusion Matrix:
# [[412   2]
#  [134 350]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86       414
#            1       0.99      0.72      0.84       484
#
#     accuracy                           0.85       898
#    macro avg       0.87      0.86      0.85       898
# weighted avg       0.88      0.85      0.85       898
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7420
# Adjusted Threshold Test Results:
# Accuracy: 0.8474
# Precision: 0.9728
# Recall: 0.7376
# F1 Score: 0.8390
# ROC AUC Score: 0.8797
# Confusion Matrix:
# [[404  10]
#  [127 357]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86       414
#            1       0.97      0.74      0.84       484
#
#     accuracy                           0.85       898
#    macro avg       0.87      0.86      0.85       898
# weighted avg       0.88      0.85      0.85       898
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.9949
# Adjusted Threshold Test Results:
# Accuracy: 0.8508
# Precision: 0.9944
# Recall: 0.7273
# F1 Score: 0.8401
# ROC AUC Score: 0.8666
# Confusion Matrix:
# [[412   2]
#  [132 352]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86       414
#            1       0.99      0.73      0.84       484
#
#     accuracy                           0.85       898
#    macro avg       0.88      0.86      0.85       898
# weighted avg       0.89      0.85      0.85       898
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7561
# Adjusted Threshold Test Results:
# Accuracy: 0.8396
# Precision: 0.9545
# Recall: 0.7376
# F1 Score: 0.8322
# ROC AUC Score: 0.8458
# Confusion Matrix:
# [[397  17]
#  [127 357]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85       414
#            1       0.95      0.74      0.83       484
#
#     accuracy                           0.84       898
#    macro avg       0.86      0.85      0.84       898
# weighted avg       0.86      0.84      0.84       898
#
#
# Adjusting Thresholds for RadiomicsOnly Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4451
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.4466
# Adjusted Threshold Test Results:
# Accuracy: 0.4340
# Precision: 0.2500
# Recall: 0.7500
# F1 Score: 0.3750
# ROC AUC Score: 0.4817
# Confusion Matrix:
# [[14 27]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.34      0.48        41
#            1       0.25      0.75      0.38        12
#
#     accuracy                           0.43        53
#    macro avg       0.54      0.55      0.43        53
# weighted avg       0.69      0.43      0.46        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4878
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5322
# Adjusted Threshold Test Results:
# Accuracy: 0.7925
# Precision: 1.0000
# Recall: 0.0833
# F1 Score: 0.1538
# ROC AUC Score: 0.5417
# Confusion Matrix:
# [[41  0]
#  [11  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.9178
# Adjusted Threshold Test Results:
# Accuracy: 0.4528
# Precision: 0.2424
# Recall: 0.6667
# F1 Score: 0.3556
# ROC AUC Score: 0.5030
# Confusion Matrix:
# [[16 25]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.39      0.52        41
#            1       0.24      0.67      0.36        12
#
#     accuracy                           0.45        53
#    macro avg       0.52      0.53      0.44        53
# weighted avg       0.67      0.45      0.49        53
#
#
# Adjusting Thresholds for ClinicalRadiomics Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5660
# Adjusted Threshold Test Results:
# Accuracy: 0.7170
# Precision: 0.3846
# Recall: 0.4167
# F1 Score: 0.4000
# ROC AUC Score: 0.5711
# Confusion Matrix:
# [[33  8]
#  [ 7  5]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        41
#            1       0.38      0.42      0.40        12
#
#     accuracy                           0.72        53
#    macro avg       0.60      0.61      0.61        53
# weighted avg       0.73      0.72      0.72        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7772
# Adjusted Threshold Test Results:
# Accuracy: 0.3208
# Precision: 0.2273
# Recall: 0.8333
# F1 Score: 0.3571
# ROC AUC Score: 0.4675
# Confusion Matrix:
# [[ 7 34]
#  [ 2 10]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.17      0.28        41
#            1       0.23      0.83      0.36        12
#
#     accuracy                           0.32        53
#    macro avg       0.50      0.50      0.32        53
# weighted avg       0.65      0.32      0.30        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.8736
# Adjusted Threshold Test Results:
# Accuracy: 0.7925
# Precision: 1.0000
# Recall: 0.0833
# F1 Score: 0.1538
# ROC AUC Score: 0.4949
# Confusion Matrix:
# [[41  0]
#  [11  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Adjusting Thresholds for CombinedRadiomics Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 1.0000
# Adjusted Threshold Test Results:
# Accuracy: 0.5056
# Precision: 1.0000
# Recall: 0.0826
# F1 Score: 0.1527
# ROC AUC Score: 0.5413
# Confusion Matrix:
# [[414   0]
#  [444  40]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      1.00      0.65       414
#            1       1.00      0.08      0.15       484
#
#     accuracy                           0.51       898
#    macro avg       0.74      0.54      0.40       898
# weighted avg       0.76      0.51      0.38       898
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.4987
# Adjusted Threshold Test Results:
# Accuracy: 0.8341
# Precision: 0.9515
# Recall: 0.7293
# F1 Score: 0.8257
# ROC AUC Score: 0.9052
# Confusion Matrix:
# [[396  18]
#  [131 353]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84       414
#            1       0.95      0.73      0.83       484
#
#     accuracy                           0.83       898
#    macro avg       0.85      0.84      0.83       898
# weighted avg       0.86      0.83      0.83       898
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.6156
# Adjusted Threshold Test Results:
# Accuracy: 0.8307
# Precision: 0.9611
# Recall: 0.7149
# F1 Score: 0.8199
# ROC AUC Score: 0.8631
# Confusion Matrix:
# [[400  14]
#  [138 346]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84       414
#            1       0.96      0.71      0.82       484
#
#     accuracy                           0.83       898
#    macro avg       0.85      0.84      0.83       898
# weighted avg       0.86      0.83      0.83       898
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7077
# Adjusted Threshold Test Results:
# Accuracy: 0.8408
# Precision: 0.8993
# Recall: 0.7934
# F1 Score: 0.8430
# ROC AUC Score: 0.8777
# Confusion Matrix:
# [[371  43]
#  [100 384]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       414
#            1       0.90      0.79      0.84       484
#
#     accuracy                           0.84       898
#    macro avg       0.84      0.84      0.84       898
# weighted avg       0.85      0.84      0.84       898
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.4610
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[414   0]
#  [484   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63       414
#            1       0.00      0.00      0.00       484
#
#     accuracy                           0.46       898
#    macro avg       0.23      0.50      0.32       898
# weighted avg       0.21      0.46      0.29       898
#
#
# Adjusting Thresholds for CombinedSelected Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.6825
# Adjusted Threshold Test Results:
# Accuracy: 0.8726
# Precision: 0.9316
# Recall: 0.8229
# F1 Score: 0.8739
# ROC AUC Score: 0.9416
# Confusion Matrix:
# [[386  29]
#  [ 85 395]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       415
#            1       0.93      0.82      0.87       480
#
#     accuracy                           0.87       895
#    macro avg       0.88      0.88      0.87       895
# weighted avg       0.88      0.87      0.87       895
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.6717
# Adjusted Threshold Test Results:
# Accuracy: 0.8715
# Precision: 0.9893
# Recall: 0.7688
# F1 Score: 0.8652
# ROC AUC Score: 0.9044
# Confusion Matrix:
# [[411   4]
#  [111 369]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.99      0.88       415
#            1       0.99      0.77      0.87       480
#
#     accuracy                           0.87       895
#    macro avg       0.89      0.88      0.87       895
# weighted avg       0.90      0.87      0.87       895
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8392 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7113
# Adjusted Threshold Test Results:
# Accuracy: 0.8704
# Precision: 0.9789
# Recall: 0.7750
# F1 Score: 0.8651
# ROC AUC Score: 0.9124
# Confusion Matrix:
# [[407   8]
#  [108 372]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.88       415
#            1       0.98      0.78      0.87       480
#
#     accuracy                           0.87       895
#    macro avg       0.88      0.88      0.87       895
# weighted avg       0.89      0.87      0.87       895
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8392 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.9466
# Adjusted Threshold Test Results:
# Accuracy: 0.8760
# Precision: 0.9843
# Recall: 0.7812
# F1 Score: 0.8711
# ROC AUC Score: 0.9198
# Confusion Matrix:
# [[409   6]
#  [105 375]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.88       415
#            1       0.98      0.78      0.87       480
#
#     accuracy                           0.88       895
#    macro avg       0.89      0.88      0.88       895
# weighted avg       0.90      0.88      0.88       895
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7196
# Adjusted Threshold Test Results:
# Accuracy: 0.8827
# Precision: 0.9584
# Recall: 0.8167
# F1 Score: 0.8819
# ROC AUC Score: 0.9458
# Confusion Matrix:
# [[398  17]
#  [ 88 392]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88       415
#            1       0.96      0.82      0.88       480
#
#     accuracy                           0.88       895
#    macro avg       0.89      0.89      0.88       895
# weighted avg       0.89      0.88      0.88       895

# %%
# Get the best hyperparameters for each classifier in each dataset
best_parameters = []

# Iterate through each dataset in nested_cv_results
for dataset, dataset_results in nested_cv_results.items():
    cv_results_all = dataset_results.get('cv_results_all', {})
    
    # Iterate through each classifier in the current dataset
    for classifier, cv_results in cv_results_all.items():
        if cv_results.empty:
            print(f"No cross-validation results found for {classifier} in {dataset}.")
            continue
        
        # Identify the row with the highest mean_test_score
        best_row = cv_results.loc[cv_results['mean_test_score'].idxmax()]
        best_params = best_row['params']
        best_score = best_row['mean_test_score']
        
        # Append the results to the list
        best_parameters.append({
            'Dataset': dataset,
            'Classifier': classifier,
            'Best Score (F1)': best_score,
            'Best Hyperparameters': best_params
        })

# Convert the list to a DataFrame
best_params_df = pd.DataFrame(best_parameters)

# Optional: Expand the 'Best Hyperparameters' column for better readability
# This will create separate columns for each hyperparameter
best_params_expanded = best_params_df.join(
    best_params_df.pop('Best Hyperparameters').apply(pd.Series)
)

# Display the expanded DataFrame
pd.set_option('display.max_colwidth', None)  # Ensure full visibility of hyperparameters
print(best_params_expanded)
# Out:
#               Dataset           Classifier  Best Score (F1)  \
# 0            Combined  Logistic Regression         0.860800
# 1            Combined        Random Forest         0.862927
# 2            Combined              XGBoost         0.860754
# 3            Combined             LightGBM         0.849638
# 4            Combined                  SVM         0.869226
# 5            Clinical  Logistic Regression         0.545455
# 6            Clinical        Random Forest         0.393548
# 7            Clinical              XGBoost         0.515278
# 8            Clinical             LightGBM         0.550833
# 9            Clinical                  SVM         0.537154
# 10              Image  Logistic Regression         0.866936
# 11              Image        Random Forest         0.860573
# 12              Image              XGBoost         0.849569
# 13              Image             LightGBM         0.852669
# 14              Image                  SVM         0.883755
# 15      RadiomicsOnly  Logistic Regression         0.457210
# 16      RadiomicsOnly        Random Forest         0.318750
# 17      RadiomicsOnly              XGBoost         0.441021
# 18      RadiomicsOnly             LightGBM         0.433654
# 19      RadiomicsOnly                  SVM         0.471005
# 20  ClinicalRadiomics  Logistic Regression         0.443452
# 21  ClinicalRadiomics        Random Forest         0.312500
# 22  ClinicalRadiomics              XGBoost         0.425914
# 23  ClinicalRadiomics             LightGBM         0.417087
# 24  ClinicalRadiomics                  SVM         0.448637
# 25  CombinedRadiomics  Logistic Regression         0.882878
# 26  CombinedRadiomics        Random Forest         0.831487
# 27  CombinedRadiomics              XGBoost         0.759689
# 28  CombinedRadiomics             LightGBM         0.781974
# 29  CombinedRadiomics                  SVM         0.898924
# 30   CombinedSelected  Logistic Regression         0.872550
# 31   CombinedSelected        Random Forest         0.850388
# 32   CombinedSelected              XGBoost         0.846547
# 33   CombinedSelected             LightGBM         0.848720
# 34   CombinedSelected                  SVM         0.870521
#
#    classifier__penalty  classifier__C  classifier__n_estimators  \
# 0                   l2     166.810054                       NaN
# 1                  NaN            NaN                     150.0
# 2                  NaN            NaN                     100.0
# 3                  NaN            NaN                     150.0
# 4                  NaN       0.100000                       NaN
# 5                   l2    1291.549665                       NaN
# 6                  NaN            NaN                     200.0
# 7                  NaN            NaN                     100.0
# 8                  NaN            NaN                     150.0
# 9                  NaN       0.100000                       NaN
# 10                  l1       0.359381                       NaN
# 11                 NaN            NaN                     200.0
# 12                 NaN            NaN                     100.0
# 13                 NaN            NaN                     200.0
# 14                 NaN       0.100000                       NaN
# 15                  l2     166.810054                       NaN
# 16                 NaN            NaN                     150.0
# 17                 NaN            NaN                      50.0
# 18                 NaN            NaN                     150.0
# 19                 NaN       1.000000                       NaN
# 20                  l2    1291.549665                       NaN
# 21                 NaN            NaN                      50.0
# 22                 NaN            NaN                      50.0
# 23                 NaN            NaN                     150.0
# 24                 NaN       1.000000                       NaN
# 25                  l1       0.359381                       NaN
# 26                 NaN            NaN                     200.0
# 27                 NaN            NaN                      50.0
# 28                 NaN            NaN                     150.0
# 29                 NaN       0.100000                       NaN
# 30                  l2    1291.549665                       NaN
# 31                 NaN            NaN                     200.0
# 32                 NaN            NaN                     100.0
# 33                 NaN            NaN                     200.0
# 34                 NaN       1.000000                       NaN
#
#     classifier__min_samples_split  classifier__min_samples_leaf  \
# 0                             NaN                           NaN
# 1                             2.0                           2.0
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# 5                             NaN                           NaN
# 6                             2.0                           2.0
# 7                             NaN                           NaN
# 8                             NaN                           NaN
# 9                             NaN                           NaN
# 10                            NaN                           NaN
# 11                            2.0                           2.0
# 12                            NaN                           NaN
# 13                            NaN                           NaN
# 14                            NaN                           NaN
# 15                            NaN                           NaN
# 16                            2.0                           2.0
# 17                            NaN                           NaN
# 18                            NaN                           NaN
# 19                            NaN                           NaN
# 20                            NaN                           NaN
# 21                            2.0                           2.0
# 22                            NaN                           NaN
# 23                            NaN                           NaN
# 24                            NaN                           NaN
# 25                            NaN                           NaN
# 26                            2.0                           2.0
# 27                            NaN                           NaN
# 28                            NaN                           NaN
# 29                            NaN                           NaN
# 30                            NaN                           NaN
# 31                            2.0                           2.0
# 32                            NaN                           NaN
# 33                            NaN                           NaN
# 34                            NaN                           NaN
#
#     classifier__max_depth  classifier__learning_rate  classifier__verbose  \
# 0                     NaN                        NaN                  NaN
# 1                    10.0                        NaN                  NaN
# 2                     3.0                       0.10                  NaN
# 3                     NaN                       0.10                 -1.0
# 4                     NaN                        NaN                  NaN
# 5                     NaN                        NaN                  NaN
# 6                    10.0                        NaN                  NaN
# 7                    10.0                       0.10                  NaN
# 8                     NaN                       0.10                 -1.0
# 9                     NaN                        NaN                  NaN
# 10                    NaN                        NaN                  NaN
# 11                   10.0                        NaN                  NaN
# 12                    3.0                       0.10                  NaN
# 13                    NaN                       0.10                 -1.0
# 14                    NaN                        NaN                  NaN
# 15                    NaN                        NaN                  NaN
# 16                   10.0                        NaN                  NaN
# 17                    7.0                       0.01                  NaN
# 18                    NaN                       0.01                 -1.0
# 19                    NaN                        NaN                  NaN
# 20                    NaN                        NaN                  NaN
# 21                   20.0                        NaN                  NaN
# 22                    7.0                       0.01                  NaN
# 23                    NaN                       0.01                 -1.0
# 24                    NaN                        NaN                  NaN
# 25                    NaN                        NaN                  NaN
# 26                   20.0                        NaN                  NaN
# 27                    7.0                       0.01                  NaN
# 28                    NaN                       0.01                 -1.0
# 29                    NaN                        NaN                  NaN
# 30                    NaN                        NaN                  NaN
# 31                   20.0                        NaN                  NaN
# 32                    3.0                       0.10                  NaN
# 33                    NaN                       0.10                 -1.0
# 34                    NaN                        NaN                  NaN
#
#     classifier__num_leaves classifier__kernel
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                     63.0                NaN
# 4                      NaN                rbf
# 5                      NaN                NaN
# 6                      NaN                NaN
# 7                      NaN                NaN
# 8                     63.0                NaN
# 9                      NaN             linear
# 10                     NaN                NaN
# 11                     NaN                NaN
# 12                     NaN                NaN
# 13                    31.0                NaN
# 14                     NaN             linear
# 15                     NaN                NaN
# 16                     NaN                NaN
# 17                     NaN                NaN
# 18                    63.0                NaN
# 19                     NaN             linear
# 20                     NaN                NaN
# 21                     NaN                NaN
# 22                     NaN                NaN
# 23                    63.0                NaN
# 24                     NaN             linear
# 25                     NaN                NaN
# 26                     NaN                NaN
# 27                     NaN                NaN
# 28                    63.0                NaN
# 29                     NaN             linear
# 30                     NaN                NaN
# 31                     NaN                NaN
# 32                     NaN                NaN
# 33                    31.0                NaN
# 34                     NaN             linear

# %%
#Per-Patient Aggregated Evaluation with Youden's J Thresholds

import numpy as np
import pandas as pd
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report, roc_curve
)
from sklearn.base import clone

# Helper function to find optimal threshold using Youden's J statistic
def find_optimal_threshold(y_true, y_scores):
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    J = tpr - fpr
    ix = np.argmax(J)
    optimal_threshold = thresholds[ix]
    return optimal_threshold

# Initialize a dictionary to store per-patient test results
test_results_per_patient = {}

for dataset_name in data_splits.keys():
    print(f"\nAggregating Predictions for {dataset_name} Dataset")
    
    # Initialize nested dictionary for classifiers
    test_results_per_patient[dataset_name] = {}
    
    # Retrieve data splits
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test_full = data['y_test']
    patient_ids_test = data['patient_ids_test']
    
    # Create a DataFrame for test data
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test_full.values
    test_df['patient_id'] = patient_ids_test.values
    
    # Get per-patient true labels (assuming all slices of a patient have the same label)
    y_true_per_patient = test_df.groupby('patient_id')['y_true'].first()
    
    for classifier_name in classifiers.keys():
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve nested CV results
        cv_results_all = nested_cv_results[dataset_name]['cv_results_all'][classifier_name]
        
        # Find the best hyperparameters (highest mean_test_score)
        best_row = cv_results_all.loc[cv_results_all['mean_test_score'].idxmax()]
        best_params = best_row['params']
        
        # Extract classifier hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Clone the base classifier
        base_classifier = classifiers[classifier_name]
        classifier = clone(base_classifier)
        
        # Set best hyperparameters
        classifier.set_params(**classifier_params)
        
         # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)

        # Handle Logistic Regression solver and penalty compatibility
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                classifier.set_params(dual=True)
            else:
                classifier.set_params(dual=False)
        
        # Define the pipeline
        #pipeline = ImbPipeline(steps=[
        #    ('smote', SMOTE(sampling_strategy='minority', random_state=42)),
        #    ('scaler', MinMaxScaler()),
        #    ('classifier', classifier)
        #])

        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Predict probabilities on the test set
        if hasattr(pipeline.named_steps['classifier'], "predict_proba"):
            y_proba = pipeline.predict_proba(X_test_full)[:, 1]
        else:
            print(f"Classifier '{classifier_name}' does not support probability estimates. Skipping.")
            continue
        
        # Add predicted probabilities to test_df
        test_df[f'{classifier_name}_proba'] = y_proba
        
        # Compute optimal slice_threshold using Youden's J
        slice_threshold = find_optimal_threshold(y_test_full, y_proba)
        print(f"Optimal Slice Threshold (Youden's J): {slice_threshold:.4f}")
        
        # Assign per-slice predictions based on slice_threshold
        test_df[f'{classifier_name}_pred_slice'] = (y_proba >= slice_threshold).astype(int)
        
        # Aggregate predictions per patient based on patient_threshold
        # Calculate the proportion of slices predicted as 1 for each patient
        slice_proportions = test_df.groupby('patient_id')[f'{classifier_name}_pred_slice'].mean()
        
        # Compute patient_threshold using Youden's J on slice proportions
        patient_threshold = find_optimal_threshold(y_true_per_patient, slice_proportions)
        print(f"Optimal Patient Threshold (Youden's J): {patient_threshold:.4f}")
        
        # Assign patient-level predictions based on patient_threshold
        y_pred_per_patient = (slice_proportions >= patient_threshold).astype(int)
        
        # Align the true labels
        y_true = y_true_per_patient
        
        # Compute performance metrics
        accuracy = accuracy_score(y_true, y_pred_per_patient)
        precision = precision_score(y_true, y_pred_per_patient, zero_division=0)
        recall = recall_score(y_true, y_pred_per_patient)
        f1 = f1_score(y_true, y_pred_per_patient)
        try:
            roc_auc = roc_auc_score(y_true, slice_proportions)  # Using slice proportions for ROC AUC
        except ValueError:
            roc_auc = None  # Handle cases where ROC AUC is not defined
        
        conf_matrix = confusion_matrix(y_true, y_pred_per_patient)
        class_report = classification_report(y_true, y_pred_per_patient, zero_division=0)
        
        # Store the results
        test_results_per_patient[dataset_name][classifier_name + ' (Patient Aggregated)'] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"\nAggregated Test Results for {classifier_name} on {dataset_name} Dataset:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        if roc_auc is not None:
            print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)
# Out:
# Aggregating Predictions for Combined Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.8421
# Optimal Patient Threshold (Youden's J): 0.5750
#
# Aggregated Test Results for Logistic Regression on Combined Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5906
# Optimal Patient Threshold (Youden's J): 0.6750
#
# Aggregated Test Results for Random Forest on Combined Dataset:
# Accuracy: 0.9623
# Precision: 0.8571
# Recall: 1.0000
# F1 Score: 0.9231
# ROC AUC Score: 0.9512
# Confusion Matrix:
# [[39  2]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        41
#            1       0.86      1.00      0.92        12
#
#     accuracy                           0.96        53
#    macro avg       0.93      0.98      0.95        53
# weighted avg       0.97      0.96      0.96        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.8924
# Optimal Patient Threshold (Youden's J): 0.5750
#
# Aggregated Test Results for XGBoost on Combined Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.9947
# Optimal Patient Threshold (Youden's J): 0.6000
#
# Aggregated Test Results for LightGBM on Combined Dataset:
# Accuracy: 0.9811
# Precision: 0.9231
# Recall: 1.0000
# F1 Score: 0.9600
# ROC AUC Score: 0.9756
# Confusion Matrix:
# [[40  1]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.98        53
#    macro avg       0.96      0.99      0.97        53
# weighted avg       0.98      0.98      0.98        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.8777
# Optimal Patient Threshold (Youden's J): 0.6000
#
# Aggregated Test Results for SVM on Combined Dataset:
# Accuracy: 0.9811
# Precision: 0.9231
# Recall: 1.0000
# F1 Score: 0.9600
# ROC AUC Score: 0.9756
# Confusion Matrix:
# [[40  1]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.98        53
#    macro avg       0.96      0.99      0.97        53
# weighted avg       0.98      0.98      0.98        53
#
#
# Aggregating Predictions for Clinical Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6439
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Logistic Regression on Clinical Dataset:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.7358
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3328
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Random Forest on Clinical Dataset:
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.7114
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7301
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for XGBoost on Clinical Dataset:
# Accuracy: 0.7547
# Precision: 0.4615
# Recall: 0.5000
# F1 Score: 0.4800
# ROC AUC Score: 0.6646
# Confusion Matrix:
# [[34  7]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        41
#            1       0.46      0.50      0.48        12
#
#     accuracy                           0.75        53
#    macro avg       0.66      0.66      0.66        53
# weighted avg       0.76      0.75      0.76        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7192
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on Clinical Dataset:
# Accuracy: 0.7358
# Precision: 0.4375
# Recall: 0.5833
# F1 Score: 0.5000
# ROC AUC Score: 0.6819
# Confusion Matrix:
# [[32  9]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        41
#            1       0.44      0.58      0.50        12
#
#     accuracy                           0.74        53
#    macro avg       0.65      0.68      0.66        53
# weighted avg       0.77      0.74      0.75        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6836
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for SVM on Clinical Dataset:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.7358
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Aggregating Predictions for Image Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7592
# Optimal Patient Threshold (Youden's J): 0.6000
#
# Aggregated Test Results for Logistic Regression on Image Dataset:
# Accuracy: 0.9811
# Precision: 0.9231
# Recall: 1.0000
# F1 Score: 0.9600
# ROC AUC Score: 0.9756
# Confusion Matrix:
# [[40  1]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.98        53
#    macro avg       0.96      0.99      0.97        53
# weighted avg       0.98      0.98      0.98        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7414
# Optimal Patient Threshold (Youden's J): 0.6500
#
# Aggregated Test Results for Random Forest on Image Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7420
# Optimal Patient Threshold (Youden's J): 0.7000
#
# Aggregated Test Results for XGBoost on Image Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.9949
# Optimal Patient Threshold (Youden's J): 0.6750
#
# Aggregated Test Results for LightGBM on Image Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7561
# Optimal Patient Threshold (Youden's J): 0.6750
#
# Aggregated Test Results for SVM on Image Dataset:
# Accuracy: 0.9811
# Precision: 0.9231
# Recall: 1.0000
# F1 Score: 0.9600
# ROC AUC Score: 0.9756
# Confusion Matrix:
# [[40  1]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.98        53
#    macro avg       0.96      0.99      0.97        53
# weighted avg       0.98      0.98      0.98        53
#
#
# Aggregating Predictions for RadiomicsOnly Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for Logistic Regression on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.4466
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Random Forest on RadiomicsOnly Dataset:
# Accuracy: 0.4340
# Precision: 0.2500
# Recall: 0.7500
# F1 Score: 0.3750
# ROC AUC Score: 0.5457
# Confusion Matrix:
# [[14 27]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.34      0.48        41
#            1       0.25      0.75      0.38        12
#
#     accuracy                           0.43        53
#    macro avg       0.54      0.55      0.43        53
# weighted avg       0.69      0.43      0.46        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for XGBoost on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5322
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on RadiomicsOnly Dataset:
# Accuracy: 0.7925
# Precision: 1.0000
# Recall: 0.0833
# F1 Score: 0.1538
# ROC AUC Score: 0.5417
# Confusion Matrix:
# [[41  0]
#  [11  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.9178
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for SVM on RadiomicsOnly Dataset:
# Accuracy: 0.4528
# Precision: 0.2424
# Recall: 0.6667
# F1 Score: 0.3556
# ROC AUC Score: 0.5285
# Confusion Matrix:
# [[16 25]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.39      0.52        41
#            1       0.24      0.67      0.36        12
#
#     accuracy                           0.45        53
#    macro avg       0.52      0.53      0.44        53
# weighted avg       0.67      0.45      0.49        53
#
#
# Aggregating Predictions for ClinicalRadiomics Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for Logistic Regression on ClinicalRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5660
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Random Forest on ClinicalRadiomics Dataset:
# Accuracy: 0.7170
# Precision: 0.3846
# Recall: 0.4167
# F1 Score: 0.4000
# ROC AUC Score: 0.6108
# Confusion Matrix:
# [[33  8]
#  [ 7  5]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        41
#            1       0.38      0.42      0.40        12
#
#     accuracy                           0.72        53
#    macro avg       0.60      0.61      0.61        53
# weighted avg       0.73      0.72      0.72        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7772
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for XGBoost on ClinicalRadiomics Dataset:
# Accuracy: 0.3208
# Precision: 0.2273
# Recall: 0.8333
# F1 Score: 0.3571
# ROC AUC Score: 0.5020
# Confusion Matrix:
# [[ 7 34]
#  [ 2 10]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.17      0.28        41
#            1       0.23      0.83      0.36        12
#
#     accuracy                           0.32        53
#    macro avg       0.50      0.50      0.32        53
# weighted avg       0.65      0.32      0.30        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.8736
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on ClinicalRadiomics Dataset:
# Accuracy: 0.7925
# Precision: 1.0000
# Recall: 0.0833
# F1 Score: 0.1538
# ROC AUC Score: 0.5417
# Confusion Matrix:
# [[41  0]
#  [11  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for SVM on ClinicalRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Aggregating Predictions for CombinedRadiomics Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 1.0000
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Logistic Regression on CombinedRadiomics Dataset:
# Accuracy: 0.7925
# Precision: 1.0000
# Recall: 0.0833
# F1 Score: 0.1538
# ROC AUC Score: 0.5417
# Confusion Matrix:
# [[41  0]
#  [11  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.4987
# Optimal Patient Threshold (Youden's J): 0.6250
#
# Aggregated Test Results for Random Forest on CombinedRadiomics Dataset:
# Accuracy: 0.9623
# Precision: 0.8571
# Recall: 1.0000
# F1 Score: 0.9231
# ROC AUC Score: 0.9685
# Confusion Matrix:
# [[39  2]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        41
#            1       0.86      1.00      0.92        12
#
#     accuracy                           0.96        53
#    macro avg       0.93      0.98      0.95        53
# weighted avg       0.97      0.96      0.96        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6156
# Optimal Patient Threshold (Youden's J): 0.5227
#
# Aggregated Test Results for XGBoost on CombinedRadiomics Dataset:
# Accuracy: 0.9811
# Precision: 0.9231
# Recall: 1.0000
# F1 Score: 0.9600
# ROC AUC Score: 0.9797
# Confusion Matrix:
# [[40  1]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.98        53
#    macro avg       0.96      0.99      0.97        53
# weighted avg       0.98      0.98      0.98        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7077
# Optimal Patient Threshold (Youden's J): 0.6500
#
# Aggregated Test Results for LightGBM on CombinedRadiomics Dataset:
# Accuracy: 0.9434
# Precision: 0.8000
# Recall: 1.0000
# F1 Score: 0.8889
# ROC AUC Score: 0.9451
# Confusion Matrix:
# [[38  3]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        41
#            1       0.80      1.00      0.89        12
#
#     accuracy                           0.94        53
#    macro avg       0.90      0.96      0.93        53
# weighted avg       0.95      0.94      0.95        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for SVM on CombinedRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Aggregating Predictions for CombinedSelected Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6825
# Optimal Patient Threshold (Youden's J): 0.6750
#
# Aggregated Test Results for Logistic Regression on CombinedSelected Dataset:
# Accuracy: 0.9811
# Precision: 0.9231
# Recall: 1.0000
# F1 Score: 0.9600
# ROC AUC Score: 0.9776
# Confusion Matrix:
# [[40  1]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.98        53
#    macro avg       0.96      0.99      0.97        53
# weighted avg       0.98      0.98      0.98        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6717
# Optimal Patient Threshold (Youden's J): 0.7250
#
# Aggregated Test Results for Random Forest on CombinedSelected Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8392 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7113
# Optimal Patient Threshold (Youden's J): 0.6750
#
# Aggregated Test Results for XGBoost on CombinedSelected Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8392 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.9466
# Optimal Patient Threshold (Youden's J): 0.6000
#
# Aggregated Test Results for LightGBM on CombinedSelected Dataset:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# ROC AUC Score: 1.0000
# Confusion Matrix:
# [[41  0]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7196
# Optimal Patient Threshold (Youden's J): 0.6750
#
# Aggregated Test Results for SVM on CombinedSelected Dataset:
# Accuracy: 0.9811
# Precision: 0.9231
# Recall: 1.0000
# F1 Score: 0.9600
# ROC AUC Score: 0.9776
# Confusion Matrix:
# [[40  1]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        41
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.98        53
#    macro avg       0.96      0.99      0.97        53
# weighted avg       0.98      0.98      0.98        53

# %%
# Visualize Per-Patient Performance Metrics

import matplotlib.pyplot as plt
import seaborn as sns

# Function to plot metrics for each classifier in a dataset
def plot_metrics(dataset_name, classifiers_results):
    metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
    classifier_names = list(classifiers_results.keys())
    metric_values = {metric: [classifiers_results[clf][metric] for clf in classifier_names] for metric in metrics}
    
    df_metrics = pd.DataFrame(metric_values, index=classifier_names)
    df_metrics = df_metrics.reset_index().rename(columns={'index': 'Classifier'})
    
    df_melted = df_metrics.melt(id_vars='Classifier', var_name='Metric', value_name='Value')
    
    plt.figure(figsize=(14, 7))
    sns.barplot(x='Classifier', y='Value', hue='Metric', data=df_melted)
    plt.title(f'Per-Patient Aggregated Performance Metrics for {dataset_name} Dataset')
    plt.xticks(rotation=45)
    plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# Plot metrics for each dataset
for dataset_name, classifiers_results in test_results_per_patient.items():
    plot_metrics(dataset_name, classifiers_results)

# %%
# Bootstrap Confidence Intervals for Test Metrics

import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Number of bootstrap iterations
n_bootstraps = 1000
rng = np.random.RandomState(seed=42)  # For reproducibility

# Initialize a dictionary to store bootstrap results
bootstrap_results = {}

for dataset_name in data_splits.keys():
    print(f"\nBootstrapping Test Metrics for '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_test_full = data['X_test_full']
    y_test = data['y_test'].reset_index(drop=True)
    
    # Initialize dictionary for classifiers
    bootstrap_results[dataset_name] = {}
    
    for classifier_name in classifiers.keys():
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve the best hyperparameters from nested_cv_results
        nested_results = nested_cv_results[dataset_name]
        cv_results_all = nested_results['cv_results_all']
        cv_results = cv_results_all[classifier_name]
        
        # Find the hyperparameters with the best mean_test_score
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier with default parameters
        default_classifier = classifiers[classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)
        
        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)

        # Handle compatibility between solver and penalty for Logistic Regression
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        
        # Retrieve training data
        X_train_full = data['X_train_full']
        y_train_full = data['y_train_full']
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Initialize lists to store bootstrap metrics
        bootstrap_accuracies = []
        bootstrap_precisions = []
        bootstrap_recalls = []
        bootstrap_f1s = []
        bootstrap_roc_aucs = []
        
        # Convert y_test to numpy array
        y_test_array = y_test.values
        
        # Compute predicted probabilities once (since the model is fixed)
        if hasattr(pipeline.named_steps['classifier'], "predict_proba"):
            y_proba_full = pipeline.predict_proba(X_test_full)[:, 1]
        else:
            # For classifiers that do not have predict_proba, skip ROC AUC
            y_proba_full = None
        
        # Perform bootstrap resampling
        for i in range(n_bootstraps):
            # Sample indices with replacement
            indices = rng.choice(len(X_test_full), size=len(X_test_full), replace=True)
            X_test_bootstrap = X_test_full.iloc[indices]
            y_test_bootstrap = y_test_array[indices]
            
            # Make predictions on the bootstrap sample
            y_pred_bootstrap = pipeline.predict(X_test_bootstrap)
            
            # Compute metrics
            accuracy = accuracy_score(y_test_bootstrap, y_pred_bootstrap)
            precision = precision_score(y_test_bootstrap, y_pred_bootstrap, zero_division=0)
            recall = recall_score(y_test_bootstrap, y_pred_bootstrap)
            f1 = f1_score(y_test_bootstrap, y_pred_bootstrap)
            if y_proba_full is not None:
                y_proba_bootstrap = y_proba_full[indices]
                roc_auc = roc_auc_score(y_test_bootstrap, y_proba_bootstrap)
            else:
                roc_auc = np.nan  # Not available for this classifier
                
            # Append metrics
            bootstrap_accuracies.append(accuracy)
            bootstrap_precisions.append(precision)
            bootstrap_recalls.append(recall)
            bootstrap_f1s.append(f1)
            bootstrap_roc_aucs.append(roc_auc)
        
        # Compute confidence intervals (e.g., 95% CI)
        def compute_confidence_interval(metric_values):
            sorted_values = np.sort(metric_values)
            lower = np.percentile(sorted_values, 2.5)
            upper = np.percentile(sorted_values, 97.5)
            mean = np.mean(metric_values)
            return mean, lower, upper
        
        accuracy_mean, accuracy_lower, accuracy_upper = compute_confidence_interval(bootstrap_accuracies)
        precision_mean, precision_lower, precision_upper = compute_confidence_interval(bootstrap_precisions)
        recall_mean, recall_lower, recall_upper = compute_confidence_interval(bootstrap_recalls)
        f1_mean, f1_lower, f1_upper = compute_confidence_interval(bootstrap_f1s)
        roc_auc_mean, roc_auc_lower, roc_auc_upper = compute_confidence_interval(bootstrap_roc_aucs)
        
        # Store the bootstrap results
        bootstrap_results[dataset_name][classifier_name] = {
            'accuracy': (accuracy_mean, accuracy_lower, accuracy_upper),
            'precision': (precision_mean, precision_lower, precision_upper),
            'recall': (recall_mean, recall_lower, recall_upper),
            'f1': (f1_mean, f1_lower, f1_upper),
            'roc_auc': (roc_auc_mean, roc_auc_lower, roc_auc_upper),
        }
        
        # Print the results
        print(f"{classifier_name} Bootstrap Confidence Intervals:")
        print(f"Accuracy: {accuracy_mean:.4f} (95% CI: {accuracy_lower:.4f} - {accuracy_upper:.4f})")
        print(f"Precision: {precision_mean:.4f} (95% CI: {precision_lower:.4f} - {precision_upper:.4f})")
        print(f"Recall: {recall_mean:.4f} (95% CI: {recall_lower:.4f} - {recall_upper:.4f})")
        print(f"F1 Score: {f1_mean:.4f} (95% CI: {f1_lower:.4f} - {f1_upper:.4f})")
        if not np.isnan(roc_auc_mean):
            print(f"ROC AUC: {roc_auc_mean:.4f} (95% CI: {roc_auc_lower:.4f} - {roc_auc_upper:.4f})")
        else:
            print("ROC AUC: Not available for this classifier")
# Out:
# Bootstrapping Test Metrics for 'Combined' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.8034 (95% CI: 0.7773 - 0.8296)
# Precision: 0.8457 (95% CI: 0.8109 - 0.8786)
# Recall: 0.7770 (95% CI: 0.7378 - 0.8154)
# F1 Score: 0.8097 (95% CI: 0.7811 - 0.8370)
# ROC AUC: 0.9078 (95% CI: 0.8886 - 0.9260)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.8258 (95% CI: 0.8018 - 0.8508)
# Precision: 0.8914 (95% CI: 0.8606 - 0.9198)
# Recall: 0.7714 (95% CI: 0.7327 - 0.8095)
# F1 Score: 0.8269 (95% CI: 0.8000 - 0.8530)
# ROC AUC: 0.9069 (95% CI: 0.8862 - 0.9257)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.8252 (95% CI: 0.8018 - 0.8497)
# Precision: 0.8797 (95% CI: 0.8491 - 0.9079)
# Recall: 0.7831 (95% CI: 0.7465 - 0.8180)
# F1 Score: 0.8285 (95% CI: 0.8023 - 0.8542)
# ROC AUC: 0.9051 (95% CI: 0.8863 - 0.9242)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.8008 (95% CI: 0.7739 - 0.8274)
# Precision: 0.8278 (95% CI: 0.7925 - 0.8636)
# Recall: 0.7958 (95% CI: 0.7593 - 0.8323)
# F1 Score: 0.8113 (95% CI: 0.7823 - 0.8388)
# ROC AUC: 0.8793 (95% CI: 0.8552 - 0.9024)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.8192 (95% CI: 0.7929 - 0.8441)
# Precision: 0.9008 (95% CI: 0.8714 - 0.9278)
# Recall: 0.7468 (95% CI: 0.7049 - 0.7853)
# F1 Score: 0.8165 (95% CI: 0.7862 - 0.8436)
# ROC AUC: 0.8908 (95% CI: 0.8679 - 0.9119)
#
# Bootstrapping Test Metrics for 'Clinical' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.7739 (95% CI: 0.6604 - 0.8868)
# Precision: 0.5003 (95% CI: 0.2308 - 0.7500)
# Recall: 0.6668 (95% CI: 0.3750 - 0.9231)
# F1 Score: 0.5625 (95% CI: 0.3075 - 0.7692)
# ROC AUC: 0.7100 (95% CI: 0.5155 - 0.8805)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7200 (95% CI: 0.5849 - 0.8302)
# Precision: 0.3638 (95% CI: 0.1000 - 0.6667)
# Recall: 0.3321 (95% CI: 0.0769 - 0.6250)
# F1 Score: 0.3371 (95% CI: 0.1000 - 0.5718)
# ROC AUC: 0.6445 (95% CI: 0.4477 - 0.8255)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.6026 (95% CI: 0.4717 - 0.7358)
# Precision: 0.3009 (95% CI: 0.1111 - 0.5000)
# Recall: 0.5811 (95% CI: 0.2857 - 0.8571)
# F1 Score: 0.3896 (95% CI: 0.1621 - 0.5790)
# ROC AUC: 0.6062 (95% CI: 0.4055 - 0.7816)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.6073 (95% CI: 0.4717 - 0.7358)
# Precision: 0.3048 (95% CI: 0.1249 - 0.5000)
# Recall: 0.5866 (95% CI: 0.2857 - 0.8750)
# F1 Score: 0.3942 (95% CI: 0.1818 - 0.6047)
# ROC AUC: 0.6455 (95% CI: 0.4680 - 0.8153)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.5915 (95% CI: 0.4528 - 0.7170)
# Precision: 0.3140 (95% CI: 0.1429 - 0.5000)
# Recall: 0.6729 (95% CI: 0.3750 - 1.0000)
# F1 Score: 0.4214 (95% CI: 0.2162 - 0.6061)
# ROC AUC: 0.7028 (95% CI: 0.5035 - 0.8884)
#
# Bootstrapping Test Metrics for 'Image' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.8048 (95% CI: 0.7795 - 0.8296)
# Precision: 0.8733 (95% CI: 0.8393 - 0.9048)
# Recall: 0.7455 (95% CI: 0.7066 - 0.7826)
# F1 Score: 0.8042 (95% CI: 0.7756 - 0.8295)
# ROC AUC: 0.8315 (95% CI: 0.8028 - 0.8562)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.8336 (95% CI: 0.8073 - 0.8586)
# Precision: 0.9238 (95% CI: 0.8963 - 0.9495)
# Recall: 0.7537 (95% CI: 0.7127 - 0.7939)
# F1 Score: 0.8299 (95% CI: 0.8014 - 0.8581)
# ROC AUC: 0.8802 (95% CI: 0.8566 - 0.9041)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 0.8415 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.8380 (95% CI: 0.8129 - 0.8619)
# Precision: 0.9174 (95% CI: 0.8866 - 0.9435)
# Recall: 0.7678 (95% CI: 0.7328 - 0.8030)
# F1 Score: 0.8359 (95% CI: 0.8082 - 0.8608)
# ROC AUC: 0.8794 (95% CI: 0.8558 - 0.9007)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 0.8415 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.8186 (95% CI: 0.7929 - 0.8430)
# Precision: 0.8794 (95% CI: 0.8488 - 0.9102)
# Recall: 0.7686 (95% CI: 0.7308 - 0.8062)
# F1 Score: 0.8201 (95% CI: 0.7926 - 0.8463)
# ROC AUC: 0.8669 (95% CI: 0.8414 - 0.8892)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.8354 (95% CI: 0.8107 - 0.8586)
# Precision: 0.9441 (95% CI: 0.9204 - 0.9654)
# Recall: 0.7379 (95% CI: 0.6996 - 0.7736)
# F1 Score: 0.8282 (95% CI: 0.7990 - 0.8533)
# ROC AUC: 0.8460 (95% CI: 0.8177 - 0.8725)
#
# Bootstrapping Test Metrics for 'RadiomicsOnly' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.4542 (95% CI: 0.3208 - 0.5849)
# Precision: 0.1606 (95% CI: 0.0357 - 0.3182)
# Recall: 0.3354 (95% CI: 0.0769 - 0.6000)
# F1 Score: 0.2124 (95% CI: 0.0541 - 0.3784)
# ROC AUC: 0.4472 (95% CI: 0.3000 - 0.5990)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7394 (95% CI: 0.6226 - 0.8491)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.4814 (95% CI: 0.2709 - 0.6826)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.2257 (95% CI: 0.1132 - 0.3396)
# Precision: 0.2257 (95% CI: 0.1132 - 0.3396)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3646 (95% CI: 0.2034 - 0.5070)
# ROC AUC: 0.4871 (95% CI: 0.4583 - 0.5000)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.2281 (95% CI: 0.1132 - 0.3396)
# Precision: 0.2281 (95% CI: 0.1132 - 0.3396)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3679 (95% CI: 0.2034 - 0.5070)
# ROC AUC: 0.5407 (95% CI: 0.5000 - 0.6500)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.4550 (95% CI: 0.3208 - 0.5849)
# Precision: 0.2454 (95% CI: 0.1000 - 0.4062)
# Recall: 0.6700 (95% CI: 0.3750 - 0.9232)
# F1 Score: 0.3539 (95% CI: 0.1579 - 0.5417)
# ROC AUC: 0.5043 (95% CI: 0.3516 - 0.6604)
#
# Bootstrapping Test Metrics for 'ClinicalRadiomics' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.2294 (95% CI: 0.1132 - 0.3396)
# Precision: 0.2294 (95% CI: 0.1132 - 0.3396)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3697 (95% CI: 0.2034 - 0.5070)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.2445 (95% CI: 0.1321 - 0.3774)
# Precision: 0.2295 (95% CI: 0.1154 - 0.3585)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3698 (95% CI: 0.2069 - 0.5278)
# ROC AUC: 0.5693 (95% CI: 0.3883 - 0.7425)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.2235 (95% CI: 0.1132 - 0.3396)
# Precision: 0.2235 (95% CI: 0.1132 - 0.3396)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3616 (95% CI: 0.2034 - 0.5070)
# ROC AUC: 0.4677 (95% CI: 0.3279 - 0.5922)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.2261 (95% CI: 0.1132 - 0.3401)
# Precision: 0.2261 (95% CI: 0.1132 - 0.3401)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3650 (95% CI: 0.2034 - 0.5076)
# ROC AUC: 0.4918 (95% CI: 0.3148 - 0.6945)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.2296 (95% CI: 0.1321 - 0.3396)
# Precision: 0.2296 (95% CI: 0.1321 - 0.3396)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3701 (95% CI: 0.2333 - 0.5070)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Bootstrapping Test Metrics for 'CombinedRadiomics' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.5057 (95% CI: 0.4744 - 0.5368)
# Precision: 1.0000 (95% CI: 1.0000 - 1.0000)
# Recall: 0.0828 (95% CI: 0.0587 - 0.1059)
# F1 Score: 0.1527 (95% CI: 0.1109 - 0.1915)
# ROC AUC: 0.5414 (95% CI: 0.5294 - 0.5530)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 136
#     134 if y_proba_full is not None:
#     135     y_proba_bootstrap = y_proba_full[indices]
# --> 136     roc_auc = roc_auc_score(y_test_bootstrap, y_proba_bootstrap)
#     137 else:
#     138     roc_auc = np.nan  # Not available for this classifier
#
# File ~/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:639, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     637 elif y_type == "binary":
#     638     labels = np.unique(y_true)
# --> 639     y_true = label_binarize(y_true, classes=labels)[:, 0]
#     640     return _average_binary_score(
#     641         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     642         y_true,
#    (...)
#     645         sample_weight=sample_weight,
#     646     )
#     647 else:  # multilabel-indicator
#
# File ~/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:556, in label_binarize(y, classes, neg_label, pos_label, sparse_output)
#     553 y = column_or_1d(y)
#     555 # pick out the known labels from y
# --> 556 y_in_classes = np.isin(y, classes)
#     557 y_seen = y[y_in_classes]
#     558 indices = np.searchsorted(sorted_class, y_seen)
#
# File ~/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:1105, in isin(element, test_elements, assume_unique, invert, kind)
#     989 """
#     990 Calculates ``element in test_elements``, broadcasting over `element` only.
#     991 Returns a boolean array of the same shape as `element` that is True
#    (...)
#    1102        [ True, False]])
#    1103 """
#    1104 element = np.asarray(element)
# -> 1105 return _in1d(element, test_elements, assume_unique=assume_unique,
#    1106              invert=invert, kind=kind).reshape(element.shape)
#
# File ~/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/numpy/lib/_arraysetops_impl.py:890, in _in1d(ar1, ar2, assume_unique, invert, kind)
#     888     outgoing_array = np.ones_like(ar1, dtype=bool)
#     889 else:
# --> 890     outgoing_array = np.zeros_like(ar1, dtype=bool)
#     892 # Make elements 1 where the integer exists in ar2
#     893 if invert:
#
# File ~/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/numpy/_core/numeric.py:139, in zeros_like(a, dtype, order, subok, shape, device)
#     137 # needed instead of a 0 to get same result as zeros for string dtypes
#     138 z = zeros(1, dtype=res.dtype)
# --> 139 multiarray.copyto(res, z, casting='unsafe')
#     140 return res
#
# KeyboardInterrupt:

# %%
# Bootstrap Confidence Intervals with Patient-Level and Slice-Level Thresholding

import numpy as np
import pandas as pd
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, confusion_matrix, classification_report
)
from sklearn.base import clone

# Number of bootstrap iterations
n_bootstraps = 1000
rng = np.random.RandomState(seed=42)  # For reproducibility

# Initialize a dictionary to store bootstrap results
bootstrap_results_per_patient = {}

for dataset_name in data_splits.keys():
    print(f"\nBootstrapping Test Metrics for '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_test_full = data['X_test_full'].reset_index(drop=True)
    y_test = data['y_test'].reset_index(drop=True)
    patient_ids_test = data['patient_ids_test'].reset_index(drop=True)
    
    # Combine test data into a single DataFrame
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test
    test_df['patient_id'] = patient_ids_test
    
    # Get unique patient IDs
    unique_patient_ids = test_df['patient_id'].unique()
    
    # Initialize dictionary for classifiers
    bootstrap_results_per_patient[dataset_name] = {}
    
    for classifier_name in classifiers.keys():
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve the best hyperparameters from nested_cv_results
        nested_results = nested_cv_results[dataset_name]
        cv_results_all = nested_results['cv_results_all']
        cv_results = cv_results_all[classifier_name]
        
        # Find the hyperparameters with the best mean_test_score
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier with default parameters
        default_classifier = classifiers[classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)

        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)
        
        # Handle compatibility between solver and penalty for Logistic Regression
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        
        # Retrieve training data
        X_train_full = data['X_train_full']
        y_train_full = data['y_train_full']
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Compute predicted probabilities on the full test set
        if hasattr(pipeline.named_steps['classifier'], "predict_proba"):
            y_proba_full = pipeline.predict_proba(X_test_full)[:, 1]
        else:
            print(f"Classifier '{classifier_name}' does not support probability estimates. Skipping.")
            continue
        
        # Add predicted probabilities to test_df
        test_df['y_proba'] = y_proba_full
        
        # Initialize lists to store bootstrap metrics
        bootstrap_accuracies = []
        bootstrap_precisions = []
        bootstrap_recalls = []
        bootstrap_f1s = []
        bootstrap_roc_aucs = []
        
        # Perform bootstrap resampling
        for i in range(n_bootstraps):
            # Sample patient IDs with replacement
            sampled_patient_ids = rng.choice(unique_patient_ids, size=len(unique_patient_ids), replace=True)
            
            # Get the indices of the slices corresponding to the sampled patient IDs
            sampled_indices = test_df[test_df['patient_id'].isin(sampled_patient_ids)].index
            
            # Create bootstrap sample
            test_df_bootstrap = test_df.loc[sampled_indices].reset_index(drop=True)
            
            # Get true labels and predicted probabilities
            y_true_bootstrap = test_df_bootstrap['y_true']
            y_proba_bootstrap = test_df_bootstrap['y_proba']
            
            # Slice-level thresholding using Youden's J statistic
            fpr, tpr, thresholds = roc_curve(y_true_bootstrap, y_proba_bootstrap)
            J = tpr - fpr
            ix = np.argmax(J)
            optimal_slice_threshold = thresholds[ix]
            # Apply optimal slice threshold
            test_df_bootstrap['y_pred_slice'] = (test_df_bootstrap['y_proba'] >= optimal_slice_threshold).astype(int)
            
            # Aggregate predictions per patient
            slice_proportions = test_df_bootstrap.groupby('patient_id')['y_pred_slice'].mean()
            y_true_per_patient_bootstrap = test_df_bootstrap.groupby('patient_id')['y_true'].first()
            
            # Patient-level thresholding using Youden's J statistic
            fpr_p, tpr_p, thresholds_p = roc_curve(y_true_per_patient_bootstrap, slice_proportions)
            J_p = tpr_p - fpr_p
            ix_p = np.argmax(J_p)
            optimal_patient_threshold = thresholds_p[ix_p]
            # Apply optimal patient threshold
            y_pred_per_patient_bootstrap = (slice_proportions >= optimal_patient_threshold).astype(int)
            
            # Compute performance metrics at the patient level
            accuracy = accuracy_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            precision = precision_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap, zero_division=0)
            recall = recall_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            f1 = f1_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            roc_auc = roc_auc_score(y_true_per_patient_bootstrap, slice_proportions)
            
            # Append metrics
            bootstrap_accuracies.append(accuracy)
            bootstrap_precisions.append(precision)
            bootstrap_recalls.append(recall)
            bootstrap_f1s.append(f1)
            bootstrap_roc_aucs.append(roc_auc)
        
        # Compute confidence intervals (e.g., 95% CI)
        def compute_confidence_interval(metric_values):
            sorted_values = np.sort(metric_values)
            lower = np.percentile(sorted_values, 2.5)
            upper = np.percentile(sorted_values, 97.5)
            mean = np.mean(metric_values)
            return mean, lower, upper
        
        accuracy_mean, accuracy_lower, accuracy_upper = compute_confidence_interval(bootstrap_accuracies)
        precision_mean, precision_lower, precision_upper = compute_confidence_interval(bootstrap_precisions)
        recall_mean, recall_lower, recall_upper = compute_confidence_interval(bootstrap_recalls)
        f1_mean, f1_lower, f1_upper = compute_confidence_interval(bootstrap_f1s)
        roc_auc_mean, roc_auc_lower, roc_auc_upper = compute_confidence_interval(bootstrap_roc_aucs)
        
        # Store the bootstrap results
        bootstrap_results_per_patient[dataset_name][classifier_name] = {
            'accuracy': (accuracy_mean, accuracy_lower, accuracy_upper),
            'precision': (precision_mean, precision_lower, precision_upper),
            'recall': (recall_mean, recall_lower, recall_upper),
            'f1': (f1_mean, f1_lower, f1_upper),
            'roc_auc': (roc_auc_mean, roc_auc_lower, roc_auc_upper),
        }
        
        # Print the results
        print(f"\n{classifier_name} Bootstrap Confidence Intervals (Patient-Level):")
        print(f"Accuracy: {accuracy_mean:.4f} (95% CI: {accuracy_lower:.4f} - {accuracy_upper:.4f})")
        print(f"Precision: {precision_mean:.4f} (95% CI: {precision_lower:.4f} - {precision_upper:.4f})")
        print(f"Recall: {recall_mean:.4f} (95% CI: {recall_lower:.4f} - {recall_upper:.4f})")
        print(f"F1 Score: {f1_mean:.4f} (95% CI: {f1_lower:.4f} - {f1_upper:.4f})")
        print(f"ROC AUC: {roc_auc_mean:.4f} (95% CI: {roc_auc_lower:.4f} - {roc_auc_upper:.4f})")

# %%
# Prepare the base classifiers with their best hyperparameters
# Import necessary libraries
from sklearn.ensemble import StackingClassifier, VotingClassifier
from sklearn.base import clone
# Prepare the base classifiers with their best hyperparameters
def get_best_classifier(classifier_name, dataset_name):
    # Retrieve the best hyperparameters from nested_cv_results
    nested_results = nested_cv_results[dataset_name]
    cv_results_all = nested_results['cv_results_all']
    cv_results = cv_results_all[classifier_name]
    
    # Find the hyperparameters with the best mean_test_score
    max_mean_test_score = cv_results['mean_test_score'].max()
    best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
    
    # If multiple rows have the same max score, pick the first one
    best_row = best_rows.iloc[0]
    
    # Extract the best hyperparameters from the pipeline parameters
    best_params = best_row['params']
    
    # The params are for the entire pipeline; extract classifier's hyperparameters
    classifier_params = {}
    for param_name, param_value in best_params.items():
        if param_name.startswith('classifier__'):
            # Remove 'classifier__' prefix to get the parameter name
            param_short = param_name.replace('classifier__', '')
            classifier_params[param_short] = param_value
    
    # Get the default classifier with default parameters
    default_classifier = classifiers[classifier_name]
    
    # Clone the default classifier to avoid modifying the original
    classifier = clone(default_classifier)
    
    # Update the classifier's parameters with the best hyperparameters
    classifier.set_params(**classifier_params)

    # **Compute scale_pos_weight for XGBoost and LightGBM**
    if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
        scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
        print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
        classifier.set_params(scale_pos_weight=scale_pos_weight)
    
    # Handle compatibility between solver and penalty for Logistic Regression
    if classifier_name == 'Logistic Regression':
        penalty = classifier.get_params().get('penalty', 'l2')
        solver = classifier.get_params().get('solver', 'lbfgs')
        if penalty == 'l1' and solver not in ['liblinear', 'saga']:
            # Change solver to 'liblinear' if penalty is 'l1'
            classifier.set_params(solver='liblinear')
            print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
        elif penalty == 'elasticnet' and solver != 'saga':
            # 'elasticnet' penalty requires 'saga' solver
            classifier.set_params(solver='saga')
            print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
        elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
            # Dual formulation is only implemented for l2 penalty with liblinear solver
            classifier.set_params(dual=True)
        else:
            # Ensure dual is False for other solvers
            classifier.set_params(dual=False)
    return classifier

# %%
# Function: Create the ensemble classifiers
def create_ensemble_classifiers(dataset_name):
    # Prepare base classifiers
    base_classifiers = []
    classifier_names = ['Logistic Regression', 'Random Forest', 'XGBoost', 'LightGBM']
    
    for clf_name in classifier_names:
        clf = get_best_classifier(clf_name, dataset_name)
        base_classifiers.append((clf_name.lower().replace(' ', '_'), clf))
    
    # Create the stacking classifier
    stacking_classifier = StackingClassifier(
        estimators=base_classifiers,
        final_estimator=LogisticRegression(random_state=42),
        passthrough=False,
        cv=5,
        n_jobs=-1
    )
    
    # Create the voting classifier
    voting_classifier = VotingClassifier(
        estimators=base_classifiers,
        voting='soft',  # Use 'hard' for majority voting
        n_jobs=-1
    )
    
    return stacking_classifier, voting_classifier

# %%
# Retrain and test on Ensemble Classifiers with Slice-Level and Patient-Level Thresholding

# Initialize a dictionary to store test results
test_results_ensemble = {}

for dataset_name in data_splits.keys():
    print(f"\nEvaluating Ensemble Classifiers on '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test = data['y_test']
    patient_ids_test = data['patient_ids_test'].reset_index(drop=True)
    
    # Create a DataFrame for test data
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test.values
    test_df['patient_id'] = patient_ids_test.values
    
    # Get per-patient true labels (assuming all slices of a patient have the same label)
    y_true_per_patient = test_df.groupby('patient_id')['y_true'].first()
    
    # Create ensemble classifiers
    stacking_classifier, voting_classifier = create_ensemble_classifiers(dataset_name)
    
    ensemble_classifiers = {
        'Stacking Classifier': stacking_classifier,
        'Voting Classifier': voting_classifier
    }
    
    for ensemble_name, ensemble_clf in ensemble_classifiers.items():
        print(f"\nClassifier: {ensemble_name}")
        
        # Handle classifiers that do not support predict_proba
        if not hasattr(ensemble_clf, "predict_proba"):
            print(f"Classifier '{ensemble_name}' does not support probability estimates. Skipping.")
            continue
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', ensemble_clf)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Predict probabilities on the test set
        y_proba = pipeline.predict_proba(X_test_full)[:, 1]
        
        # Add predicted probabilities to test_df
        test_df[f'{ensemble_name}_proba'] = y_proba
        
        # Compute optimal slice_threshold using Youden's J
        fpr, tpr, thresholds = roc_curve(y_test, y_proba)
        J = tpr - fpr
        ix = np.argmax(J)
        slice_threshold = thresholds[ix]
        print(f"Optimal Slice Threshold (Youden's J): {slice_threshold:.4f}")
        
        # Assign per-slice predictions based on slice_threshold
        test_df[f'{ensemble_name}_pred_slice'] = (y_proba >= slice_threshold).astype(int)
        
        # Aggregate predictions per patient
        slice_proportions = test_df.groupby('patient_id')[f'{ensemble_name}_pred_slice'].mean()
        
        # Compute patient_threshold using Youden's J on slice proportions
        fpr_p, tpr_p, thresholds_p = roc_curve(y_true_per_patient, slice_proportions)
        J_p = tpr_p - fpr_p
        ix_p = np.argmax(J_p)
        patient_threshold = thresholds_p[ix_p]
        print(f"Optimal Patient Threshold (Youden's J): {patient_threshold:.4f}")
        
        # Assign patient-level predictions based on patient_threshold
        y_pred_per_patient = (slice_proportions >= patient_threshold).astype(int)
        
        # Align the true labels
        y_true = y_true_per_patient
        
        # Compute performance metrics
        accuracy = accuracy_score(y_true, y_pred_per_patient)
        precision = precision_score(y_true, y_pred_per_patient, zero_division=0)
        recall = recall_score(y_true, y_pred_per_patient)
        f1 = f1_score(y_true, y_pred_per_patient)
        try:
            roc_auc = roc_auc_score(y_true, slice_proportions)  # Using slice proportions for ROC AUC
        except ValueError:
            roc_auc = None  # Handle cases where ROC AUC is not defined
        
        conf_matrix = confusion_matrix(y_true, y_pred_per_patient)
        class_report = classification_report(y_true, y_pred_per_patient, zero_division=0)
        
        # Store the results
        test_results_ensemble[dataset_name] = test_results_ensemble.get(dataset_name, {})
        test_results_ensemble[dataset_name][ensemble_name + ' (Patient Aggregated)'] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"\nAggregated Test Results for {ensemble_name} on {dataset_name} Dataset:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        if roc_auc is not None:
            print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)

# %%
# Bootstrap Confidence Intervals for Ensemble Classifiers

import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve

# Number of bootstrap iterations
n_bootstraps = 1000
rng = np.random.RandomState(seed=42)  # For reproducibility

# Initialize a dictionary to store bootstrap results
bootstrap_results_ensemble = {}

for dataset_name in data_splits.keys():
    print(f"\nBootstrapping Test Metrics for Ensemble Classifiers on '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_test_full = data['X_test_full'].reset_index(drop=True)
    y_test = data['y_test'].reset_index(drop=True)
    patient_ids_test = data['patient_ids_test'].reset_index(drop=True)
    
    # Combine test data into a single DataFrame
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test
    test_df['patient_id'] = patient_ids_test
    
    # Get unique patient IDs
    unique_patient_ids = test_df['patient_id'].unique()
    
    # Create ensemble classifiers
    stacking_classifier, voting_classifier = create_ensemble_classifiers(dataset_name)
    
    ensemble_classifiers = {
        'Stacking Classifier': stacking_classifier,
        'Voting Classifier': voting_classifier
    }
    
    for ensemble_name, ensemble_clf in ensemble_classifiers.items():
        print(f"\nClassifier: {ensemble_name}")
        
        # Handle classifiers that do not support predict_proba
        if not hasattr(ensemble_clf, "predict_proba"):
            print(f"Classifier '{ensemble_name}' does not support probability estimates. Skipping.")
            continue
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(data['X_train_full'], data['y_train_full'])
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', ensemble_clf)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Compute predicted probabilities on the full test set
        y_proba_full = pipeline.predict_proba(X_test_full)[:, 1]
        
        # Add predicted probabilities to test_df
        test_df['y_proba'] = y_proba_full
        
        # Initialize lists to store bootstrap metrics
        bootstrap_accuracies = []
        bootstrap_precisions = []
        bootstrap_recalls = []
        bootstrap_f1s = []
        bootstrap_roc_aucs = []
        
        # Perform bootstrap resampling
        for i in range(n_bootstraps):
            # Sample patient IDs with replacement
            sampled_patient_ids = rng.choice(unique_patient_ids, size=len(unique_patient_ids), replace=True)
            
            # Get the indices of the slices corresponding to the sampled patient IDs
            sampled_indices = test_df[test_df['patient_id'].isin(sampled_patient_ids)].index
            
            # Create bootstrap sample
            test_df_bootstrap = test_df.loc[sampled_indices].reset_index(drop=True)
            
            # Get true labels and predicted probabilities
            y_true_bootstrap = test_df_bootstrap['y_true']
            y_proba_bootstrap = test_df_bootstrap['y_proba']
            
            # Slice-level thresholding using Youden's J statistic
            fpr, tpr, thresholds = roc_curve(y_true_bootstrap, y_proba_bootstrap)
            J = tpr - fpr
            ix = np.argmax(J)
            optimal_slice_threshold = thresholds[ix]
            # Apply optimal slice threshold
            test_df_bootstrap['y_pred_slice'] = (test_df_bootstrap['y_proba'] >= optimal_slice_threshold).astype(int)
            
            # Aggregate predictions per patient
            slice_proportions = test_df_bootstrap.groupby('patient_id')['y_pred_slice'].mean()
            y_true_per_patient_bootstrap = test_df_bootstrap.groupby('patient_id')['y_true'].first()
            
            # Patient-level thresholding using Youden's J statistic
            fpr_p, tpr_p, thresholds_p = roc_curve(y_true_per_patient_bootstrap, slice_proportions)
            J_p = tpr_p - fpr_p
            ix_p = np.argmax(J_p)
            optimal_patient_threshold = thresholds_p[ix_p]
            # Apply optimal patient threshold
            y_pred_per_patient_bootstrap = (slice_proportions >= optimal_patient_threshold).astype(int)
            
            # Compute performance metrics at the patient level
            accuracy = accuracy_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            precision = precision_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap, zero_division=0)
            recall = recall_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            f1 = f1_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            roc_auc = roc_auc_score(y_true_per_patient_bootstrap, slice_proportions)
            
            # Append metrics
            bootstrap_accuracies.append(accuracy)
            bootstrap_precisions.append(precision)
            bootstrap_recalls.append(recall)
            bootstrap_f1s.append(f1)
            bootstrap_roc_aucs.append(roc_auc)
        
        # Compute confidence intervals (e.g., 95% CI)
        def compute_confidence_interval(metric_values):
            sorted_values = np.sort(metric_values)
            lower = np.percentile(sorted_values, 2.5)
            upper = np.percentile(sorted_values, 97.5)
            mean = np.mean(metric_values)
            return mean, lower, upper
        
        accuracy_mean, accuracy_lower, accuracy_upper = compute_confidence_interval(bootstrap_accuracies)
        precision_mean, precision_lower, precision_upper = compute_confidence_interval(bootstrap_precisions)
        recall_mean, recall_lower, recall_upper = compute_confidence_interval(bootstrap_recalls)
        f1_mean, f1_lower, f1_upper = compute_confidence_interval(bootstrap_f1s)
        roc_auc_mean, roc_auc_lower, roc_auc_upper = compute_confidence_interval(bootstrap_roc_aucs)
        
        # Store the bootstrap results
        bootstrap_results_ensemble[dataset_name] = bootstrap_results_ensemble.get(dataset_name, {})
        bootstrap_results_ensemble[dataset_name][ensemble_name] = {
            'accuracy': (accuracy_mean, accuracy_lower, accuracy_upper),
            'precision': (precision_mean, precision_lower, precision_upper),
            'recall': (recall_mean, recall_lower, recall_upper),
            'f1': (f1_mean, f1_lower, f1_upper),
            'roc_auc': (roc_auc_mean, roc_auc_lower, roc_auc_upper),
        }
        
        # Print the results
        print(f"\n{ensemble_name} Bootstrap Confidence Intervals (Patient-Level):")
        print(f"Accuracy: {accuracy_mean:.4f} (95% CI: {accuracy_lower:.4f} - {accuracy_upper:.4f})")
        print(f"Precision: {precision_mean:.4f} (95% CI: {precision_lower:.4f} - {precision_upper:.4f})")
        print(f"Recall: {recall_mean:.4f} (95% CI: {recall_lower:.4f} - {recall_upper:.4f})")
        print(f"F1 Score: {f1_mean:.4f} (95% CI: {f1_lower:.4f} - {f1_upper:.4f})")
        print(f"ROC AUC: {roc_auc_mean:.4f} (95% CI: {roc_auc_lower:.4f} - {roc_auc_upper:.4f})")

# %%
# Visualize Ensemble Classifier Performance

import matplotlib.pyplot as plt
import seaborn as sns

# Update your plotting function to include ensemble classifiers
def plot_metrics_with_ensembles(dataset_name, classifiers_results, ensemble_results):
    metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
    classifier_names = list(classifiers_results.keys()) + list(ensemble_results.keys())
    metric_values = {metric: [] for metric in metrics}
    
    for clf_name in classifier_names:
        if clf_name in classifiers_results:
            results = classifiers_results[clf_name]
        else:
            results = ensemble_results[clf_name]
        for metric in metrics:
            metric_values[metric].append(results[metric])
    
    df_metrics = pd.DataFrame(metric_values, index=classifier_names)
    df_metrics = df_metrics.reset_index().rename(columns={'index': 'Classifier'})
    
    df_melted = df_metrics.melt(id_vars='Classifier', var_name='Metric', value_name='Value')
    
    plt.figure(figsize=(14, 7))
    sns.barplot(x='Classifier', y='Value', hue='Metric', data=df_melted)
    plt.title(f'Per-Patient Aggregated Performance Metrics for {dataset_name} Dataset')
    plt.xticks(rotation=45)
    plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# Plot metrics for each dataset
for dataset_name in data_splits.keys():
    classifiers_results = test_results_per_patient[dataset_name]
    ensemble_results = test_results_ensemble.get(dataset_name, {})
    plot_metrics_with_ensembles(dataset_name, classifiers_results, ensemble_results)

# %%
# SHAP Analysis

#import shap
#import matplotlib.pyplot as plt
#
## For computational efficiency, we can sample a subset of data
## Number of samples to use for SHAP analysis
#n_samples = 100
#
#for dataset_name in data_splits.keys():
#    print(f"\nPerforming SHAP Analysis for '{dataset_name}' Dataset")
#    
#    # Retrieve data splits for the current dataset
#    data = data_splits[dataset_name]
#    X_train_full = data['X_train_full']
#    y_train_full = data['y_train_full']
#    X_test_full = data['X_test_full']
#    y_test = data['y_test']
#    
#    # For SHAP analysis, we'll use a small sample of the test data
#    if len(X_test_full) > n_samples:
#        X_test_sample = X_test_full.sample(n=n_samples, random_state=42)
#    else:
#        X_test_sample = X_test_full.copy()
#    
#    for classifier_name in classifiers.keys():
#        print(f"\nClassifier: {classifier_name}")
#        
#        # Retrieve the best hyperparameters from nested_cv_results
#        nested_results = nested_cv_results[dataset_name]
#        cv_results_all = nested_results['cv_results_all']
#        cv_results = cv_results_all[classifier_name]
#        
#        # Find the hyperparameters with the best mean_test_score
#        max_mean_test_score = cv_results['mean_test_score'].max()
#        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
#        
#        # If multiple rows have the same max score, pick the first one
#        best_row = best_rows.iloc[0]
#        
#        # Extract the best hyperparameters from the pipeline parameters
#        best_params = best_row['params']
#        
#        # The params are for the entire pipeline; extract classifier's hyperparameters
#        classifier_params = {}
#        for param_name, param_value in best_params.items():
#            if param_name.startswith('classifier__'):
#                # Remove 'classifier__' prefix to get the parameter name
#                param_short = param_name.replace('classifier__', '')
#                classifier_params[param_short] = param_value
#        
#        # Get the default classifier with default parameters
#        default_classifier = classifiers[classifier_name]
#        
#        # Clone the default classifier to avoid modifying the original
#        classifier = clone(default_classifier)
#        
#        # Update the classifier's parameters with the best hyperparameters
#        classifier.set_params(**classifier_params)
#        
#        # Handle compatibility between solver and penalty for Logistic Regression
#        if classifier_name == 'Logistic Regression':
#            penalty = classifier.get_params().get('penalty', 'l2')
#            solver = classifier.get_params().get('solver', 'lbfgs')
#            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
#                # Change solver to 'liblinear' if penalty is 'l1'
#                classifier.set_params(solver='liblinear')
#                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
#            elif penalty == 'elasticnet' and solver != 'saga':
#                # 'elasticnet' penalty requires 'saga' solver
#                classifier.set_params(solver='saga')
#                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
#            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
#                # Dual formulation is only implemented for l2 penalty with liblinear solver
#                classifier.set_params(dual=True)
#            else:
#                # Ensure dual is False for other solvers
#                classifier.set_params(dual=False)
#        
#        # Apply SMOTE to training data only
#        print("\nApplying SMOTE to balance the classes in the training data...")
#        smote = SMOTE(random_state=42)
#        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
#        
#        # Define the pipeline without SMOTE
#        pipeline = Pipeline(steps=[
#            ('scaler', MinMaxScaler()),
#            ('classifier', classifier)
#        ])
#        
#        # Fit the pipeline on the entire training set
#        pipeline.fit(X_train_resampled, y_train_resampled)
#        
#        # Extract the classifier from the pipeline
#        trained_classifier = pipeline.named_steps['classifier']
#        
#        # Prepare the data (after scaling)
#        X_train_scaled = pipeline.named_steps['scaler'].transform(X_train_resampled)
#        X_test_scaled = pipeline.named_steps['scaler'].transform(X_test_sample)
#        
#        # For SHAP, we need to use the model and data
#        # Use appropriate SHAP explainer based on the model
#        if classifier_name in ['Random Forest', 'XGBoost', 'LightGBM']:
#            # Use TreeExplainer
#            explainer = shap.TreeExplainer(trained_classifier)
#        elif classifier_name == 'Logistic Regression':
#            explainer = shap.LinearExplainer(trained_classifier, X_train_scaled)
#        elif classifier_name == 'SVM':
#            # For SVM, use KernelExplainer (may be slow)
#            print("KernelExplainer may be slow for SVM. Using a small sample of background data.")
#            X_train_small = X_train_scaled[:100]  # Use a small subset as background
#            def model_predict(data):
#                return trained_classifier.decision_function(data)
#            explainer = shap.KernelExplainer(model_predict, X_train_small)
#        else:
#            print(f"SHAP analysis not implemented for classifier '{classifier_name}'.")
#            continue
#        
#        # Compute SHAP values
#        print("Computing SHAP values...")
#        shap_values = explainer.shap_values(X_test_scaled)
#        
#        # For multi-class classifiers, shap_values is a list
#        if isinstance(shap_values, list):
#            # For binary classification, take the SHAP values for the positive class
#            shap_values = shap_values[1]
#        
#        # Get feature names
#        feature_names = X_test_full.columns
#        
#        # Create a summary plot
#        shap.summary_plot(shap_values, X_test_scaled, feature_names=feature_names)
