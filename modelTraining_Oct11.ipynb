# %%
# Import Libraries
import pandas as pd
import numpy as np
import random
import time
import matplotlib.pyplot as plt
import seaborn as sns
import gzip
import pickle

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)

# Sklearn and Imbalanced-learn Libraries
from sklearn.model_selection import StratifiedKFold, train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import RFECV, VarianceThreshold, mutual_info_classif
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, balanced_accuracy_score,
    classification_report
)
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.utils import resample
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE




from sklearn.base import BaseEstimator, TransformerMixin

# Additional Libraries
from sklearn.base import clone
from sklearn.exceptions import NotFittedError
import warnings
warnings.filterwarnings('ignore')

# Machine Learning Libraries with GPU Support
import xgboost as xgb
import lightgbm as lgb

# For SHAP values
import shap

# Statistical Tests
from scipy.stats import friedmanchisquare
import scikit_posthocs as sp

# For progress monitoring
from tqdm import tqdm
from kneed import KneeLocator


import warnings

# Suppress warnings to reduce clutter
warnings.filterwarnings('ignore')

from sklearn.exceptions import ConvergenceWarning

# Suppress ConvergenceWarning
warnings.filterwarnings('ignore', category=ConvergenceWarning)

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

from joblib import Parallel, delayed
from sklearn.base import BaseEstimator, TransformerMixin
from scipy.stats import mannwhitneyu
import numpy as np
import pandas as pd

# Necessary imports
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import cross_val_score
from sklearn.utils.validation import check_X_y, check_array
import pandas as pd
import numpy as np

from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

# %%
# File paths for clinical, extracted features and radiomics features
clinical_data_path = '/Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/Clinical_and_Other_Features_final_comb.xlsx'
features_path = '/Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/features_extracted_VGG16_tumor_mid10_5.pkl.gz'
imaging_features_path = '/Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/Imaging_Features.xlsx'

# %%
#Function: Load and Process Clinical and Extracted Features Data
def load_clinical_data(clinical_data_path):
    """
    Loads and preprocesses clinical data from an Excel file.

    Parameters:
    - clinical_data_path (str): Path to the clinical data Excel file.

    Returns:
    - pd.DataFrame: Preprocessed clinical data.
    """
    print("Loading clinical data...")
    clinical_data = pd.read_excel(clinical_data_path)

    # Rename columns for consistency
    clinical_data.columns = [col.replace(' ', '_') for col in clinical_data.columns]
    clinical_data = clinical_data.rename(
        columns={
            'Patient_ID': 'patient_id',
            'Pathologic_Response_to_Neoadjuvant_Therapy': 'response'
        }
    )

    # Convert 'Breast_MRI_001' to '001' in the patient_id column
    clinical_data['patient_id'] = clinical_data['patient_id'].apply(
        lambda x: x.split('_')[-1] if isinstance(x, str) else x
    )

    # Convert response to binary: 1 means pCR, else non-pCR
    clinical_data['response'] = clinical_data['response'].apply(
        lambda x: 1 if x == 1 else 0
    )

    # Preprocess clinical data
    clinical_data['patient_id'] = clinical_data['patient_id'].astype(str)

    # Separate numerical and categorical columns
    patient_id_cols = ["patient_id"]
    response_cols = ["response"]
    numerical_cols = ["Date_of_Birth"]  # Consider converting to 'Age at Diagnosis'
    categorical_cols = clinical_data.columns[
        (clinical_data.columns != "Date_of_Birth") &
        (clinical_data.columns != "patient_id") &
        (clinical_data.columns != "response")
    ]

    numerical_df = clinical_data[numerical_cols]
    patient_id_df = clinical_data[patient_id_cols]
    response_df = clinical_data[response_cols]

    # One-hot encode categorical columns
    clinical_data[categorical_cols] = clinical_data[categorical_cols].astype('category')
    categorical_df = pd.get_dummies(clinical_data[categorical_cols], drop_first=True)
    categorical_df = categorical_df.astype(int)

    # Concatenate all dataframes
    encoded_df = pd.concat(
        [patient_id_df, numerical_df, categorical_df, response_df],
        axis=1
    )

    print("Clinical data loaded and processed.")
    return encoded_df

def load_image_features(features_path):
    """
    Loads and processes image features from a compressed pickle file.

    Parameters:
    - features_path (str): Path to the compressed pickle file containing image features.

    Returns:
    - pd.DataFrame: Processed image features.
    """
    print("Loading image features...")
    with gzip.open(features_path, 'rb') as f:
        features_dict = pickle.load(f)

    # Extract patient IDs and features
    features_data = {
        'patient_id': [key.split('-')[0] for key in features_dict.keys()],
        **{
            f'feature_{i}': [features_dict[key][i] for key in features_dict.keys()]
            for i in range(len(next(iter(features_dict.values()))))
        }
    }

    # Create a DataFrame
    features_df = pd.DataFrame(features_data)
    features_df['patient_id'] = features_df['patient_id'].astype(str)
    print("Image features loaded.")
    return features_df



def load_and_preprocess_data(clinical_data_path, features_path):
    clinical_data_processed = load_clinical_data(clinical_data_path)
    features_df = load_image_features(features_path)
    clinical_data_processed['patient_id'] = clinical_data_processed['patient_id'].astype(str)
    features_df['patient_id'] = features_df['patient_id'].astype(str)

    # Prepare three variations of the dataset
    print("Preparing dataset variations...")

    datasets = {}

    # Handle missing data in image features
    print("Imputing missing values in image features...")
    imputer = SimpleImputer(strategy='mean')
    features_df_imputed = imputer.fit_transform(features_df.drop(columns=['patient_id']))

    # Feature scaling
    print("Scaling image features...")
    scaler = MinMaxScaler()
    features_df_scaled = scaler.fit_transform(features_df_imputed)

    # Create a DataFrame for scaled features
    features_scaled_df = pd.DataFrame(features_df_scaled, columns=[f'feature_{i}' for i in range(features_df_scaled.shape[1])])
    features_scaled_df['patient_id'] = features_df['patient_id'].values

    # Now, merge scaled image features with clinical data
    data_scaled = features_scaled_df.merge(
        clinical_data_processed,
        on='patient_id',
        how='inner'
    ).reset_index(drop=True)

    # 1. Image Features (Scaled)
    image_feature_columns = [col for col in data_scaled.columns if 'feature_' in col]

    X_image = data_scaled[image_feature_columns]
    y_image = data_scaled['response'].astype(int)
    groups_image = data_scaled['patient_id']

    # 2. Clinical Features
    # Subset clinical data to include only patients present in data_scaled
    patient_ids_in_data_scaled = clinical_data_processed['patient_id'].isin(data_scaled['patient_id'])
    clinical_data_in_data_scaled = clinical_data_processed[patient_ids_in_data_scaled].reset_index(drop=True)

    X_clinical = clinical_data_in_data_scaled.drop(columns=['patient_id', 'response'])
    y_clinical = clinical_data_in_data_scaled['response'].astype(int)
    groups_clinical = clinical_data_in_data_scaled['patient_id']

    # 3. Combined Features (Scaled image features + clinical data)
    # Exclude 'patient_id' and 'response' from features
    exclude_columns = ['patient_id', 'response']
    X_combined = data_scaled.drop(columns=exclude_columns)
    y_combined = data_scaled['response'].astype(int)
    groups_combined = data_scaled['patient_id']

    # Preprocess each dataset variation
    def preprocess_data(X):
        # Remove features with zero variance
        variance_threshold = VarianceThreshold(threshold=0)
        X_var = variance_threshold.fit_transform(X)
        feature_names = X.columns[variance_threshold.get_support(indices=True)]
        X = pd.DataFrame(X_var, columns=feature_names)
        return X

    X_combined = preprocess_data(X_combined)
    X_clinical = preprocess_data(X_clinical)
    X_image = preprocess_data(X_image)

    datasets['Combined'] = (X_combined, y_combined, groups_combined)
    datasets['Clinical'] = (X_clinical, y_clinical, groups_clinical)
    datasets['Image'] = (X_image, y_image, groups_image)

    return datasets

# %%
# Make Clinical, Image and Combined Data in data variations
data_variations = load_and_preprocess_data(clinical_data_path, features_path)
# Out:
# Loading clinical data...
# Clinical data loaded and processed.
# Loading image features...
# Image features loaded.
# Preparing dataset variations...
# Imputing missing values in image features...
# Scaling image features...

# %%
#Function: Load additional imaging features from radiomics Imaging_Features.xlsx

def load_additional_imaging_features(imaging_features_path):
    print("Loading additional imaging features...")
    imaging_features_df = pd.read_excel(imaging_features_path)
    
    # Rename the 'Patient ID' column to 'patient_id'
    imaging_features_df = imaging_features_df.rename(columns={'Patient ID': 'patient_id'})
    
    # Convert 'Breast_MRI_001' to '001' in the patient_id column
    imaging_features_df['patient_id'] = imaging_features_df['patient_id'].apply(
        lambda x: x.split('_')[-1] if isinstance(x, str) else x
    )
    
    # Ensure patient_id is string type
    imaging_features_df['patient_id'] = imaging_features_df['patient_id'].astype(str)
    
    # Clean up feature names by replacing spaces and special characters
    imaging_features_df.columns = [col.replace(' ', '_')
                                     .replace('(', '')
                                     .replace(')', '')
                                     .replace(',', '_')
                                     .replace('.', '_') for col in imaging_features_df.columns]
    
    print("Additional imaging features loaded.")
    return imaging_features_df

# Load the additional imaging features
additional_imaging_features_df = load_additional_imaging_features(imaging_features_path)
# Out:
# Loading additional imaging features...
# Additional imaging features loaded.

# %%
# Prepare new datasets with the radiomics imaging features

print("Preparing new datasets with additional imaging features...")

clinical_data_processed = load_clinical_data(clinical_data_path)
# Ensure patient IDs are strings
additional_imaging_features_df['patient_id'] = additional_imaging_features_df['patient_id'].astype(str)
clinical_data_processed['patient_id'] = clinical_data_processed['patient_id'].astype(str)

# Imaging Only Dataset (from Imaging_Features.xlsx)
# Merge the imaging features with the response variable from clinical data
imaging_only_df = additional_imaging_features_df.merge(
    clinical_data_processed[['patient_id', 'response']],
    on='patient_id',
    how='inner'
)

# Create X and y for Imaging Only dataset
X_imaging_only = imaging_only_df.drop(columns=['patient_id', 'response'])
y_imaging_only = imaging_only_df['response'].astype(int)
groups_imaging_only = imaging_only_df['patient_id']

# Clinical + Imaging Dataset
# Merge imaging features with clinical data
clinical_imaging_df = additional_imaging_features_df.merge(
    clinical_data_processed,
    on='patient_id',
    how='inner'
)

# Create X and y for Clinical + Imaging dataset
X_clinical_imaging = clinical_imaging_df.drop(columns=['patient_id', 'response'])
y_clinical_imaging = clinical_imaging_df['response'].astype(int)
groups_clinical_imaging = clinical_imaging_df['patient_id']

# Combined Existing Dataset + Imaging Features (Extracted Features + Clinical + Imaging)
# Get existing combined dataset
X_combined_existing, y_combined_existing, groups_combined_existing = data_variations['Combined']

# Ensure patient IDs are strings
X_combined_existing = X_combined_existing.copy()
X_combined_existing['patient_id'] = groups_combined_existing.astype(str)

# Merge with additional imaging features
combined_with_imaging_df = X_combined_existing.merge(
    additional_imaging_features_df,
    on='patient_id',
    how='inner'
)

# Ensure response variable is included
combined_with_imaging_df = combined_with_imaging_df.merge(
    clinical_data_processed[['patient_id', 'response']],
    on='patient_id',
    how='left'
)

# Create X and y for Combined with Imaging dataset
X_combined_with_imaging = combined_with_imaging_df.drop(columns=['patient_id', 'response'])
y_combined_with_imaging = combined_with_imaging_df['response'].astype(int)
groups_combined_with_imaging = combined_with_imaging_df['patient_id']

# Add new datasets to data_variations
data_variations['RadiomicsOnly'] = (X_imaging_only, y_imaging_only, groups_imaging_only)
data_variations['ClinicalRadiomics'] = (X_clinical_imaging, y_clinical_imaging, groups_clinical_imaging)
data_variations['CombinedRadiomics'] = (X_combined_with_imaging, y_combined_with_imaging, groups_combined_with_imaging)

print("New datasets added to data_variations.")
# Out:
# Preparing new datasets with additional imaging features...
# Loading clinical data...
# Clinical data loaded and processed.
# New datasets added to data_variations.

# %%
#Data Train Test Split
def stratified_group_split(X, y, groups, test_size=0.2, random_state=None):
    # Create a DataFrame with groups and their corresponding class labels
    group_df = pd.DataFrame({'group': groups, 'label': y})
    group_df = group_df.drop_duplicates()

    # Perform stratified split on groups
    stratify = group_df['label']
    group_train, group_test = train_test_split(
        group_df['group'], test_size=test_size, random_state=random_state, stratify=stratify
    )

    # Select samples based on group splits
    train_idx = X[groups.isin(group_train)].index
    test_idx = X[groups.isin(group_test)].index

    return train_idx, test_idx

# Usage
data_splits = {}

for dataset_name, (X_full, y_full, groups) in data_variations.items():
    print(f"\nProcessing {dataset_name} Dataset")

    # Ensure groups is a pandas Series with reset index
    groups = pd.Series(groups).reset_index(drop=True)
    y_full_series = pd.Series(y_full).reset_index(drop=True)
    X_full = X_full.reset_index(drop=True)

    train_idx, test_idx = stratified_group_split(X_full, y_full_series, groups, test_size=0.2, random_state=42)

    X_train_full = X_full.loc[train_idx].reset_index(drop=True)
    y_train_full = y_full_series.loc[train_idx].reset_index(drop=True)
    X_test_full = X_full.loc[test_idx].reset_index(drop=True)
    y_test = y_full_series.loc[test_idx].reset_index(drop=True)

    # Retrieve patient IDs for train and test sets
    patient_ids_train = groups.loc[train_idx].reset_index(drop=True)
    patient_ids_test = groups.loc[test_idx].reset_index(drop=True)

    data_splits[dataset_name] = {
        'X_train_full': X_train_full,
        'X_test_full': X_test_full,
        'y_train_full': y_train_full,
        'y_test': y_test,
        'patient_ids_train': patient_ids_train,
        'patient_ids_test': patient_ids_test
    }

    # Verify class distribution
    print("Training set class distribution:")
    print(y_train_full.value_counts(normalize=True))
    print("Test set class distribution:")
    print(y_test.value_counts(normalize=True))
# Out:
# Processing Combined Dataset
# Training set class distribution:
# response
# 0    0.770963
# 1    0.229037
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773832
# 1    0.226168
# Name: proportion, dtype: float64
#
# Processing Clinical Dataset
# Training set class distribution:
# response
# 0    0.770335
# 1    0.229665
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773585
# 1    0.226415
# Name: proportion, dtype: float64
#
# Processing Image Dataset
# Training set class distribution:
# response
# 0    0.770963
# 1    0.229037
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773832
# 1    0.226168
# Name: proportion, dtype: float64
#
# Processing RadiomicsOnly Dataset
# Training set class distribution:
# response
# 0    0.766667
# 1    0.233333
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773585
# 1    0.226415
# Name: proportion, dtype: float64
#
# Processing ClinicalRadiomics Dataset
# Training set class distribution:
# response
# 0    0.766667
# 1    0.233333
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773585
# 1    0.226415
# Name: proportion, dtype: float64
#
# Processing CombinedRadiomics Dataset
# Training set class distribution:
# response
# 0    0.770963
# 1    0.229037
# Name: proportion, dtype: float64
# Test set class distribution:
# response
# 0    0.773832
# 1    0.226168
# Name: proportion, dtype: float64

# %%
#Function: MannWhitney & RFECV Feature Selection
class MannWhitneyUTestFeatureSelector(BaseEstimator, TransformerMixin):
    """
    Custom transformer for feature selection using the Mann-Whitney U test
    with Bonferroni correction and optional parallelization.
    """
    def __init__(self, alpha=0.05, bonferroni=True, n_jobs=-1):
        """
        Initialize the selector.

        Parameters:
        - alpha (float): The significance level for the Mann-Whitney U test.
        - bonferroni (bool): Whether to apply Bonferroni correction.
        - n_jobs (int): The number of jobs to run in parallel (default is -1, using all available cores).
        """
        self.alpha = alpha
        self.bonferroni = bonferroni
        self.n_jobs = n_jobs
        self.selected_features_ = None

    def _perform_test(self, col, X, y):
        """
        Helper function to perform Mann-Whitney U test on a single feature.
        """
        group0 = X.loc[y == 0, col]
        group1 = X.loc[y == 1, col]
        try:
            _, p = mannwhitneyu(group0, group1, alternative='two-sided')
        except ValueError:
            p = 1  # Assign high p-value if test fails
        return p

    def fit(self, X, y):
        """
        Fit the selector to the data by performing the Mann-Whitney U test for each feature.
        
        Parameters:
        - X (pd.DataFrame): The input feature matrix.
        - y (pd.Series): The target variable.
        
        Returns:
        - self: The fitted selector.
        """
        # Ensure X is a DataFrame and y is a Series with matching indices
        X = pd.DataFrame(X)
        y = pd.Series(y, index=X.index)
        
        # Parallelized Mann-Whitney U tests
        p_values = Parallel(n_jobs=self.n_jobs)(
            delayed(self._perform_test)(col, X, y) for col in X.columns
        )
        
        self.p_values_ = np.array(p_values)
        
        # Apply Bonferroni correction if needed
        if self.bonferroni:
            corrected_alpha = self.alpha / X.shape[1]  # Adjust alpha by number of tests
        else:
            corrected_alpha = self.alpha

        # Select features with p-values below the corrected alpha level
        self.selected_features_ = X.columns[self.p_values_ < corrected_alpha]
        
        return self

    def transform(self, X):
        """
        Transform the data by selecting the features that passed the Mann-Whitney U test.

        Parameters:
        - X (pd.DataFrame): The input feature matrix.

        Returns:
        - pd.DataFrame: The selected feature matrix.
        """
        # Ensure X is a DataFrame
        X = pd.DataFrame(X)
        return X.loc[:, self.selected_features_]
    
def manual_rfecv(X, y, groups, estimator, cv, scoring='f1', min_features_to_select=5, step=0.1, early_stopping_rounds=3):
    """
    Manually performs Recursive Feature Elimination with Cross-Validation (RFECV)
    using the specified estimator and cross-validation strategy.
    
    Parameters:
    - X (pd.DataFrame): Feature matrix.
    - y (pd.Series): Target vector.
    - groups (pd.Series or array-like): Group labels for the samples used while splitting the dataset.
    - estimator: The machine learning estimator to use for feature selection.
    - cv: Cross-validation strategy.
    - scoring (str): Scoring metric (default is 'f1').
    - min_features_to_select (int): Minimum number of features to select.
    - step (float): Proportion of features to remove at each iteration.
    - early_stopping_rounds (int): Number of rounds to wait for improvement before stopping.
    
    Returns:
    - best_features (list): The list of best selected features based on cross-validation score.
    - history (pd.DataFrame): History of number of features and corresponding CV scores.
    """
    
    n_features = X.shape[1]
    step_num = int(max(1, step * n_features))  # Convert the step percentage to an absolute number of features
    
    # History to keep track of scores, feature sets and feature counts
    history = []
    feature_sets = []
    
    # Copy X to avoid modifying the original dataframe
    X_remaining = X.copy()

    # Early stopping tracking
    no_improvement_rounds = 0
    best_score = -np.inf
    
    while X_remaining.shape[1] > min_features_to_select:
        print(f"Evaluating with {X_remaining.shape[1]} features...")
        n_features_remaining = X_remaining.shape[1]
        step_num = int(max(1, step * n_features_remaining)) 
        
        # Custom cross-validation loop
        scores = []
        for train_idx, test_idx in cv.split(X_remaining, y, groups):
            X_train_cv, X_valid_cv = X_remaining.iloc[train_idx], X_remaining.iloc[test_idx]
            y_train_cv, y_valid_cv = y.iloc[train_idx], y.iloc[test_idx]
            estimator.fit(X_train_cv, y_train_cv)
            y_pred_cv = estimator.predict(X_valid_cv)
            score = f1_score(y_valid_cv, y_pred_cv)
            scores.append(score)
        avg_score = np.mean(scores)
        
        # Append results to the history and store the current feature set
        history.append((X_remaining.shape[1], round(avg_score, 2)))  # Round CV score to 2 decimal places
        feature_sets.append(X_remaining.columns.tolist())
        
        # Early stopping check
        if avg_score > best_score:
            best_score = avg_score
            no_improvement_rounds = 0
        else:
            no_improvement_rounds += 1
        
        if no_improvement_rounds >= early_stopping_rounds:
            print("Early stopping, no significant improvement.")
            break
        
        # Train the model and get feature importances
        estimator.fit(X_remaining, y)
        importances = estimator.feature_importances_
        
        # Create a DataFrame of features and importances
        feature_importances = pd.DataFrame({
            'feature': X_remaining.columns,
            'importance': importances
        })
        
        # Sort features by importance (ascending)
        feature_importances.sort_values(by='importance', ascending=True, inplace=True)
        
        # Remove the least important features based on step size
        n_to_remove = min(step_num, X_remaining.shape[1] - min_features_to_select)
        features_to_remove = feature_importances.head(n_to_remove)['feature'].tolist()
        
        # Drop the least important features
        X_remaining.drop(columns=features_to_remove, inplace=True)
    
    # Convert history to a DataFrame for easy access
    history_df = pd.DataFrame(history, columns=['n_features', 'cv_score'])
    
    # Identify the best cross-validation score and the corresponding feature sets with the least number of features
    max_score = history_df['cv_score'].max()
    best_idx = history_df[history_df['cv_score'] == max_score]['n_features'].idxmin()  # Minimize the number of features
    
    # The best selected features correspond to the maximum cross-validation score with the least features
    best_features = feature_sets[best_idx]
    
    return best_features, history_df

# %%
# Feature Selection
selected_features_dict = {}

apply_smote = False  # Set to False if you want to skip SMOTE
apply_mannwhitney = True  # Set to False if you want to skip Mann-Whitney U Test

datasets_to_skip_mannwhitney = ['Clinical', 'RadiomicsOnly', 'ClinicalRadiomics', 'CombinedRadiomics']


for dataset_name in data_variations.keys():
    
    print(f"\nStarting feature selection for '{dataset_name}' Dataset")
    
    # Retrieve data
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test = data['y_test']
    patient_ids_train = data['patient_ids_train']  # Preserving patient IDs
    patient_ids_test = data['patient_ids_test']
    # Handle Missing Data - Imputation
    print("\nHandling missing data with SimpleImputer...")
    imputer = SimpleImputer(strategy='mean')
    X_train_imputed = imputer.fit_transform(X_train_full)
    X_train_imputed = pd.DataFrame(X_train_imputed, columns=X_train_full.columns, index=X_train_full.index)
    # Feature Scaling using MinMaxScaler
    print("\nScaling features with MinMaxScaler...")
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train_imputed)
    X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train_full.columns, index=X_train_full.index)
    # L1-based Feature Selection
    print("\nPerforming L1-based feature selection...")
    if dataset_name == 'Clinical':
        l1_selector = SelectFromModel(
            LogisticRegression(penalty='l1', solver='liblinear', random_state=42, max_iter=1000)
        )
    else:
        l1_selector = SelectFromModel(
            LogisticRegression(penalty='l1', solver='liblinear', random_state=42, max_iter=1000),
            max_features=100  # Adjust as needed
        )
    l1_selector.fit(X_train_scaled, y_train_full)
    X_train_l1 = l1_selector.transform(X_train_scaled)
    X_train_l1 = pd.DataFrame(X_train_l1, columns=X_train_scaled.columns[l1_selector.get_support()])
    print(f"Number of features after L1-based selection: {X_train_l1.shape[1]}")
    # Mann-Whitney U Test Feature Selection
    # Replace the Mann-Whitney U Test conditional block with the following
    if apply_mannwhitney and dataset_name not in datasets_to_skip_mannwhitney:
        print("\nPerforming Mann-Whitney U Test feature selection with Bonferroni correction and parallelization...")
        mannwhitney_selector = MannWhitneyUTestFeatureSelector(alpha=0.05, bonferroni=True, n_jobs=-1)
        mannwhitney_selector.fit(X_train_l1, y_train_full)
        X_train_mwu = mannwhitney_selector.transform(X_train_l1)
        print(f"Number of features after Mann-Whitney U Test: {X_train_mwu.shape[1]}")
    else:
        print(f"\nSkipping Mann-Whitney U Test for '{dataset_name}' dataset. Using L1-selected features.")
        X_train_mwu = X_train_l1
    # Manually perform RFECV using a Random Forest Classifier
    print("\nPerforming Recursive Feature Elimination with Cross-Validation (RFECV)...")
    rf_estimator = RandomForestClassifier(random_state=42, n_jobs=-1, n_estimators=50, max_depth=7)
    
    cv_strategy = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
    # Perform manual RFECV, passing groups_train
    best_features, rfecv_history = manual_rfecv(
        X_train_mwu, y_train_full, patient_ids_train, rf_estimator, cv_strategy,
        scoring='f1', min_features_to_select=5, step=0.1, early_stopping_rounds=10
    )
    print(f"\nBest Features Selected: {best_features}")
    print("\nRFECV History:")
    print(rfecv_history)
    # Plot the number of features vs. cross-validation score
    plt.figure(figsize=(10, 6))
    plt.plot(rfecv_history['n_features'], rfecv_history['cv_score'], marker='o')
    plt.xlabel("Number of Features Selected")
    plt.ylabel("Cross-validation F1 Score")
    plt.title(f"Manual RFECV - {dataset_name}")
    plt.gca().invert_xaxis()  # Optional: Invert x-axis to show decreasing number of features
    plt.grid(True)
    plt.show()
    
    # Apply SMOTE **after** feature selection
    if apply_smote:
        print("\nApplying SMOTE to balance the classes after feature selection...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_mwu[best_features], y_train_full)
        X_train_resampled = pd.DataFrame(X_train_resampled, columns=best_features).reset_index(drop=True)
        y_train_resampled = pd.Series(y_train_resampled).reset_index(drop=True)
        print(f"Number of samples after SMOTE: {X_train_resampled.shape[0]}")
        print(f"Class distribution after SMOTE:\n{y_train_resampled.value_counts()}")
    else:
        print("\nSkipping SMOTE. Using original training data.")
        X_train_resampled = X_train_mwu[best_features].reset_index(drop=True)
        y_train_resampled = y_train_full.reset_index(drop=True)
    

    # Ensure that all selected features exist in the test dataset
    missing_in_train = set(best_features) - set(X_train_full.columns)
    missing_in_test = set(best_features) - set(X_test_full.columns)
    if missing_in_train:
        raise ValueError(f"The following selected features are missing in X_train_full: {missing_in_train}")
    if missing_in_test:
        raise ValueError(f"The following selected features are missing in X_test_full: {missing_in_test}")
    # Subset the original X_train_full and X_test_full to include only the selected features
    X_test_final = X_test_full[best_features].copy().reset_index(drop=True)
    y_test_final = y_test.reset_index(drop=True)
    # Store the final datasets with selected features in data_splits
    data_splits[dataset_name] = {
        'X_train_full': X_train_resampled,
        'X_test_full': X_test_final,
        'y_train_full': y_train_resampled,
        'y_test': y_test_final,
        'patient_ids_train': patient_ids_train.reset_index(drop=True),
        'patient_ids_test': patient_ids_test.reset_index(drop=True)
    }

    selected_features_dict[dataset_name] = best_features
    print(f"\nFinal datasets for '{dataset_name}' stored with selected features.")
# Out:
# Starting feature selection for 'Combined' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 100
#
# Performing Mann-Whitney U Test feature selection with Bonferroni correction and parallelization...
# Number of features after Mann-Whitney U Test: 51
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 51 features...
# Evaluating with 46 features...
# Evaluating with 42 features...
# Evaluating with 38 features...
# Evaluating with 35 features...
# Evaluating with 32 features...
# Evaluating with 29 features...
# Evaluating with 27 features...
# Evaluating with 25 features...
# Evaluating with 23 features...
# Evaluating with 21 features...
# Evaluating with 19 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['feature_953', 'feature_3966', 'feature_10530', 'feature_17715', 'feature_19776', 'feature_21676', 'feature_21846', 'feature_23016', 'feature_25069', 'PR_"{0_=_neg,\n1_=_pos}"_1']
#
# RFECV History:
#     n_features  cv_score
# 0           51      0.16
# 1           46      0.16
# 2           42      0.12
# 3           38      0.16
# 4           35      0.10
# 5           32      0.18
# 6           29      0.15
# 7           27      0.24
# 8           25      0.15
# 9           23      0.17
# 10          21      0.12
# 11          19      0.17
# 12          18      0.23
# 13          17      0.22
# 14          16      0.24
# 15          15      0.23
# 16          14      0.22
# 17          13      0.21
# 18          12      0.23
# 19          11      0.28
# 20          10      0.30
# 21           9      0.29
# 22           8      0.28
# 23           7      0.26
# 24           6      0.25
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'Combined' stored with selected features.
#
# Starting feature selection for 'Clinical' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 16
#
# Skipping Mann-Whitney U Test for 'Clinical' dataset. Using L1-selected features.
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['Race_and_Ethnicity_"{0_=_N/A\n1_=_white,\n2_=_black,\n3_=_asian,\n4_=_native,\n5_=_hispanic,\n6_=_multi,\n7_=_hawa,____8_=_amer_indian}"_2', 'PR_"{0_=_neg,\n1_=_pos}"_1', 'HER2_"{0_=_neg,\n1_=_pos,_2_=_borderline}"_1', 'Staging(Metastasis)#(Mx_-replaced_by_-1)[M]_0', 'Tumor_Grade(M)\n(Mitotic)_3', 'Multicentric/Multifocal_{0_=_no,_1_=_yes}_1']
#
# RFECV History:
#     n_features  cv_score
# 0           16      0.19
# 1           15      0.14
# 2           14      0.26
# 3           13      0.14
# 4           12      0.19
# 5           11      0.30
# 6           10      0.32
# 7            9      0.35
# 8            8      0.32
# 9            7      0.34
# 10           6      0.36
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'Clinical' stored with selected features.
#
# Starting feature selection for 'Image' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 100
#
# Performing Mann-Whitney U Test feature selection with Bonferroni correction and parallelization...
# Number of features after Mann-Whitney U Test: 53
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 53 features...
# Evaluating with 48 features...
# Evaluating with 44 features...
# Evaluating with 40 features...
# Evaluating with 36 features...
# Evaluating with 33 features...
# Evaluating with 30 features...
# Evaluating with 27 features...
# Evaluating with 25 features...
# Evaluating with 23 features...
# Evaluating with 21 features...
# Evaluating with 19 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['feature_3966', 'feature_5630', 'feature_10530', 'feature_19264', 'feature_21627', 'feature_21676', 'feature_21846']
#
# RFECV History:
#     n_features  cv_score
# 0           53      0.08
# 1           48      0.04
# 2           44      0.09
# 3           40      0.10
# 4           36      0.08
# 5           33      0.09
# 6           30      0.10
# 7           27      0.14
# 8           25      0.15
# 9           23      0.11
# 10          21      0.17
# 11          19      0.17
# 12          18      0.15
# 13          17      0.18
# 14          16      0.18
# 15          15      0.16
# 16          14      0.19
# 17          13      0.16
# 18          12      0.21
# 19          11      0.21
# 20          10      0.26
# 21           9      0.22
# 22           8      0.23
# 23           7      0.27
# 24           6      0.24
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'Image' stored with selected features.
#
# Starting feature selection for 'RadiomicsOnly' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 28
#
# Skipping Mann-Whitney U Test for 'RadiomicsOnly' dataset. Using L1-selected features.
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 28 features...
# Evaluating with 26 features...
# Evaluating with 24 features...
# Evaluating with 22 features...
# Evaluating with 20 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Early stopping, no significant improvement.
#
# Best Features Selected: ['F1_DT_POSTCON_T11=0_05_T12=0_5', 'F1_DT_T1NFS_T11=0_1_T12=0_8', 'BEDR2_Tumor', 'Ratio_Tissue_vol_enhancing_more_than_10percent_from_PostCon_to_Breast_Vol', 'Grouping_based_proportion_of_tumor_voxels_2D_tumorSlice_Group_1', 'Grouping_based_variance_of_washin_slope_3D_tissue_T1_Group_1', 'Grouping_based_proportion_of_3D_tissue_T1_Group_3', 'Grouping_based_proportion_of_3D_tissue_PostCon_Group_2', 'EnhancementClusterNeighborhoodSimilarity_Tumor', '1st_DFT_CoeffMap_Momment_Invariant_1_3D_tumor', 'Contrast_tissue_PostCon', 'Max_Probability_tissue_PostCon', 'Change_in_variance_of_Uptake_Tumor', 'SER_map_Contrast_tumor', 'SER_map_std_dev_tumor', 'PE_map_Cluster_Prominence_tumor', 'WashinRate_map_information_measure_correlation1_tumor', 'SER_Partial_tissue_vol_cu_mm_T1', 'SER_map_Autocorrelation_tissue_T1', 'SER_map_Entropy_tissue_T1', 'SER_map_information_measure_correlation2_tissue_T1', 'SER_map_mean_tissue_T1', 'PE_map_Sum_of_Squares_variance_tissue_PostCon', 'PE_map_inverse_difference_normalized_tissue_PostCon', 'PE_map_inverse_difference_moment_normalized_tissue_PostCon', 'WashinRate_map_Cluster_Prominence_tissue_PostCon', 'WashinRate_map_Cluster_Shade_tissue_PostCon', 'WashinRate_map_sum_average_tissue_PostCon']
#
# RFECV History:
#     n_features  cv_score
# 0           28      0.31
# 1           26      0.26
# 2           24      0.27
# 3           22      0.19
# 4           20      0.20
# 5           18      0.28
# 6           17      0.29
# 7           16      0.29
# 8           15      0.28
# 9           14      0.29
# 10          13      0.24
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'RadiomicsOnly' stored with selected features.
#
# Starting feature selection for 'ClinicalRadiomics' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 31
#
# Skipping Mann-Whitney U Test for 'ClinicalRadiomics' dataset. Using L1-selected features.
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 31 features...
# Evaluating with 28 features...
# Evaluating with 26 features...
# Evaluating with 24 features...
# Evaluating with 22 features...
# Evaluating with 20 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Early stopping, no significant improvement.
#
# Best Features Selected: ['BEDR2_Tumor', 'Ratio_Tissue_vol_enhancing_more_than_10percent_from_PostCon_to_Breast_Vol', 'Grouping_based_proportion_of_3D_tissue_PostCon_Group_2', 'EnhancementClusterNeighborhoodSimilarity_Tumor', 'Change_in_variance_of_Uptake_Tumor', 'SER_map_std_dev_tumor', 'SER_Partial_tissue_vol_cu_mm_T1', 'SER_map_Entropy_tissue_T1', 'SER_map_information_measure_correlation2_tissue_T1', 'SER_map_mean_tissue_T1', 'PE_map_inverse_difference_normalized_tissue_PostCon', 'WashinRate_map_Cluster_Shade_tissue_PostCon', 'Date_of_Birth', 'PR_"{0_=_neg,\n1_=_pos}"_1']
#
# RFECV History:
#     n_features  cv_score
# 0           31      0.23
# 1           28      0.30
# 2           26      0.21
# 3           24      0.27
# 4           22      0.20
# 5           20      0.22
# 6           18      0.25
# 7           17      0.26
# 8           16      0.25
# 9           15      0.23
# 10          14      0.30
# 11          13      0.29
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'ClinicalRadiomics' stored with selected features.
#
# Starting feature selection for 'CombinedRadiomics' Dataset
#
# Handling missing data with SimpleImputer...
#
# Scaling features with MinMaxScaler...
#
# Performing L1-based feature selection...
# Number of features after L1-based selection: 100
#
# Skipping Mann-Whitney U Test for 'CombinedRadiomics' dataset. Using L1-selected features.
#
# Performing Recursive Feature Elimination with Cross-Validation (RFECV)...
# Evaluating with 100 features...
# Evaluating with 90 features...
# Evaluating with 81 features...
# Evaluating with 73 features...
# Evaluating with 66 features...
# Evaluating with 60 features...
# Evaluating with 54 features...
# Evaluating with 49 features...
# Evaluating with 45 features...
# Evaluating with 41 features...
# Evaluating with 37 features...
# Evaluating with 34 features...
# Evaluating with 31 features...
# Evaluating with 28 features...
# Evaluating with 26 features...
# Evaluating with 24 features...
# Evaluating with 22 features...
# Evaluating with 20 features...
# Evaluating with 18 features...
# Evaluating with 17 features...
# Evaluating with 16 features...
# Evaluating with 15 features...
# Evaluating with 14 features...
# Evaluating with 13 features...
# Evaluating with 12 features...
# Evaluating with 11 features...
# Evaluating with 10 features...
# Evaluating with 9 features...
# Evaluating with 8 features...
# Evaluating with 7 features...
# Evaluating with 6 features...
#
# Best Features Selected: ['Date_of_Birth', 'BEDR2_Tumor', 'EnhancementClusterNeighborhoodSimilarity_Tumor', '1st_DFT_CoeffMap_Momment_Invariant_1_2D_tumorSlice', 'Max_Probability_tissue_PostCon', 'Change_in_variance_of_Uptake_Tumor', 'SER_map_information_measure_correlation2_tissue_T1', 'SER_map_skewness_tissue_PostCon']
#
# RFECV History:
#     n_features  cv_score
# 0          100      0.04
# 1           90      0.02
# 2           81      0.06
# 3           73      0.04
# 4           66      0.05
# 5           60      0.03
# 6           54      0.06
# 7           49      0.06
# 8           45      0.03
# 9           41      0.05
# 10          37      0.07
# 11          34      0.07
# 12          31      0.00
# 13          28      0.06
# 14          26      0.08
# 15          24      0.04
# 16          22      0.11
# 17          20      0.14
# 18          18      0.13
# 19          17      0.11
# 20          16      0.13
# 21          15      0.09
# 22          14      0.13
# 23          13      0.13
# 24          12      0.12
# 25          11      0.16
# 26          10      0.17
# 27           9      0.12
# 28           8      0.17
# 29           7      0.16
# 30           6      0.16
# Skipping SMOTE. Using original training data.
#
# Final datasets for 'CombinedRadiomics' stored with selected features.

# %%
# Create a new dataset 'CombinedSelected' that combines the selected features from 'Clinical' and 'Image' datasets

print("\nCreating new dataset 'CombinedSelected' from the selected features of 'Clinical' and 'Image' datasets.")

# Retrieve the selected features for 'Clinical' and 'Image' datasets
clinical_selected_features = selected_features_dict['Clinical']
image_selected_features = selected_features_dict['Image']

# Retrieve full datasets before splitting from data_variations
X_clinical_full, y_clinical_full, groups_clinical = data_variations['Clinical']
X_image_full, y_image_full, groups_image = data_variations['Image']

# Apply the selected features to the full datasets
X_clinical_selected = X_clinical_full[clinical_selected_features].copy()
X_image_selected = X_image_full[image_selected_features].copy()

# Add 'patient_id' to each dataset
X_clinical_selected['patient_id'] = groups_clinical.astype(str)
X_image_selected['patient_id'] = groups_image.astype(str)

# Merge the datasets on 'patient_id'
combined_df = pd.merge(X_clinical_selected, X_image_selected, on='patient_id', how='inner')

clinical_data_processed = load_clinical_data(clinical_data_path)
# Get the response variable
y_combined = combined_df.merge(
    clinical_data_processed[['patient_id', 'response']],
    on='patient_id',
    how='left')['response'].astype(int)


# Extract patient IDs
groups_combined = combined_df['patient_id']

# Drop 'patient_id' from features
X_combined = combined_df.drop(columns=['patient_id'])

# Now perform train-test split for 'CombinedSelected' dataset
train_idx, test_idx = stratified_group_split(X_combined, y_combined, groups_combined, test_size=0.2, random_state=42)

X_train_full = X_combined.loc[train_idx].reset_index(drop=True)
y_train_full = y_combined.loc[train_idx].reset_index(drop=True)
X_test_full = X_combined.loc[test_idx].reset_index(drop=True)
y_test = y_combined.loc[test_idx].reset_index(drop=True)

patient_ids_train = groups_combined.loc[train_idx].reset_index(drop=True)
patient_ids_test = groups_combined.loc[test_idx].reset_index(drop=True)

# Store in data_splits
data_splits['CombinedSelected'] = {
    'X_train_full': X_train_full,
    'X_test_full': X_test_full,
    'y_train_full': y_train_full,
    'y_test': y_test,
    'patient_ids_train': patient_ids_train,
    'patient_ids_test': patient_ids_test
}

print("New dataset 'CombinedSelected' created and added to data_splits.")
# Out:
# Creating new dataset 'CombinedSelected' from the selected features of 'Clinical' and 'Image' datasets.
# Loading clinical data...
# Clinical data loaded and processed.
# New dataset 'CombinedSelected' created and added to data_splits.

# %%
# Define classifiers and param grid to evaluate
classifiers = {
    'Logistic Regression': LogisticRegression(max_iter=1000, solver='liblinear', random_state=42, class_weight='balanced'),
    'Random Forest': RandomForestClassifier(class_weight='balanced', random_state=42, n_jobs=-1),
    #'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'XGBoost': xgb.XGBClassifier(eval_metric='logloss', random_state=42, n_jobs=-1),
    'LightGBM': lgb.LGBMClassifier(class_weight='balanced', random_state=42, n_jobs=-1),
    'SVM': SVC(kernel='rbf', probability=True, random_state=42, max_iter=5000,class_weight='balanced')
}


param_grids = {
    'XGBoost': {
        'classifier__n_estimators': [50, 100, 150, 200],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__max_depth': [3, 5, 7, 10]
    },
    'LightGBM': {
        'classifier__n_estimators': [50, 100, 150, 200],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__num_leaves': [31, 63],
        'classifier__verbose': [-1]
    },
    'Random Forest': {
        'classifier__n_estimators': [50, 100, 150, 200],
        'classifier__max_depth': [None, 10, 20],
        'classifier__min_samples_split': [2, 5],
        'classifier__min_samples_leaf': [1, 2]
    },
    'Gradient Boosting': {
        'classifier__n_estimators': [100, 150],
        'classifier__learning_rate': [0.01, 0.1],
        'classifier__max_depth': [3, 5, 7]
    },
    'Logistic Regression': {
        'classifier__C': np.logspace(-4, 4, 10),
        'classifier__penalty': ['l1', 'l2']
    },
    'SVM': {
        'classifier__C': [0.1, 1, 5, 10],
        'classifier__kernel': ['linear', 'rbf']
    }
}

# %%
# Function: Nested Cross Validation for Hyperparameter Tuning

def nested_cv_evaluation(dataset_name, X, y, groups, classifiers, param_grids, outer_splits=3, inner_splits=2):
    """
    Performs nested cross-validation with hyperparameter tuning and group-aware splitting.
    """
    print(f"\nStarting Nested CV for {dataset_name} dataset...")
    outer_cv = StratifiedGroupKFold(n_splits=outer_splits, shuffle=True, random_state=42)
    aggregated_scores = {}
    best_estimators = {}
    nested_scores = {name: [] for name in classifiers.keys()}
    cv_results_all = {name: [] for name in classifiers.keys()}  # To store cv_results_

    for name, base_classifier in classifiers.items():
        print(f"\nEvaluating {name} on {dataset_name} dataset...")
        start_time = time.time()
        scores = {'accuracy': [], 'precision': [], 'recall': [], 'f1': []}
        best_estimators[name] = []
        cv_results_list = []  # To collect cv_results_ from each outer fold

        for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y, groups=groups), 1):
            print(f"  Outer Fold {fold}/{outer_splits}")
            X_train_fold, X_valid = X.iloc[train_idx], X.iloc[test_idx]
            y_train_fold, y_valid = y.iloc[train_idx], y.iloc[test_idx]
            groups_train_fold = groups.iloc[train_idx]

            # Define the inner cross-validation with group awareness
            inner_cv = StratifiedGroupKFold(n_splits=inner_splits, shuffle=True, random_state=42)


            # **Compute scale_pos_weight for XGBoost and LightGBM**
            if name == 'XGBoost' or name == 'LightGBM':
                scale_pos_weight = (y_train_fold == 0).sum() / (y_train_fold == 1).sum()
                print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {name}")
                # Clone the base classifier to avoid modifying the original
                classifier = clone(base_classifier)
                classifier.set_params(scale_pos_weight=scale_pos_weight)
            else:
                classifier = clone(base_classifier)

            # Define the pipeline
            pipeline = ImbPipeline(steps=[
                ('smote', SMOTE(sampling_strategy='minority', random_state=42)),
                ('scaler', MinMaxScaler()),
                ('classifier', classifier)
            ])

            # Hyperparameter tuning with RandomizedSearchCV
            search = RandomizedSearchCV(
                estimator=pipeline,
                param_distributions=param_grids[name],
                scoring='f1',
                n_iter=5,  # Adjusted for efficiency
                cv=inner_cv.split(X_train_fold, y_train_fold, groups=groups_train_fold),
                random_state=42,
                n_jobs=-1
            )

            # Fit the model on the training fold
            search.fit(X_train_fold, y_train_fold)

            # Get the best estimator
            best_model = search.best_estimator_

            # Evaluate on the validation fold
            y_pred = best_model.predict(X_valid)

            # Compute metrics
            accuracy = accuracy_score(y_valid, y_pred)
            precision = precision_score(y_valid, y_pred, zero_division=0)
            recall = recall_score(y_valid, y_pred)
            f1 = f1_score(y_valid, y_pred)

            # Append scores
            scores['accuracy'].append(accuracy)
            scores['precision'].append(precision)
            scores['recall'].append(recall)
            scores['f1'].append(f1)
            nested_scores[name].append(f1)

            # Store the best estimator
            best_estimators[name].append(best_model)

            # Collect cv_results_
            cv_results = pd.DataFrame(search.cv_results_)
            cv_results_list.append(cv_results)

        # Aggregate scores
        aggregated_scores[name] = {metric: (np.mean(scores[metric]), np.std(scores[metric])) for metric in scores}

        # Combine cv_results_ from all outer folds
        cv_results_all[name] = pd.concat(cv_results_list, ignore_index=True)

        elapsed_time = time.time() - start_time
        print(f"{name} - Completed in {elapsed_time:.2f} seconds")
        print(f"Aggregated Scores for {name}: {aggregated_scores[name]}")

    return aggregated_scores, best_estimators, nested_scores, cv_results_all

# %%
# Nested CV for Hyperparameter Tuning

nested_cv_results = {}  # To store nested CV results
for dataset_name in data_splits.keys():
    print(f"\nStarting Nested Cross-Validation for {dataset_name} Dataset")

    # Retrieve data
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    groups_train = data['patient_ids_train']

    # Perform nested cross-validation
    aggregated_scores, best_estimators, nested_scores, cv_results_all = nested_cv_evaluation(
        dataset_name, X_train_full, y_train_full, groups_train, classifiers, param_grids
    )

    # Store the results
    nested_cv_results[dataset_name] = {
        'aggregated_scores': aggregated_scores,
        'best_estimators': best_estimators,
        'nested_scores': nested_scores,
        'cv_results_all': cv_results_all
    }
# Out:
# Starting Nested Cross-Validation for Combined Dataset
#
# Starting Nested CV for Combined dataset...
#
# Evaluating Logistic Regression on Combined dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 1.82 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.7278139106554075), np.float64(0.004111106542055251)), 'precision': (np.float64(0.4305708020050125), np.float64(0.040457595620497354)), 'recall': (np.float64(0.6183765364488257), np.float64(0.15204101954665877)), 'f1': (np.float64(0.4991238947498358), np.float64(0.06863213373519152))}
#
# Evaluating Random Forest on Combined dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.81 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7278063734559019), np.float64(0.007827927312741585)), 'precision': (np.float64(0.42047073994310175), np.float64(0.05233681282919321)), 'recall': (np.float64(0.5240761023893554), np.float64(0.08121085128529743)), 'f1': (np.float64(0.4638096154861215), np.float64(0.05685005728073384))}
#
# Evaluating XGBoost on Combined dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.4712 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.0000 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.6812 for XGBoost
# XGBoost - Completed in 2.57 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.6441050877467062), np.float64(0.01676140939491285)), 'precision': (np.float64(0.3650957893948323), np.float64(0.0517228688377294)), 'recall': (np.float64(0.7565372601517181), np.float64(0.06473624695631493)), 'f1': (np.float64(0.4906777687915104), np.float64(0.056157017837855684))}
#
# Evaluating LightGBM on Combined dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.4712 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.0000 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.6812 for LightGBM
# LightGBM - Completed in 38.47 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.6612200122239672), np.float64(0.007971839667728495)), 'precision': (np.float64(0.3716223601671007), np.float64(0.035522602231871134)), 'recall': (np.float64(0.7082471299338771), np.float64(0.0922500144404928)), 'f1': (np.float64(0.48496813808670886), np.float64(0.04263776978665568))}
#
# Evaluating SVM on Combined dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 3.68 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6777182567416823), np.float64(0.02842632978614873)), 'precision': (np.float64(0.38886376719221255), np.float64(0.06397409266378203)), 'recall': (np.float64(0.6957527078009006), np.float64(0.06629272727904138)), 'f1': (np.float64(0.4948350153348407), np.float64(0.058638480555861835))}
#
# Starting Nested Cross-Validation for Clinical Dataset
#
# Starting Nested CV for Clinical dataset...
#
# Evaluating Logistic Regression on Clinical dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.30 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.7174603174603175), np.float64(0.035916534917411966)), 'precision': (np.float64(0.4268997668997669), np.float64(0.05803396280859605)), 'recall': (np.float64(0.6436274509803922), np.float64(0.045188528143104006)), 'f1': (np.float64(0.5122562503820527), np.float64(0.05496040864960581))}
#
# Evaluating Random Forest on Clinical dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.23 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7368530020703933), np.float64(0.017570310152610437)), 'precision': (np.float64(0.4335511982570806), np.float64(0.047905519449446675)), 'recall': (np.float64(0.4582516339869281), np.float64(0.014760700298891065)), 'f1': (np.float64(0.44470439691027924), np.float64(0.03026810409350893))}
#
# Evaluating XGBoost on Clinical dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.4839 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.3438 for XGBoost
# XGBoost - Completed in 0.76 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.6409937888198758), np.float64(0.04178605761876806)), 'precision': (np.float64(0.3534495279593319), np.float64(0.043850363794935454)), 'recall': (np.float64(0.6644607843137255), np.float64(0.04619431610540397)), 'f1': (np.float64(0.46073871409028727), np.float64(0.04610102822396836))}
#
# Evaluating LightGBM on Clinical dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.4839 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.3438 for LightGBM
# LightGBM - Completed in 4.98 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.6169772256728778), np.float64(0.05929933368283449)), 'precision': (np.float64(0.3539491872825206), np.float64(0.04500895268349589)), 'recall': (np.float64(0.7677287581699347), np.float64(0.08318333610584912)), 'f1': (np.float64(0.4810598021082846), np.float64(0.04102029228896985))}
#
# Evaluating SVM on Clinical dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 0.40 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6742581090407177), np.float64(0.0733572703390596)), 'precision': (np.float64(0.40771128271128276), np.float64(0.08466052687400252)), 'recall': (np.float64(0.7323529411764707), np.float64(0.0636726779652138)), 'f1': (np.float64(0.5134952766531714), np.float64(0.04887265576850693))}
#
# Starting Nested Cross-Validation for Image Dataset
#
# Starting Nested CV for Image dataset...
#
# Evaluating Logistic Regression on Image dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.50 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.7381700227760465), np.float64(0.03756208652348507)), 'precision': (np.float64(0.4492490545939222), np.float64(0.019631237968488917)), 'recall': (np.float64(0.5952861952861953), np.float64(0.07149671305101966)), 'f1': (np.float64(0.5086845119525935), np.float64(0.01639931935890592))}
#
# Evaluating Random Forest on Image dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.65 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7205507911318682), np.float64(0.019585013728547918)), 'precision': (np.float64(0.38408266513936623), np.float64(0.05165845272789058)), 'recall': (np.float64(0.3785505658999635), np.float64(0.054381948429499914)), 'f1': (np.float64(0.3804367362945706), np.float64(0.04927720019574162))}
#
# Evaluating XGBoost on Image dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.4712 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.0000 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.6812 for XGBoost
# XGBoost - Completed in 1.93 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.4066469877239576), np.float64(0.10755542464934445)), 'precision': (np.float64(0.24882547127237617), np.float64(0.05175881162072394)), 'recall': (np.float64(0.7424911768285263), np.float64(0.04865426277353556)), 'f1': (np.float64(0.3674860962038739), np.float64(0.055291215592339904))}
#
# Evaluating LightGBM on Image dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.4712 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.0000 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.6812 for LightGBM
# LightGBM - Completed in 37.98 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.549474862754449), np.float64(0.024175604426892684)), 'precision': (np.float64(0.28750157868629267), np.float64(0.026526675643189477)), 'recall': (np.float64(0.6603626627723013), np.float64(0.04094849465176489)), 'f1': (np.float64(0.39997721218217364), np.float64(0.030396452447288308))}
#
# Evaluating SVM on Image dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 3.28 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.7506564215569388), np.float64(0.02853724472886439)), 'precision': (np.float64(0.46202452535130617), np.float64(0.016484029897522748)), 'recall': (np.float64(0.5357632550403634), np.float64(0.057868175445014124)), 'f1': (np.float64(0.4941118270271143), np.float64(0.022614043817958677))}
#
# Starting Nested Cross-Validation for RadiomicsOnly Dataset
#
# Starting Nested CV for RadiomicsOnly dataset...
#
# Evaluating Logistic Regression on RadiomicsOnly dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.47 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.580952380952381), np.float64(0.03563483225498993)), 'precision': (np.float64(0.31179582944288825), np.float64(0.03113239837172267)), 'recall': (np.float64(0.6795112781954886), np.float64(0.11703297953785577)), 'f1': (np.float64(0.42698412698412697), np.float64(0.05221233080443977))}
#
# Evaluating Random Forest on RadiomicsOnly dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.09 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7095238095238096), np.float64(0.06834619092574916)), 'precision': (np.float64(0.3748196248196248), np.float64(0.1850033933380733)), 'recall': (np.float64(0.27459273182957394), np.float64(0.09590790750607561)), 'f1': (np.float64(0.3062517062517063), np.float64(0.11903966462649893))}
#
# Evaluating XGBoost on RadiomicsOnly dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for XGBoost
# XGBoost - Completed in 1.41 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.3333333333333333), np.float64(0.04096345365258395)), 'precision': (np.float64(0.24428344162689516), np.float64(0.03255220902863043)), 'recall': (np.float64(0.8928571428571429), np.float64(0.10514001031342675)), 'f1': (np.float64(0.38245768063706237), np.float64(0.04615057220148944))}
#
# Evaluating LightGBM on RadiomicsOnly dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for LightGBM
# LightGBM - Completed in 4.01 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.5285714285714286), np.float64(0.06172133998483679)), 'precision': (np.float64(0.2921233238306409), np.float64(0.03413439326169019)), 'recall': (np.float64(0.7158521303258145), np.float64(0.06726913454706149)), 'f1': (np.float64(0.41476707642121174), np.float64(0.045214892788628724))}
#
# Evaluating SVM on RadiomicsOnly dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 0.47 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6380952380952382), np.float64(0.05512303287042964)), 'precision': (np.float64(0.36123058542413383), np.float64(0.0316064321670354)), 'recall': (np.float64(0.7221177944862155), np.float64(0.09848958410485407)), 'f1': (np.float64(0.48123791102514507), np.float64(0.04932668347078917))}
#
# Starting Nested Cross-Validation for ClinicalRadiomics Dataset
#
# Starting Nested CV for ClinicalRadiomics dataset...
#
# Evaluating Logistic Regression on ClinicalRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.32 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.6523809523809524), np.float64(0.006734350297014714)), 'precision': (np.float64(0.3708048224177256), np.float64(0.038792639074154846)), 'recall': (np.float64(0.7128759398496242), np.float64(0.02016848095288996)), 'f1': (np.float64(0.4870306997966572), np.float64(0.036784769649952705))}
#
# Evaluating Random Forest on ClinicalRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 1.79 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7666666666666667), np.float64(0.052596957224701285)), 'precision': (np.float64(0.5294117647058824), np.float64(0.14229765396782512)), 'recall': (np.float64(0.37484335839599), np.float64(0.10766395761779364)), 'f1': (np.float64(0.4260454002389486), np.float64(0.09687827198262519))}
#
# Evaluating XGBoost on ClinicalRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for XGBoost
# XGBoost - Completed in 1.05 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.6285714285714286), np.float64(0.10101525445522105)), 'precision': (np.float64(0.3636868686868686), np.float64(0.0758181912382546)), 'recall': (np.float64(0.6572681704260651), np.float64(0.0705715191807335)), 'f1': (np.float64(0.4577221228384019), np.float64(0.04565173041486557))}
#
# Evaluating LightGBM on ClinicalRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.2424 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6667 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.0000 for LightGBM
# LightGBM - Completed in 4.72 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.5476190476190476), np.float64(0.03749527559053244)), 'precision': (np.float64(0.29181929181929184), np.float64(0.03169903537422997)), 'recall': (np.float64(0.6679197994987468), np.float64(0.12264067297904102)), 'f1': (np.float64(0.4032482847341338), np.float64(0.04665426181994866))}
#
# Evaluating SVM on ClinicalRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 0.47 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6523809523809524), np.float64(0.013468700594029428)), 'precision': (np.float64(0.3741935483870968), np.float64(0.043314703932649246)), 'recall': (np.float64(0.7194548872180451), np.float64(0.07395109682726327)), 'f1': (np.float64(0.4882955546284707), np.float64(0.031009288331431302))}
#
# Starting Nested Cross-Validation for CombinedRadiomics Dataset
#
# Starting Nested CV for CombinedRadiomics dataset...
#
# Evaluating Logistic Regression on CombinedRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.42 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.46280049444028754), np.float64(0.06547577364975007)), 'precision': (np.float64(0.2858169465017382), np.float64(0.04336476637285855)), 'recall': (np.float64(0.8849843819723336), np.float64(0.027600918311238315)), 'f1': (np.float64(0.4302679677835557), np.float64(0.04875696366441428))}
#
# Evaluating Random Forest on CombinedRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 3.29 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7613366332563168), np.float64(0.011086193429749923)), 'precision': (np.float64(0.5925925925925926), np.float64(0.2916299212596967)), 'recall': (np.float64(0.19311589793517503), np.float64(0.05825490276387579)), 'f1': (np.float64(0.26092342342342345), np.float64(0.04640104280066564))}
#
# Evaluating XGBoost on CombinedRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.4712 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.0000 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.6812 for XGBoost
# XGBoost - Completed in 0.90 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.5614562691684688), np.float64(0.07993600932678535)), 'precision': (np.float64(0.28899937396596703), np.float64(0.032878733928357405)), 'recall': (np.float64(0.6239300636890999), np.float64(0.11899372935327271)), 'f1': (np.float64(0.3939606756237794), np.float64(0.051521436124839996))}
#
# Evaluating LightGBM on CombinedRadiomics dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.4712 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.0000 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 3.6812 for LightGBM
# LightGBM - Completed in 17.26 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.660557423867433), np.float64(0.02839833889115463)), 'precision': (np.float64(0.2609710550887021), np.float64(0.051881677803204636)), 'recall': (np.float64(0.26718997200924915), np.float64(0.047103219514410245)), 'f1': (np.float64(0.26400560224089636), np.float64(0.04954038427107423))}
#
# Evaluating SVM on CombinedRadiomics dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# /Users/mohammad.enayet/Documents/Personal/Research/sparkMLproject/myenv/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# SVM - Completed in 2.86 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6221574479864714), np.float64(0.035909041479357084)), 'precision': (np.float64(0.3361327709404876), np.float64(0.018233355195205515)), 'recall': (np.float64(0.6827309236947792), np.float64(0.1169610485740654)), 'f1': (np.float64(0.4486852137599193), np.float64(0.03864958964460582))}
#
# Starting Nested Cross-Validation for CombinedSelected Dataset
#
# Starting Nested CV for CombinedSelected dataset...
#
# Evaluating Logistic Regression on CombinedSelected dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Logistic Regression - Completed in 0.33 seconds
# Aggregated Scores for Logistic Regression: {'accuracy': (np.float64(0.676911572125876), np.float64(0.06224123303538267)), 'precision': (np.float64(0.37460475385705716), np.float64(0.012763858996889617)), 'recall': (np.float64(0.6026207989023711), np.float64(0.06734672815873377)), 'f1': (np.float64(0.4607941194044775), np.float64(0.026309416079686215))}
#
# Evaluating Random Forest on CombinedSelected dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# Random Forest - Completed in 2.63 seconds
# Aggregated Scores for Random Forest: {'accuracy': (np.float64(0.7046807390685329), np.float64(0.046217303167881724)), 'precision': (np.float64(0.3270164513430616), np.float64(0.02107001612614278)), 'recall': (np.float64(0.2710053484130049), np.float64(0.03926713181962264)), 'f1': (np.float64(0.2939654128163673), np.float64(0.021275432753315237))}
#
# Evaluating XGBoost on CombinedSelected dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.6443 for XGBoost
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6325 for XGBoost
#   Outer Fold 3/3
# Computed scale_pos_weight: 2.8855 for XGBoost
# XGBoost - Completed in 1.85 seconds
# Aggregated Scores for XGBoost: {'accuracy': (np.float64(0.6119173055003257), np.float64(0.020954253123666316)), 'precision': (np.float64(0.33221518328895266), np.float64(0.02612517802009205)), 'recall': (np.float64(0.7325888945039529), np.float64(0.2112999470241505)), 'f1': (np.float64(0.44927599633481985), np.float64(0.06218308493337627))}
#
# Evaluating LightGBM on CombinedSelected dataset...
#   Outer Fold 1/3
# Computed scale_pos_weight: 3.6443 for LightGBM
#   Outer Fold 2/3
# Computed scale_pos_weight: 3.6325 for LightGBM
#   Outer Fold 3/3
# Computed scale_pos_weight: 2.8855 for LightGBM
# LightGBM - Completed in 36.10 seconds
# Aggregated Scores for LightGBM: {'accuracy': (np.float64(0.657060000742734), np.float64(0.06665410726970263)), 'precision': (np.float64(0.3503509269386047), np.float64(0.024635784494755505)), 'recall': (np.float64(0.5636178588617105), np.float64(0.051780038921972193)), 'f1': (np.float64(0.4296804748875982), np.float64(0.012846919508763814))}
#
# Evaluating SVM on CombinedSelected dataset...
#   Outer Fold 1/3
#   Outer Fold 2/3
#   Outer Fold 3/3
# SVM - Completed in 2.71 seconds
# Aggregated Scores for SVM: {'accuracy': (np.float64(0.6699760553826101), np.float64(0.04526136647878038)), 'precision': (np.float64(0.3859406236447028), np.float64(0.0485144830025405)), 'recall': (np.float64(0.7352733766596148), np.float64(0.0671530894483241)), 'f1': (np.float64(0.5027089408134012), np.float64(0.03797102879523813))}

# %%
# Retrain Models on Entire Training Set Using Best Hyperparameters and Evaluate on Test Set

from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, confusion_matrix, classification_report)
from sklearn.base import clone

test_results = {}  # To store test set results

for dataset_name in data_splits.keys():
    print(f"\nRetraining and Evaluating Models for {dataset_name} Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test = data['y_test']
    groups_train = data['patient_ids_train']
    groups_test = data['patient_ids_test']
    
    # Reset indices to ensure consistency
    X_train_full = X_train_full.reset_index(drop=True)
    y_train_full = y_train_full.reset_index(drop=True)
    X_test_full = X_test_full.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)
    
    # Get nested CV results for the current dataset
    nested_results = nested_cv_results[dataset_name]
    cv_results_all = nested_results['cv_results_all']
    
    test_results[dataset_name] = {}  # Initialize dictionary to store test results for each classifier
    
    for classifier_name in classifiers.keys():
        print(f"\nRetraining {classifier_name} on {dataset_name} dataset...")
        
        # Get cross-validation results for the current classifier
        cv_results = cv_results_all[classifier_name]
        
        # Find the hyperparameters with the best mean_test_score (which is F1 score)
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier with default parameters
        default_classifier = classifiers[classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)

        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)
        
        # Handle compatibility between solver and penalty for Logistic Regression
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_full, y_train_full)
        
        # Predict on the test set
        y_pred = pipeline.predict(X_test_full)
        
        # Get predicted probabilities if available
        y_proba = pipeline.predict_proba(X_test_full)[:, 1] if hasattr(pipeline, "predict_proba") else None
        
        # Compute performance metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, zero_division=0)
        recall = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, zero_division=0)
        
        # Store the test results
        test_results[dataset_name][classifier_name] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"{classifier_name} Test Results on {dataset_name} Dataset:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        if roc_auc is not None:
            print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)
# Out:
# Retraining and Evaluating Models for Combined Dataset
#
# Retraining Logistic Regression on Combined dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on Combined Dataset:
# Accuracy: 0.7084
# Precision: 0.4138
# Recall: 0.6942
# F1 Score: 0.5185
# ROC AUC Score: 0.7720
# Confusion Matrix:
# [[295 119]
#  [ 37  84]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79       414
#            1       0.41      0.69      0.52       121
#
#     accuracy                           0.71       535
#    macro avg       0.65      0.70      0.65       535
# weighted avg       0.78      0.71      0.73       535
#
#
# Retraining Random Forest on Combined dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on Combined Dataset:
# Accuracy: 0.7290
# Precision: 0.4318
# Recall: 0.6281
# F1 Score: 0.5118
# ROC AUC Score: 0.7705
# Confusion Matrix:
# [[314 100]
#  [ 45  76]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81       414
#            1       0.43      0.63      0.51       121
#
#     accuracy                           0.73       535
#    macro avg       0.65      0.69      0.66       535
# weighted avg       0.77      0.73      0.74       535
#
#
# Retraining XGBoost on Combined dataset...
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on Combined Dataset:
# Accuracy: 0.7009
# Precision: 0.4039
# Recall: 0.6777
# F1 Score: 0.5062
# ROC AUC Score: 0.7733
# Confusion Matrix:
# [[293 121]
#  [ 39  82]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79       414
#            1       0.40      0.68      0.51       121
#
#     accuracy                           0.70       535
#    macro avg       0.64      0.69      0.65       535
# weighted avg       0.77      0.70      0.72       535
#
#
# Retraining LightGBM on Combined dataset...
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on Combined Dataset:
# Accuracy: 0.6654
# Precision: 0.3739
# Recall: 0.7107
# F1 Score: 0.4900
# ROC AUC Score: 0.7213
# Confusion Matrix:
# [[270 144]
#  [ 35  86]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.65      0.75       414
#            1       0.37      0.71      0.49       121
#
#     accuracy                           0.67       535
#    macro avg       0.63      0.68      0.62       535
# weighted avg       0.77      0.67      0.69       535
#
#
# Retraining SVM on Combined dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on Combined Dataset:
# Accuracy: 0.6654
# Precision: 0.3858
# Recall: 0.8099
# F1 Score: 0.5227
# ROC AUC Score: 0.7872
# Confusion Matrix:
# [[258 156]
#  [ 23  98]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.62      0.74       414
#            1       0.39      0.81      0.52       121
#
#     accuracy                           0.67       535
#    macro avg       0.65      0.72      0.63       535
# weighted avg       0.80      0.67      0.69       535
#
#
# Retraining and Evaluating Models for Clinical Dataset
#
# Retraining Logistic Regression on Clinical dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on Clinical Dataset:
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.6961
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Retraining Random Forest on Clinical dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on Clinical Dataset:
# Accuracy: 0.7170
# Precision: 0.4000
# Recall: 0.5000
# F1 Score: 0.4444
# ROC AUC Score: 0.6230
# Confusion Matrix:
# [[32  9]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81        41
#            1       0.40      0.50      0.44        12
#
#     accuracy                           0.72        53
#    macro avg       0.62      0.64      0.63        53
# weighted avg       0.74      0.72      0.73        53
#
#
# Retraining XGBoost on Clinical dataset...
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on Clinical Dataset:
# Accuracy: 0.6981
# Precision: 0.3889
# Recall: 0.5833
# F1 Score: 0.4667
# ROC AUC Score: 0.6006
# Confusion Matrix:
# [[30 11]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        41
#            1       0.39      0.58      0.47        12
#
#     accuracy                           0.70        53
#    macro avg       0.62      0.66      0.63        53
# weighted avg       0.75      0.70      0.72        53
#
#
# Retraining LightGBM on Clinical dataset...
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on Clinical Dataset:
# Accuracy: 0.4906
# Precision: 0.2581
# Recall: 0.6667
# F1 Score: 0.3721
# ROC AUC Score: 0.6514
# Confusion Matrix:
# [[18 23]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.44      0.57        41
#            1       0.26      0.67      0.37        12
#
#     accuracy                           0.49        53
#    macro avg       0.54      0.55      0.47        53
# weighted avg       0.69      0.49      0.53        53
#
#
# Retraining SVM on Clinical dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on Clinical Dataset:
# Accuracy: 0.5849
# Precision: 0.3077
# Recall: 0.6667
# F1 Score: 0.4211
# ROC AUC Score: 0.6900
# Confusion Matrix:
# [[23 18]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.56      0.68        41
#            1       0.31      0.67      0.42        12
#
#     accuracy                           0.58        53
#    macro avg       0.58      0.61      0.55        53
# weighted avg       0.73      0.58      0.62        53
#
#
# Retraining and Evaluating Models for Image Dataset
#
# Retraining Logistic Regression on Image dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on Image Dataset:
# Accuracy: 0.6542
# Precision: 0.3280
# Recall: 0.5041
# F1 Score: 0.3974
# ROC AUC Score: 0.6032
# Confusion Matrix:
# [[289 125]
#  [ 60  61]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76       414
#            1       0.33      0.50      0.40       121
#
#     accuracy                           0.65       535
#    macro avg       0.58      0.60      0.58       535
# weighted avg       0.71      0.65      0.68       535
#
#
# Retraining Random Forest on Image dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on Image Dataset:
# Accuracy: 0.6542
# Precision: 0.2681
# Recall: 0.3058
# F1 Score: 0.2857
# ROC AUC Score: 0.6120
# Confusion Matrix:
# [[313 101]
#  [ 84  37]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77       414
#            1       0.27      0.31      0.29       121
#
#     accuracy                           0.65       535
#    macro avg       0.53      0.53      0.53       535
# weighted avg       0.67      0.65      0.66       535
#
#
# Retraining XGBoost on Image dataset...
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on Image Dataset:
# Accuracy: 0.6579
# Precision: 0.3038
# Recall: 0.3967
# F1 Score: 0.3441
# ROC AUC Score: 0.6388
# Confusion Matrix:
# [[304 110]
#  [ 73  48]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77       414
#            1       0.30      0.40      0.34       121
#
#     accuracy                           0.66       535
#    macro avg       0.56      0.57      0.56       535
# weighted avg       0.69      0.66      0.67       535
#
#
# Retraining LightGBM on Image dataset...
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on Image Dataset:
# Accuracy: 0.5159
# Precision: 0.2669
# Recall: 0.6529
# F1 Score: 0.3789
# ROC AUC Score: 0.6034
# Confusion Matrix:
# [[197 217]
#  [ 42  79]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.48      0.60       414
#            1       0.27      0.65      0.38       121
#
#     accuracy                           0.52       535
#    macro avg       0.55      0.56      0.49       535
# weighted avg       0.70      0.52      0.55       535
#
#
# Retraining SVM on Image dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on Image Dataset:
# Accuracy: 0.6748
# Precision: 0.3245
# Recall: 0.4050
# F1 Score: 0.3603
# ROC AUC Score: 0.5935
# Confusion Matrix:
# [[312 102]
#  [ 72  49]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       414
#            1       0.32      0.40      0.36       121
#
#     accuracy                           0.67       535
#    macro avg       0.57      0.58      0.57       535
# weighted avg       0.70      0.67      0.69       535
#
#
# Retraining and Evaluating Models for RadiomicsOnly Dataset
#
# Retraining Logistic Regression on RadiomicsOnly dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.1887
# Precision: 0.1837
# Recall: 0.7500
# F1 Score: 0.2951
# ROC AUC Score: 0.3882
# Confusion Matrix:
# [[ 1 40]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.02      0.04        41
#            1       0.18      0.75      0.30        12
#
#     accuracy                           0.19        53
#    macro avg       0.22      0.39      0.17        53
# weighted avg       0.23      0.19      0.10        53
#
#
# Retraining Random Forest on RadiomicsOnly dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4258
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Retraining XGBoost on RadiomicsOnly dataset...
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5285
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Retraining LightGBM on RadiomicsOnly dataset...
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.3774
# Precision: 0.2667
# Recall: 1.0000
# F1 Score: 0.4211
# ROC AUC Score: 0.5904
# Confusion Matrix:
# [[ 8 33]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.33        41
#            1       0.27      1.00      0.42        12
#
#     accuracy                           0.38        53
#    macro avg       0.63      0.60      0.37        53
# weighted avg       0.83      0.38      0.35        53
#
#
# Retraining SVM on RadiomicsOnly dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on RadiomicsOnly Dataset:
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Retraining and Evaluating Models for ClinicalRadiomics Dataset
#
# Retraining Logistic Regression on ClinicalRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.6981
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4451
# Confusion Matrix:
# [[37  4]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.82        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.70        53
#    macro avg       0.38      0.45      0.41        53
# weighted avg       0.58      0.70      0.64        53
#
#
# Retraining Random Forest on ClinicalRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4004
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Retraining XGBoost on ClinicalRadiomics dataset...
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.4717
# Precision: 0.2647
# Recall: 0.7500
# F1 Score: 0.3913
# ROC AUC Score: 0.6352
# Confusion Matrix:
# [[16 25]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.39      0.53        41
#            1       0.26      0.75      0.39        12
#
#     accuracy                           0.47        53
#    macro avg       0.55      0.57      0.46        53
# weighted avg       0.71      0.47      0.50        53
#
#
# Retraining LightGBM on ClinicalRadiomics dataset...
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.2830
# Precision: 0.2292
# Recall: 0.9167
# F1 Score: 0.3667
# ROC AUC Score: 0.5030
# Confusion Matrix:
# [[ 4 37]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.10      0.17        41
#            1       0.23      0.92      0.37        12
#
#     accuracy                           0.28        53
#    macro avg       0.51      0.51      0.27        53
# weighted avg       0.67      0.28      0.22        53
#
#
# Retraining SVM on ClinicalRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on ClinicalRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Retraining and Evaluating Models for CombinedRadiomics Dataset
#
# Retraining Logistic Regression on CombinedRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5759
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Retraining Random Forest on CombinedRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.6099
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Retraining XGBoost on CombinedRadiomics dataset...
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.7551
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.6324
# Confusion Matrix:
# [[404  10]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.76       535
#    macro avg       0.38      0.49      0.43       535
# weighted avg       0.60      0.76      0.67       535
#
#
# Retraining LightGBM on CombinedRadiomics dataset...
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.7551
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4474
# Confusion Matrix:
# [[404  10]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.76       535
#    macro avg       0.38      0.49      0.43       535
# weighted avg       0.60      0.76      0.67       535
#
#
# Retraining SVM on CombinedRadiomics dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on CombinedRadiomics Dataset:
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Retraining and Evaluating Models for CombinedSelected Dataset
#
# Retraining Logistic Regression on CombinedSelected dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Test Results on CombinedSelected Dataset:
# Accuracy: 0.6748
# Precision: 0.3702
# Recall: 0.6417
# F1 Score: 0.4695
# ROC AUC Score: 0.7246
# Confusion Matrix:
# [[284 131]
#  [ 43  77]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.68      0.77       415
#            1       0.37      0.64      0.47       120
#
#     accuracy                           0.67       535
#    macro avg       0.62      0.66      0.62       535
# weighted avg       0.76      0.67      0.70       535
#
#
# Retraining Random Forest on CombinedSelected dataset...
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Test Results on CombinedSelected Dataset:
# Accuracy: 0.7589
# Precision: 0.4430
# Recall: 0.2917
# F1 Score: 0.3518
# ROC AUC Score: 0.6899
# Confusion Matrix:
# [[371  44]
#  [ 85  35]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       415
#            1       0.44      0.29      0.35       120
#
#     accuracy                           0.76       535
#    macro avg       0.63      0.59      0.60       535
# weighted avg       0.73      0.76      0.74       535
#
#
# Retraining XGBoost on CombinedSelected dataset...
# Computed scale_pos_weight: 3.3570 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Test Results on CombinedSelected Dataset:
# Accuracy: 0.7103
# Precision: 0.3759
# Recall: 0.4417
# F1 Score: 0.4061
# ROC AUC Score: 0.6842
# Confusion Matrix:
# [[327  88]
#  [ 67  53]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81       415
#            1       0.38      0.44      0.41       120
#
#     accuracy                           0.71       535
#    macro avg       0.60      0.61      0.61       535
# weighted avg       0.73      0.71      0.72       535
#
#
# Retraining LightGBM on CombinedSelected dataset...
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Test Results on CombinedSelected Dataset:
# Accuracy: 0.6710
# Precision: 0.3427
# Recall: 0.5083
# F1 Score: 0.4094
# ROC AUC Score: 0.6721
# Confusion Matrix:
# [[298 117]
#  [ 59  61]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77       415
#            1       0.34      0.51      0.41       120
#
#     accuracy                           0.67       535
#    macro avg       0.59      0.61      0.59       535
# weighted avg       0.72      0.67      0.69       535
#
#
# Retraining SVM on CombinedSelected dataset...
#
# Applying SMOTE to balance the classes in the training data...
# SVM Test Results on CombinedSelected Dataset:
# Accuracy: 0.6860
# Precision: 0.3846
# Recall: 0.6667
# F1 Score: 0.4878
# ROC AUC Score: 0.7406
# Confusion Matrix:
# [[287 128]
#  [ 40  80]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.77       415
#            1       0.38      0.67      0.49       120
#
#     accuracy                           0.69       535
#    macro avg       0.63      0.68      0.63       535
# weighted avg       0.77      0.69      0.71       535

# %%
# Displaying Comprehensive Performance Metrics for Each Model on Test Set

for dataset_name, classifiers_results in test_results.items():
    print(f"\nTest Results for {dataset_name} Dataset:")
    for classifier_name, metrics in classifiers_results.items():
        print(f"\nClassifier: {classifier_name}")
        print(f"Accuracy: {metrics['accuracy']:.4f}")
        print(f"Precision: {metrics['precision']:.4f}")
        print(f"Recall: {metrics['recall']:.4f}")
        print(f"F1 Score: {metrics['f1']:.4f}")
        if metrics['roc_auc'] is not None:
            print(f"ROC AUC Score: {metrics['roc_auc']:.4f}")
        print("Confusion Matrix:")
        print(metrics['confusion_matrix'])
        print("Classification Report:")
        print(metrics['classification_report'])
# Out:
# Test Results for Combined Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.7084
# Precision: 0.4138
# Recall: 0.6942
# F1 Score: 0.5185
# ROC AUC Score: 0.7720
# Confusion Matrix:
# [[295 119]
#  [ 37  84]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.71      0.79       414
#            1       0.41      0.69      0.52       121
#
#     accuracy                           0.71       535
#    macro avg       0.65      0.70      0.65       535
# weighted avg       0.78      0.71      0.73       535
#
#
# Classifier: Random Forest
# Accuracy: 0.7290
# Precision: 0.4318
# Recall: 0.6281
# F1 Score: 0.5118
# ROC AUC Score: 0.7705
# Confusion Matrix:
# [[314 100]
#  [ 45  76]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81       414
#            1       0.43      0.63      0.51       121
#
#     accuracy                           0.73       535
#    macro avg       0.65      0.69      0.66       535
# weighted avg       0.77      0.73      0.74       535
#
#
# Classifier: XGBoost
# Accuracy: 0.7009
# Precision: 0.4039
# Recall: 0.6777
# F1 Score: 0.5062
# ROC AUC Score: 0.7733
# Confusion Matrix:
# [[293 121]
#  [ 39  82]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79       414
#            1       0.40      0.68      0.51       121
#
#     accuracy                           0.70       535
#    macro avg       0.64      0.69      0.65       535
# weighted avg       0.77      0.70      0.72       535
#
#
# Classifier: LightGBM
# Accuracy: 0.6654
# Precision: 0.3739
# Recall: 0.7107
# F1 Score: 0.4900
# ROC AUC Score: 0.7213
# Confusion Matrix:
# [[270 144]
#  [ 35  86]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.65      0.75       414
#            1       0.37      0.71      0.49       121
#
#     accuracy                           0.67       535
#    macro avg       0.63      0.68      0.62       535
# weighted avg       0.77      0.67      0.69       535
#
#
# Classifier: SVM
# Accuracy: 0.6654
# Precision: 0.3858
# Recall: 0.8099
# F1 Score: 0.5227
# ROC AUC Score: 0.7872
# Confusion Matrix:
# [[258 156]
#  [ 23  98]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.62      0.74       414
#            1       0.39      0.81      0.52       121
#
#     accuracy                           0.67       535
#    macro avg       0.65      0.72      0.63       535
# weighted avg       0.80      0.67      0.69       535
#
#
# Test Results for Clinical Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.6961
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Classifier: Random Forest
# Accuracy: 0.7170
# Precision: 0.4000
# Recall: 0.5000
# F1 Score: 0.4444
# ROC AUC Score: 0.6230
# Confusion Matrix:
# [[32  9]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81        41
#            1       0.40      0.50      0.44        12
#
#     accuracy                           0.72        53
#    macro avg       0.62      0.64      0.63        53
# weighted avg       0.74      0.72      0.73        53
#
#
# Classifier: XGBoost
# Accuracy: 0.6981
# Precision: 0.3889
# Recall: 0.5833
# F1 Score: 0.4667
# ROC AUC Score: 0.6006
# Confusion Matrix:
# [[30 11]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        41
#            1       0.39      0.58      0.47        12
#
#     accuracy                           0.70        53
#    macro avg       0.62      0.66      0.63        53
# weighted avg       0.75      0.70      0.72        53
#
#
# Classifier: LightGBM
# Accuracy: 0.4906
# Precision: 0.2581
# Recall: 0.6667
# F1 Score: 0.3721
# ROC AUC Score: 0.6514
# Confusion Matrix:
# [[18 23]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.44      0.57        41
#            1       0.26      0.67      0.37        12
#
#     accuracy                           0.49        53
#    macro avg       0.54      0.55      0.47        53
# weighted avg       0.69      0.49      0.53        53
#
#
# Classifier: SVM
# Accuracy: 0.5849
# Precision: 0.3077
# Recall: 0.6667
# F1 Score: 0.4211
# ROC AUC Score: 0.6900
# Confusion Matrix:
# [[23 18]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.56      0.68        41
#            1       0.31      0.67      0.42        12
#
#     accuracy                           0.58        53
#    macro avg       0.58      0.61      0.55        53
# weighted avg       0.73      0.58      0.62        53
#
#
# Test Results for Image Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.6542
# Precision: 0.3280
# Recall: 0.5041
# F1 Score: 0.3974
# ROC AUC Score: 0.6032
# Confusion Matrix:
# [[289 125]
#  [ 60  61]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76       414
#            1       0.33      0.50      0.40       121
#
#     accuracy                           0.65       535
#    macro avg       0.58      0.60      0.58       535
# weighted avg       0.71      0.65      0.68       535
#
#
# Classifier: Random Forest
# Accuracy: 0.6542
# Precision: 0.2681
# Recall: 0.3058
# F1 Score: 0.2857
# ROC AUC Score: 0.6120
# Confusion Matrix:
# [[313 101]
#  [ 84  37]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77       414
#            1       0.27      0.31      0.29       121
#
#     accuracy                           0.65       535
#    macro avg       0.53      0.53      0.53       535
# weighted avg       0.67      0.65      0.66       535
#
#
# Classifier: XGBoost
# Accuracy: 0.6579
# Precision: 0.3038
# Recall: 0.3967
# F1 Score: 0.3441
# ROC AUC Score: 0.6388
# Confusion Matrix:
# [[304 110]
#  [ 73  48]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77       414
#            1       0.30      0.40      0.34       121
#
#     accuracy                           0.66       535
#    macro avg       0.56      0.57      0.56       535
# weighted avg       0.69      0.66      0.67       535
#
#
# Classifier: LightGBM
# Accuracy: 0.5159
# Precision: 0.2669
# Recall: 0.6529
# F1 Score: 0.3789
# ROC AUC Score: 0.6034
# Confusion Matrix:
# [[197 217]
#  [ 42  79]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.48      0.60       414
#            1       0.27      0.65      0.38       121
#
#     accuracy                           0.52       535
#    macro avg       0.55      0.56      0.49       535
# weighted avg       0.70      0.52      0.55       535
#
#
# Classifier: SVM
# Accuracy: 0.6748
# Precision: 0.3245
# Recall: 0.4050
# F1 Score: 0.3603
# ROC AUC Score: 0.5935
# Confusion Matrix:
# [[312 102]
#  [ 72  49]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78       414
#            1       0.32      0.40      0.36       121
#
#     accuracy                           0.67       535
#    macro avg       0.57      0.58      0.57       535
# weighted avg       0.70      0.67      0.69       535
#
#
# Test Results for RadiomicsOnly Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.1887
# Precision: 0.1837
# Recall: 0.7500
# F1 Score: 0.2951
# ROC AUC Score: 0.3882
# Confusion Matrix:
# [[ 1 40]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.25      0.02      0.04        41
#            1       0.18      0.75      0.30        12
#
#     accuracy                           0.19        53
#    macro avg       0.22      0.39      0.17        53
# weighted avg       0.23      0.19      0.10        53
#
#
# Classifier: Random Forest
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4258
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: XGBoost
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5285
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: LightGBM
# Accuracy: 0.3774
# Precision: 0.2667
# Recall: 1.0000
# F1 Score: 0.4211
# ROC AUC Score: 0.5904
# Confusion Matrix:
# [[ 8 33]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.33        41
#            1       0.27      1.00      0.42        12
#
#     accuracy                           0.38        53
#    macro avg       0.63      0.60      0.37        53
# weighted avg       0.83      0.38      0.35        53
#
#
# Classifier: SVM
# Accuracy: 0.2264
# Precision: 0.2264
# Recall: 1.0000
# F1 Score: 0.3692
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[ 0 41]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        41
#            1       0.23      1.00      0.37        12
#
#     accuracy                           0.23        53
#    macro avg       0.11      0.50      0.18        53
# weighted avg       0.05      0.23      0.08        53
#
#
# Test Results for ClinicalRadiomics Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.6981
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4451
# Confusion Matrix:
# [[37  4]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.82        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.70        53
#    macro avg       0.38      0.45      0.41        53
# weighted avg       0.58      0.70      0.64        53
#
#
# Classifier: Random Forest
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4004
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: XGBoost
# Accuracy: 0.4717
# Precision: 0.2647
# Recall: 0.7500
# F1 Score: 0.3913
# ROC AUC Score: 0.6352
# Confusion Matrix:
# [[16 25]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.39      0.53        41
#            1       0.26      0.75      0.39        12
#
#     accuracy                           0.47        53
#    macro avg       0.55      0.57      0.46        53
# weighted avg       0.71      0.47      0.50        53
#
#
# Classifier: LightGBM
# Accuracy: 0.2830
# Precision: 0.2292
# Recall: 0.9167
# F1 Score: 0.3667
# ROC AUC Score: 0.5030
# Confusion Matrix:
# [[ 4 37]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.10      0.17        41
#            1       0.23      0.92      0.37        12
#
#     accuracy                           0.28        53
#    macro avg       0.51      0.51      0.27        53
# weighted avg       0.67      0.28      0.22        53
#
#
# Classifier: SVM
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Test Results for CombinedRadiomics Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5759
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Classifier: Random Forest
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.6099
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Classifier: XGBoost
# Accuracy: 0.7551
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.6324
# Confusion Matrix:
# [[404  10]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.76       535
#    macro avg       0.38      0.49      0.43       535
# weighted avg       0.60      0.76      0.67       535
#
#
# Classifier: LightGBM
# Accuracy: 0.7551
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.4474
# Confusion Matrix:
# [[404  10]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.76       535
#    macro avg       0.38      0.49      0.43       535
# weighted avg       0.60      0.76      0.67       535
#
#
# Classifier: SVM
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Test Results for CombinedSelected Dataset:
#
# Classifier: Logistic Regression
# Accuracy: 0.6748
# Precision: 0.3702
# Recall: 0.6417
# F1 Score: 0.4695
# ROC AUC Score: 0.7246
# Confusion Matrix:
# [[284 131]
#  [ 43  77]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.68      0.77       415
#            1       0.37      0.64      0.47       120
#
#     accuracy                           0.67       535
#    macro avg       0.62      0.66      0.62       535
# weighted avg       0.76      0.67      0.70       535
#
#
# Classifier: Random Forest
# Accuracy: 0.7589
# Precision: 0.4430
# Recall: 0.2917
# F1 Score: 0.3518
# ROC AUC Score: 0.6899
# Confusion Matrix:
# [[371  44]
#  [ 85  35]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       415
#            1       0.44      0.29      0.35       120
#
#     accuracy                           0.76       535
#    macro avg       0.63      0.59      0.60       535
# weighted avg       0.73      0.76      0.74       535
#
#
# Classifier: XGBoost
# Accuracy: 0.7103
# Precision: 0.3759
# Recall: 0.4417
# F1 Score: 0.4061
# ROC AUC Score: 0.6842
# Confusion Matrix:
# [[327  88]
#  [ 67  53]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81       415
#            1       0.38      0.44      0.41       120
#
#     accuracy                           0.71       535
#    macro avg       0.60      0.61      0.61       535
# weighted avg       0.73      0.71      0.72       535
#
#
# Classifier: LightGBM
# Accuracy: 0.6710
# Precision: 0.3427
# Recall: 0.5083
# F1 Score: 0.4094
# ROC AUC Score: 0.6721
# Confusion Matrix:
# [[298 117]
#  [ 59  61]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77       415
#            1       0.34      0.51      0.41       120
#
#     accuracy                           0.67       535
#    macro avg       0.59      0.61      0.59       535
# weighted avg       0.72      0.67      0.69       535
#
#
# Classifier: SVM
# Accuracy: 0.6860
# Precision: 0.3846
# Recall: 0.6667
# F1 Score: 0.4878
# ROC AUC Score: 0.7406
# Confusion Matrix:
# [[287 128]
#  [ 40  80]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.69      0.77       415
#            1       0.38      0.67      0.49       120
#
#     accuracy                           0.69       535
#    macro avg       0.63      0.68      0.63       535
# weighted avg       0.77      0.69      0.71       535

# %%
# Slice wise Youden's J Threshold prediction

import numpy as np
from sklearn.metrics import roc_curve

# Define a consistent suffix for adjusted classifiers
THRESHOLD_ADJUSTED_SUFFIX = ' (Threshold Adjusted)'

# Helper function to extract the base classifier name by removing any suffix in parentheses
def get_base_classifier_name(name):
    if '(' in name and ')' in name:
        return name.split('(')[0].strip()
    return name

# Function to find optimal threshold using Youden's J-statistic
def find_optimal_threshold(y_true, y_proba):
    fpr, tpr, thresholds = roc_curve(y_true, y_proba)
    J = tpr - fpr
    ix = np.argmax(J)
    optimal_threshold = thresholds[ix]
    print(f"Optimal Threshold (Youden's J): {optimal_threshold:.4f}")
    return optimal_threshold

# Apply threshold adjustment to each classifier on each dataset
for dataset_name in test_results.keys():
    print(f"\nAdjusting Thresholds for {dataset_name} Dataset:")
    classifier_names = list(test_results[dataset_name].keys())  # Get current classifier names
    for classifier_name in classifier_names:
        if THRESHOLD_ADJUSTED_SUFFIX in classifier_name:
            continue  # Skip already adjusted classifiers
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve the pipeline and test data
        data = data_splits[dataset_name]
        X_test_full = data['X_test_full']
        y_test = data['y_test']
        X_train_full = data['X_train_full']
        y_train_full = data['y_train_full']
        
        # Extract base classifier name
        base_classifier_name = get_base_classifier_name(classifier_name)
        
        # Get the best hyperparameters from nested_cv_results
        nested_results = nested_cv_results[dataset_name]
        cv_results_all = nested_results['cv_results_all']
        try:
            cv_results = cv_results_all[base_classifier_name]
        except KeyError:
            print(f"Error: '{base_classifier_name}' not found in cv_results_all for dataset '{dataset_name}'. Skipping threshold adjustment for this classifier.")
            continue
        
        # Find the hyperparameters with the best mean_test_score (F1 score)
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier from the classifiers dictionary
        default_classifier = classifiers[base_classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)
        
        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)

        # Handle compatibility between solver and penalty for Logistic Regression
        if base_classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        

        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Compute predicted probabilities
        y_proba = pipeline.predict_proba(X_test_full)[:, 1] if hasattr(pipeline, "predict_proba") else None
        
        # Check if y_proba is available
        if y_proba is None:
            print("Predicted probabilities not available. Skipping threshold adjustment.")
            continue
        
        # Find optimal threshold
        optimal_threshold = find_optimal_threshold(y_test, y_proba)
        
        # Make predictions with the optimal threshold
        y_pred_optimal = (y_proba >= optimal_threshold).astype(int)
        
        # Evaluate performance
        accuracy = accuracy_score(y_test, y_pred_optimal)
        precision = precision_score(y_test, y_pred_optimal, zero_division=0)
        recall = recall_score(y_test, y_pred_optimal)
        f1 = f1_score(y_test, y_pred_optimal)
        roc_auc = roc_auc_score(y_test, y_proba)
        conf_matrix = confusion_matrix(y_test, y_pred_optimal)
        class_report = classification_report(y_test, y_pred_optimal, zero_division=0)
        
        # Define the adjusted classifier name
        adjusted_classifier_name = f"{base_classifier_name}{THRESHOLD_ADJUSTED_SUFFIX}"
        
        # Update the results with adjusted threshold
        test_results[dataset_name][adjusted_classifier_name] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"Adjusted Threshold Test Results:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)
# Out:
# Adjusting Thresholds for Combined Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.4307
# Adjusted Threshold Test Results:
# Accuracy: 0.6710
# Precision: 0.3878
# Recall: 0.7851
# F1 Score: 0.5191
# ROC AUC Score: 0.7689
# Confusion Matrix:
# [[264 150]
#  [ 26  95]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.64      0.75       414
#            1       0.39      0.79      0.52       121
#
#     accuracy                           0.67       535
#    macro avg       0.65      0.71      0.63       535
# weighted avg       0.79      0.67      0.70       535
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.4877
# Adjusted Threshold Test Results:
# Accuracy: 0.7514
# Precision: 0.4647
# Recall: 0.6529
# F1 Score: 0.5430
# ROC AUC Score: 0.7847
# Confusion Matrix:
# [[323  91]
#  [ 42  79]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83       414
#            1       0.46      0.65      0.54       121
#
#     accuracy                           0.75       535
#    macro avg       0.67      0.72      0.69       535
# weighted avg       0.79      0.75      0.76       535
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7140
# Adjusted Threshold Test Results:
# Accuracy: 0.7140
# Precision: 0.4259
# Recall: 0.7603
# F1 Score: 0.5460
# ROC AUC Score: 0.7976
# Confusion Matrix:
# [[290 124]
#  [ 29  92]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79       414
#            1       0.43      0.76      0.55       121
#
#     accuracy                           0.71       535
#    macro avg       0.67      0.73      0.67       535
# weighted avg       0.80      0.71      0.74       535
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.2692
# Adjusted Threshold Test Results:
# Accuracy: 0.5720
# Precision: 0.3312
# Recall: 0.8760
# F1 Score: 0.4807
# ROC AUC Score: 0.7055
# Confusion Matrix:
# [[200 214]
#  [ 15 106]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.48      0.64       414
#            1       0.33      0.88      0.48       121
#
#     accuracy                           0.57       535
#    macro avg       0.63      0.68      0.56       535
# weighted avg       0.79      0.57      0.60       535
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5964
# Adjusted Threshold Test Results:
# Accuracy: 0.7720
# Precision: 0.4967
# Recall: 0.6281
# F1 Score: 0.5547
# ROC AUC Score: 0.7822
# Confusion Matrix:
# [[337  77]
#  [ 45  76]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.85       414
#            1       0.50      0.63      0.55       121
#
#     accuracy                           0.77       535
#    macro avg       0.69      0.72      0.70       535
# weighted avg       0.80      0.77      0.78       535
#
#
# Adjusting Thresholds for Clinical Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.6439
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.7104
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.3328
# Adjusted Threshold Test Results:
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.6433
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7301
# Adjusted Threshold Test Results:
# Accuracy: 0.7547
# Precision: 0.4615
# Recall: 0.5000
# F1 Score: 0.4800
# ROC AUC Score: 0.6087
# Confusion Matrix:
# [[34  7]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        41
#            1       0.46      0.50      0.48        12
#
#     accuracy                           0.75        53
#    macro avg       0.66      0.66      0.66        53
# weighted avg       0.76      0.75      0.76        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7192
# Adjusted Threshold Test Results:
# Accuracy: 0.7358
# Precision: 0.4375
# Recall: 0.5833
# F1 Score: 0.5000
# ROC AUC Score: 0.6433
# Confusion Matrix:
# [[32  9]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        41
#            1       0.44      0.58      0.50        12
#
#     accuracy                           0.74        53
#    macro avg       0.65      0.68      0.66        53
# weighted avg       0.77      0.74      0.75        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.6836
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.6941
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Adjusting Thresholds for Image Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5934
# Adjusted Threshold Test Results:
# Accuracy: 0.7159
# Precision: 0.3835
# Recall: 0.4215
# F1 Score: 0.4016
# ROC AUC Score: 0.6059
# Confusion Matrix:
# [[332  82]
#  [ 70  51]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.81       414
#            1       0.38      0.42      0.40       121
#
#     accuracy                           0.72       535
#    macro avg       0.60      0.61      0.61       535
# weighted avg       0.73      0.72      0.72       535
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.1802
# Adjusted Threshold Test Results:
# Accuracy: 0.4393
# Precision: 0.2790
# Recall: 0.9339
# F1 Score: 0.4297
# ROC AUC Score: 0.6121
# Confusion Matrix:
# [[122 292]
#  [  8 113]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.29      0.45       414
#            1       0.28      0.93      0.43       121
#
#     accuracy                           0.44       535
#    macro avg       0.61      0.61      0.44       535
# weighted avg       0.79      0.44      0.44       535
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5232
# Adjusted Threshold Test Results:
# Accuracy: 0.4841
# Precision: 0.2865
# Recall: 0.8595
# F1 Score: 0.4298
# ROC AUC Score: 0.6296
# Confusion Matrix:
# [[155 259]
#  [ 17 104]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.37      0.53       414
#            1       0.29      0.86      0.43       121
#
#     accuracy                           0.48       535
#    macro avg       0.59      0.62      0.48       535
# weighted avg       0.76      0.48      0.51       535
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.3539
# Adjusted Threshold Test Results:
# Accuracy: 0.4748
# Precision: 0.2727
# Recall: 0.7934
# F1 Score: 0.4059
# ROC AUC Score: 0.5968
# Confusion Matrix:
# [[158 256]
#  [ 25  96]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.38      0.53       414
#            1       0.27      0.79      0.41       121
#
#     accuracy                           0.47       535
#    macro avg       0.57      0.59      0.47       535
# weighted avg       0.73      0.47      0.50       535
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5285
# Adjusted Threshold Test Results:
# Accuracy: 0.6710
# Precision: 0.3410
# Recall: 0.4876
# F1 Score: 0.4014
# ROC AUC Score: 0.6010
# Confusion Matrix:
# [[300 114]
#  [ 62  59]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77       414
#            1       0.34      0.49      0.40       121
#
#     accuracy                           0.67       535
#    macro avg       0.58      0.61      0.59       535
# weighted avg       0.72      0.67      0.69       535
#
#
# Adjusting Thresholds for RadiomicsOnly Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.3354
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.2720
# Adjusted Threshold Test Results:
# Accuracy: 0.4151
# Precision: 0.2683
# Recall: 0.9167
# F1 Score: 0.4151
# ROC AUC Score: 0.5508
# Confusion Matrix:
# [[11 30]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.27      0.42        41
#            1       0.27      0.92      0.42        12
#
#     accuracy                           0.42        53
#    macro avg       0.59      0.59      0.42        53
# weighted avg       0.77      0.42      0.42        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.3791
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.3958
# Adjusted Threshold Test Results:
# Accuracy: 0.5094
# Precision: 0.3056
# Recall: 0.9167
# F1 Score: 0.4583
# ROC AUC Score: 0.5701
# Confusion Matrix:
# [[16 25]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.39      0.55        41
#            1       0.31      0.92      0.46        12
#
#     accuracy                           0.51        53
#    macro avg       0.62      0.65      0.51        53
# weighted avg       0.80      0.51      0.53        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Adjusting Thresholds for ClinicalRadiomics Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.0000
# Adjusted Threshold Test Results:
# Accuracy: 0.4906
# Precision: 0.2581
# Recall: 0.6667
# F1 Score: 0.3721
# ROC AUC Score: 0.4715
# Confusion Matrix:
# [[18 23]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.44      0.57        41
#            1       0.26      0.67      0.37        12
#
#     accuracy                           0.49        53
#    macro avg       0.54      0.55      0.47        53
# weighted avg       0.69      0.49      0.53        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.2233
# Adjusted Threshold Test Results:
# Accuracy: 0.3208
# Precision: 0.2500
# Recall: 1.0000
# F1 Score: 0.4000
# ROC AUC Score: 0.4654
# Confusion Matrix:
# [[ 5 36]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.12      0.22        41
#            1       0.25      1.00      0.40        12
#
#     accuracy                           0.32        53
#    macro avg       0.62      0.56      0.31        53
# weighted avg       0.83      0.32      0.26        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.7989
# Adjusted Threshold Test Results:
# Accuracy: 0.7925
# Precision: 1.0000
# Recall: 0.0833
# F1 Score: 0.1538
# ROC AUC Score: 0.4136
# Confusion Matrix:
# [[41  0]
#  [11  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.4411
# Adjusted Threshold Test Results:
# Accuracy: 0.4717
# Precision: 0.2778
# Recall: 0.8333
# F1 Score: 0.4167
# ROC AUC Score: 0.4868
# Confusion Matrix:
# [[15 26]
#  [ 2 10]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.37      0.52        41
#            1       0.28      0.83      0.42        12
#
#     accuracy                           0.47        53
#    macro avg       0.58      0.60      0.47        53
# weighted avg       0.75      0.47      0.49        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Adjusting Thresholds for CombinedRadiomics Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.0000
# Adjusted Threshold Test Results:
# Accuracy: 0.4523
# Precision: 0.2923
# Recall: 1.0000
# F1 Score: 0.4523
# ROC AUC Score: 0.5759
# Confusion Matrix:
# [[121 293]
#  [  0 121]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.29      0.45       414
#            1       0.29      1.00      0.45       121
#
#     accuracy                           0.45       535
#    macro avg       0.65      0.65      0.45       535
# weighted avg       0.84      0.45      0.45       535
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.2893
# Adjusted Threshold Test Results:
# Accuracy: 0.8131
# Precision: 0.6721
# Recall: 0.3388
# F1 Score: 0.4505
# ROC AUC Score: 0.5902
# Confusion Matrix:
# [[394  20]
#  [ 80  41]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89       414
#            1       0.67      0.34      0.45       121
#
#     accuracy                           0.81       535
#    macro avg       0.75      0.65      0.67       535
# weighted avg       0.80      0.81      0.79       535
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.3194
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.2780
# Adjusted Threshold Test Results:
# Accuracy: 0.7925
# Precision: 0.5543
# Recall: 0.4215
# F1 Score: 0.4789
# ROC AUC Score: 0.5689
# Confusion Matrix:
# [[373  41]
#  [ 70  51]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       414
#            1       0.55      0.42      0.48       121
#
#     accuracy                           0.79       535
#    macro avg       0.70      0.66      0.67       535
# weighted avg       0.78      0.79      0.78       535
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): inf
# Adjusted Threshold Test Results:
# Accuracy: 0.7738
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[414   0]
#  [121   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87       414
#            1       0.00      0.00      0.00       121
#
#     accuracy                           0.77       535
#    macro avg       0.39      0.50      0.44       535
# weighted avg       0.60      0.77      0.68       535
#
#
# Adjusting Thresholds for CombinedSelected Dataset:
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.3210
# Adjusted Threshold Test Results:
# Accuracy: 0.6430
# Precision: 0.3586
# Recall: 0.7500
# F1 Score: 0.4852
# ROC AUC Score: 0.7216
# Confusion Matrix:
# [[254 161]
#  [ 30  90]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.61      0.73       415
#            1       0.36      0.75      0.49       120
#
#     accuracy                           0.64       535
#    macro avg       0.63      0.68      0.61       535
# weighted avg       0.77      0.64      0.67       535
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.3780
# Adjusted Threshold Test Results:
# Accuracy: 0.7514
# Precision: 0.4564
# Recall: 0.5667
# F1 Score: 0.5056
# ROC AUC Score: 0.6932
# Confusion Matrix:
# [[334  81]
#  [ 52  68]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83       415
#            1       0.46      0.57      0.51       120
#
#     accuracy                           0.75       535
#    macro avg       0.66      0.69      0.67       535
# weighted avg       0.77      0.75      0.76       535
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3570 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.4358
# Adjusted Threshold Test Results:
# Accuracy: 0.7196
# Precision: 0.4211
# Recall: 0.6667
# F1 Score: 0.5161
# ROC AUC Score: 0.6834
# Confusion Matrix:
# [[305 110]
#  [ 40  80]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.73      0.80       415
#            1       0.42      0.67      0.52       120
#
#     accuracy                           0.72       535
#    macro avg       0.65      0.70      0.66       535
# weighted avg       0.78      0.72      0.74       535
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.5080
# Adjusted Threshold Test Results:
# Accuracy: 0.7271
# Precision: 0.4261
# Recall: 0.6250
# F1 Score: 0.5068
# ROC AUC Score: 0.6683
# Confusion Matrix:
# [[314 101]
#  [ 45  75]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81       415
#            1       0.43      0.62      0.51       120
#
#     accuracy                           0.73       535
#    macro avg       0.65      0.69      0.66       535
# weighted avg       0.77      0.73      0.74       535
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Threshold (Youden's J): 0.3557
# Adjusted Threshold Test Results:
# Accuracy: 0.6692
# Precision: 0.3797
# Recall: 0.7500
# F1 Score: 0.5042
# ROC AUC Score: 0.7364
# Confusion Matrix:
# [[268 147]
#  [ 30  90]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.65      0.75       415
#            1       0.38      0.75      0.50       120
#
#     accuracy                           0.67       535
#    macro avg       0.64      0.70      0.63       535
# weighted avg       0.78      0.67      0.70       535

# %%
# Get the best hyperparameters for each classifier in each dataset
best_parameters = []

# Iterate through each dataset in nested_cv_results
for dataset, dataset_results in nested_cv_results.items():
    cv_results_all = dataset_results.get('cv_results_all', {})
    
    # Iterate through each classifier in the current dataset
    for classifier, cv_results in cv_results_all.items():
        if cv_results.empty:
            print(f"No cross-validation results found for {classifier} in {dataset}.")
            continue
        
        # Identify the row with the highest mean_test_score
        best_row = cv_results.loc[cv_results['mean_test_score'].idxmax()]
        best_params = best_row['params']
        best_score = best_row['mean_test_score']
        
        # Append the results to the list
        best_parameters.append({
            'Dataset': dataset,
            'Classifier': classifier,
            'Best Score (F1)': best_score,
            'Best Hyperparameters': best_params
        })

# Convert the list to a DataFrame
best_params_df = pd.DataFrame(best_parameters)

# Optional: Expand the 'Best Hyperparameters' column for better readability
# This will create separate columns for each hyperparameter
best_params_expanded = best_params_df.join(
    best_params_df.pop('Best Hyperparameters').apply(pd.Series)
)

# Display the expanded DataFrame
pd.set_option('display.max_colwidth', None)  # Ensure full visibility of hyperparameters
print(best_params_expanded)
# Out:
#               Dataset           Classifier  Best Score (F1)  \
# 0            Combined  Logistic Regression         0.559901
# 1            Combined        Random Forest         0.482841
# 2            Combined              XGBoost         0.522831
# 3            Combined             LightGBM         0.511210
# 4            Combined                  SVM         0.556824
# 5            Clinical  Logistic Regression         0.545455
# 6            Clinical        Random Forest         0.393548
# 7            Clinical              XGBoost         0.515278
# 8            Clinical             LightGBM         0.550833
# 9            Clinical                  SVM         0.537154
# 10              Image  Logistic Regression         0.515959
# 11              Image        Random Forest         0.420489
# 12              Image              XGBoost         0.395602
# 13              Image             LightGBM         0.405184
# 14              Image                  SVM         0.516101
# 15      RadiomicsOnly  Logistic Regression         0.371429
# 16      RadiomicsOnly        Random Forest         0.274775
# 17      RadiomicsOnly              XGBoost         0.374772
# 18      RadiomicsOnly             LightGBM         0.436932
# 19      RadiomicsOnly                  SVM         0.401610
# 20  ClinicalRadiomics  Logistic Regression         0.506410
# 21  ClinicalRadiomics        Random Forest         0.321429
# 22  ClinicalRadiomics              XGBoost         0.499130
# 23  ClinicalRadiomics             LightGBM         0.479235
# 24  ClinicalRadiomics                  SVM         0.505814
# 25  CombinedRadiomics  Logistic Regression         0.440787
# 26  CombinedRadiomics        Random Forest         0.165282
# 27  CombinedRadiomics              XGBoost         0.348311
# 28  CombinedRadiomics             LightGBM         0.439026
# 29  CombinedRadiomics                  SVM         0.443213
# 30   CombinedSelected  Logistic Regression         0.541038
# 31   CombinedSelected        Random Forest         0.352731
# 32   CombinedSelected              XGBoost         0.469820
# 33   CombinedSelected             LightGBM         0.480782
# 34   CombinedSelected                  SVM         0.569837
#
#    classifier__penalty  classifier__C  classifier__n_estimators  \
# 0                   l2    1291.549665                       NaN
# 1                  NaN            NaN                      50.0
# 2                  NaN            NaN                     100.0
# 3                  NaN            NaN                     150.0
# 4                  NaN       1.000000                       NaN
# 5                   l2    1291.549665                       NaN
# 6                  NaN            NaN                     200.0
# 7                  NaN            NaN                     100.0
# 8                  NaN            NaN                     150.0
# 9                  NaN       0.100000                       NaN
# 10                  l2    1291.549665                       NaN
# 11                 NaN            NaN                     200.0
# 12                 NaN            NaN                     100.0
# 13                 NaN            NaN                     150.0
# 14                 NaN       1.000000                       NaN
# 15                  l2       0.000100                       NaN
# 16                 NaN            NaN                      50.0
# 17                 NaN            NaN                      50.0
# 18                 NaN            NaN                      50.0
# 19                 NaN       0.100000                       NaN
# 20                  l2       0.000100                       NaN
# 21                 NaN            NaN                      50.0
# 22                 NaN            NaN                     200.0
# 23                 NaN            NaN                     150.0
# 24                 NaN       0.100000                       NaN
# 25                  l2       0.000100                       NaN
# 26                 NaN            NaN                     150.0
# 27                 NaN            NaN                      50.0
# 28                 NaN            NaN                     150.0
# 29                 NaN       0.100000                       NaN
# 30                  l2     166.810054                       NaN
# 31                 NaN            NaN                     200.0
# 32                 NaN            NaN                     200.0
# 33                 NaN            NaN                     150.0
# 34                 NaN       1.000000                       NaN
#
#     classifier__min_samples_split  classifier__min_samples_leaf  \
# 0                             NaN                           NaN
# 1                             2.0                           2.0
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# 5                             NaN                           NaN
# 6                             2.0                           2.0
# 7                             NaN                           NaN
# 8                             NaN                           NaN
# 9                             NaN                           NaN
# 10                            NaN                           NaN
# 11                            2.0                           2.0
# 12                            NaN                           NaN
# 13                            NaN                           NaN
# 14                            NaN                           NaN
# 15                            NaN                           NaN
# 16                            2.0                           2.0
# 17                            NaN                           NaN
# 18                            NaN                           NaN
# 19                            NaN                           NaN
# 20                            NaN                           NaN
# 21                            2.0                           2.0
# 22                            NaN                           NaN
# 23                            NaN                           NaN
# 24                            NaN                           NaN
# 25                            NaN                           NaN
# 26                            2.0                           2.0
# 27                            NaN                           NaN
# 28                            NaN                           NaN
# 29                            NaN                           NaN
# 30                            NaN                           NaN
# 31                            2.0                           2.0
# 32                            NaN                           NaN
# 33                            NaN                           NaN
# 34                            NaN                           NaN
#
#     classifier__max_depth  classifier__learning_rate  classifier__verbose  \
# 0                     NaN                        NaN                  NaN
# 1                    10.0                        NaN                  NaN
# 2                     3.0                       0.10                  NaN
# 3                     NaN                       0.01                 -1.0
# 4                     NaN                        NaN                  NaN
# 5                     NaN                        NaN                  NaN
# 6                    10.0                        NaN                  NaN
# 7                    10.0                       0.10                  NaN
# 8                     NaN                       0.10                 -1.0
# 9                     NaN                        NaN                  NaN
# 10                    NaN                        NaN                  NaN
# 11                   10.0                        NaN                  NaN
# 12                    3.0                       0.10                  NaN
# 13                    NaN                       0.01                 -1.0
# 14                    NaN                        NaN                  NaN
# 15                    NaN                        NaN                  NaN
# 16                   20.0                        NaN                  NaN
# 17                    7.0                       0.01                  NaN
# 18                    NaN                       0.01                 -1.0
# 19                    NaN                        NaN                  NaN
# 20                    NaN                        NaN                  NaN
# 21                   20.0                        NaN                  NaN
# 22                   10.0                       0.01                  NaN
# 23                    NaN                       0.01                 -1.0
# 24                    NaN                        NaN                  NaN
# 25                    NaN                        NaN                  NaN
# 26                   10.0                        NaN                  NaN
# 27                    7.0                       0.01                  NaN
# 28                    NaN                       0.01                 -1.0
# 29                    NaN                        NaN                  NaN
# 30                    NaN                        NaN                  NaN
# 31                   20.0                        NaN                  NaN
# 32                   10.0                       0.01                  NaN
# 33                    NaN                       0.01                 -1.0
# 34                    NaN                        NaN                  NaN
#
#     classifier__num_leaves classifier__kernel
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                     63.0                NaN
# 4                      NaN             linear
# 5                      NaN                NaN
# 6                      NaN                NaN
# 7                      NaN                NaN
# 8                     63.0                NaN
# 9                      NaN             linear
# 10                     NaN                NaN
# 11                     NaN                NaN
# 12                     NaN                NaN
# 13                    63.0                NaN
# 14                     NaN             linear
# 15                     NaN                NaN
# 16                     NaN                NaN
# 17                     NaN                NaN
# 18                    31.0                NaN
# 19                     NaN                rbf
# 20                     NaN                NaN
# 21                     NaN                NaN
# 22                     NaN                NaN
# 23                    63.0                NaN
# 24                     NaN             linear
# 25                     NaN                NaN
# 26                     NaN                NaN
# 27                     NaN                NaN
# 28                    63.0                NaN
# 29                     NaN             linear
# 30                     NaN                NaN
# 31                     NaN                NaN
# 32                     NaN                NaN
# 33                    63.0                NaN
# 34                     NaN             linear

# %%
#Per-Patient Aggregated Evaluation with Youden's J Thresholds

import numpy as np
import pandas as pd
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, classification_report, roc_curve
)
from sklearn.base import clone

# Helper function to find optimal threshold using Youden's J statistic
def find_optimal_threshold(y_true, y_scores):
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    J = tpr - fpr
    ix = np.argmax(J)
    optimal_threshold = thresholds[ix]
    return optimal_threshold

# Initialize a dictionary to store per-patient test results
test_results_per_patient = {}

for dataset_name in data_splits.keys():
    print(f"\nAggregating Predictions for {dataset_name} Dataset")
    
    # Initialize nested dictionary for classifiers
    test_results_per_patient[dataset_name] = {}
    
    # Retrieve data splits
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test_full = data['y_test']
    patient_ids_test = data['patient_ids_test']
    
    # Create a DataFrame for test data
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test_full.values
    test_df['patient_id'] = patient_ids_test.values
    
    # Get per-patient true labels (assuming all slices of a patient have the same label)
    y_true_per_patient = test_df.groupby('patient_id')['y_true'].first()
    
    for classifier_name in classifiers.keys():
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve nested CV results
        cv_results_all = nested_cv_results[dataset_name]['cv_results_all'][classifier_name]
        
        # Find the best hyperparameters (highest mean_test_score)
        best_row = cv_results_all.loc[cv_results_all['mean_test_score'].idxmax()]
        best_params = best_row['params']
        
        # Extract classifier hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Clone the base classifier
        base_classifier = classifiers[classifier_name]
        classifier = clone(base_classifier)
        
        # Set best hyperparameters
        classifier.set_params(**classifier_params)
        
         # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)

        # Handle Logistic Regression solver and penalty compatibility
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                classifier.set_params(dual=True)
            else:
                classifier.set_params(dual=False)
        
        # Define the pipeline
        #pipeline = ImbPipeline(steps=[
        #    ('smote', SMOTE(sampling_strategy='minority', random_state=42)),
        #    ('scaler', MinMaxScaler()),
        #    ('classifier', classifier)
        #])

        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Predict probabilities on the test set
        if hasattr(pipeline.named_steps['classifier'], "predict_proba"):
            y_proba = pipeline.predict_proba(X_test_full)[:, 1]
        else:
            print(f"Classifier '{classifier_name}' does not support probability estimates. Skipping.")
            continue
        
        # Add predicted probabilities to test_df
        test_df[f'{classifier_name}_proba'] = y_proba
        
        # Compute optimal slice_threshold using Youden's J
        slice_threshold = find_optimal_threshold(y_test_full, y_proba)
        print(f"Optimal Slice Threshold (Youden's J): {slice_threshold:.4f}")
        
        # Assign per-slice predictions based on slice_threshold
        test_df[f'{classifier_name}_pred_slice'] = (y_proba >= slice_threshold).astype(int)
        
        # Aggregate predictions per patient based on patient_threshold
        # Calculate the proportion of slices predicted as 1 for each patient
        slice_proportions = test_df.groupby('patient_id')[f'{classifier_name}_pred_slice'].mean()
        
        # Compute patient_threshold using Youden's J on slice proportions
        patient_threshold = find_optimal_threshold(y_true_per_patient, slice_proportions)
        print(f"Optimal Patient Threshold (Youden's J): {patient_threshold:.4f}")
        
        # Assign patient-level predictions based on patient_threshold
        y_pred_per_patient = (slice_proportions >= patient_threshold).astype(int)
        
        # Align the true labels
        y_true = y_true_per_patient
        
        # Compute performance metrics
        accuracy = accuracy_score(y_true, y_pred_per_patient)
        precision = precision_score(y_true, y_pred_per_patient, zero_division=0)
        recall = recall_score(y_true, y_pred_per_patient)
        f1 = f1_score(y_true, y_pred_per_patient)
        try:
            roc_auc = roc_auc_score(y_true, slice_proportions)  # Using slice proportions for ROC AUC
        except ValueError:
            roc_auc = None  # Handle cases where ROC AUC is not defined
        
        conf_matrix = confusion_matrix(y_true, y_pred_per_patient)
        class_report = classification_report(y_true, y_pred_per_patient, zero_division=0)
        
        # Store the results
        test_results_per_patient[dataset_name][classifier_name + ' (Patient Aggregated)'] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"\nAggregated Test Results for {classifier_name} on {dataset_name} Dataset:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        if roc_auc is not None:
            print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)
# Out:
# Aggregating Predictions for Combined Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.4307
# Optimal Patient Threshold (Youden's J): 0.8000
#
# Aggregated Test Results for Logistic Regression on Combined Dataset:
# Accuracy: 0.7358
# Precision: 0.4500
# Recall: 0.7500
# F1 Score: 0.5625
# ROC AUC Score: 0.7734
# Confusion Matrix:
# [[30 11]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81        41
#            1       0.45      0.75      0.56        12
#
#     accuracy                           0.74        53
#    macro avg       0.68      0.74      0.69        53
# weighted avg       0.81      0.74      0.75        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.4877
# Optimal Patient Threshold (Youden's J): 0.4000
#
# Aggregated Test Results for Random Forest on Combined Dataset:
# Accuracy: 0.7547
# Precision: 0.4783
# Recall: 0.9167
# F1 Score: 0.6286
# ROC AUC Score: 0.8222
# Confusion Matrix:
# [[29 12]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.71      0.82        41
#            1       0.48      0.92      0.63        12
#
#     accuracy                           0.75        53
#    macro avg       0.72      0.81      0.72        53
# weighted avg       0.86      0.75      0.77        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7140
# Optimal Patient Threshold (Youden's J): 0.9000
#
# Aggregated Test Results for XGBoost on Combined Dataset:
# Accuracy: 0.8491
# Precision: 0.6667
# Recall: 0.6667
# F1 Score: 0.6667
# ROC AUC Score: 0.8201
# Confusion Matrix:
# [[37  4]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        41
#            1       0.67      0.67      0.67        12
#
#     accuracy                           0.85        53
#    macro avg       0.78      0.78      0.78        53
# weighted avg       0.85      0.85      0.85        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.2692
# Optimal Patient Threshold (Youden's J): 0.8000
#
# Aggregated Test Results for LightGBM on Combined Dataset:
# Accuracy: 0.7170
# Precision: 0.4348
# Recall: 0.8333
# F1 Score: 0.5714
# ROC AUC Score: 0.7673
# Confusion Matrix:
# [[28 13]
#  [ 2 10]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.79        41
#            1       0.43      0.83      0.57        12
#
#     accuracy                           0.72        53
#    macro avg       0.68      0.76      0.68        53
# weighted avg       0.82      0.72      0.74        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5964
# Optimal Patient Threshold (Youden's J): 0.4000
#
# Aggregated Test Results for SVM on Combined Dataset:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.7500
# F1 Score: 0.6000
# ROC AUC Score: 0.8242
# Confusion Matrix:
# [[32  9]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84        41
#            1       0.50      0.75      0.60        12
#
#     accuracy                           0.77        53
#    macro avg       0.71      0.77      0.72        53
# weighted avg       0.82      0.77      0.79        53
#
#
# Aggregating Predictions for Clinical Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6439
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Logistic Regression on Clinical Dataset:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.7358
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3328
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Random Forest on Clinical Dataset:
# Accuracy: 0.7358
# Precision: 0.4444
# Recall: 0.6667
# F1 Score: 0.5333
# ROC AUC Score: 0.7114
# Confusion Matrix:
# [[31 10]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82        41
#            1       0.44      0.67      0.53        12
#
#     accuracy                           0.74        53
#    macro avg       0.67      0.71      0.67        53
# weighted avg       0.79      0.74      0.75        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7301
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for XGBoost on Clinical Dataset:
# Accuracy: 0.7547
# Precision: 0.4615
# Recall: 0.5000
# F1 Score: 0.4800
# ROC AUC Score: 0.6646
# Confusion Matrix:
# [[34  7]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        41
#            1       0.46      0.50      0.48        12
#
#     accuracy                           0.75        53
#    macro avg       0.66      0.66      0.66        53
# weighted avg       0.76      0.75      0.76        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7192
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on Clinical Dataset:
# Accuracy: 0.7358
# Precision: 0.4375
# Recall: 0.5833
# F1 Score: 0.5000
# ROC AUC Score: 0.6819
# Confusion Matrix:
# [[32  9]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        41
#            1       0.44      0.58      0.50        12
#
#     accuracy                           0.74        53
#    macro avg       0.65      0.68      0.66        53
# weighted avg       0.77      0.74      0.75        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6836
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for SVM on Clinical Dataset:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.6667
# F1 Score: 0.5714
# ROC AUC Score: 0.7358
# Confusion Matrix:
# [[33  8]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.85        41
#            1       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Aggregating Predictions for Image Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5934
# Optimal Patient Threshold (Youden's J): 0.6000
#
# Aggregated Test Results for Logistic Regression on Image Dataset:
# Accuracy: 0.7925
# Precision: 0.5455
# Recall: 0.5000
# F1 Score: 0.5217
# ROC AUC Score: 0.6341
# Confusion Matrix:
# [[36  5]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87        41
#            1       0.55      0.50      0.52        12
#
#     accuracy                           0.79        53
#    macro avg       0.70      0.69      0.69        53
# weighted avg       0.79      0.79      0.79        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.1802
# Optimal Patient Threshold (Youden's J): 0.7000
#
# Aggregated Test Results for Random Forest on Image Dataset:
# Accuracy: 0.5094
# Precision: 0.3158
# Recall: 1.0000
# F1 Score: 0.4800
# ROC AUC Score: 0.6596
# Confusion Matrix:
# [[15 26]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.37      0.54        41
#            1       0.32      1.00      0.48        12
#
#     accuracy                           0.51        53
#    macro avg       0.66      0.68      0.51        53
# weighted avg       0.85      0.51      0.52        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5232
# Optimal Patient Threshold (Youden's J): 0.5000
#
# Aggregated Test Results for XGBoost on Image Dataset:
# Accuracy: 0.5094
# Precision: 0.3158
# Recall: 1.0000
# F1 Score: 0.4800
# ROC AUC Score: 0.6535
# Confusion Matrix:
# [[15 26]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.37      0.54        41
#            1       0.32      1.00      0.48        12
#
#     accuracy                           0.51        53
#    macro avg       0.66      0.68      0.51        53
# weighted avg       0.85      0.51      0.52        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3539
# Optimal Patient Threshold (Youden's J): 0.9000
#
# Aggregated Test Results for LightGBM on Image Dataset:
# Accuracy: 0.6981
# Precision: 0.3889
# Recall: 0.5833
# F1 Score: 0.4667
# ROC AUC Score: 0.6677
# Confusion Matrix:
# [[30 11]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        41
#            1       0.39      0.58      0.47        12
#
#     accuracy                           0.70        53
#    macro avg       0.62      0.66      0.63        53
# weighted avg       0.75      0.70      0.72        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5285
# Optimal Patient Threshold (Youden's J): 0.6000
#
# Aggregated Test Results for SVM on Image Dataset:
# Accuracy: 0.6981
# Precision: 0.3889
# Recall: 0.5833
# F1 Score: 0.4667
# ROC AUC Score: 0.6209
# Confusion Matrix:
# [[30 11]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        41
#            1       0.39      0.58      0.47        12
#
#     accuracy                           0.70        53
#    macro avg       0.62      0.66      0.63        53
# weighted avg       0.75      0.70      0.72        53
#
#
# Aggregating Predictions for RadiomicsOnly Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for Logistic Regression on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.2720
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Random Forest on RadiomicsOnly Dataset:
# Accuracy: 0.4151
# Precision: 0.2683
# Recall: 0.9167
# F1 Score: 0.4151
# ROC AUC Score: 0.5925
# Confusion Matrix:
# [[11 30]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.27      0.42        41
#            1       0.27      0.92      0.42        12
#
#     accuracy                           0.42        53
#    macro avg       0.59      0.59      0.42        53
# weighted avg       0.77      0.42      0.42        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for XGBoost on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3958
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on RadiomicsOnly Dataset:
# Accuracy: 0.5094
# Precision: 0.3056
# Recall: 0.9167
# F1 Score: 0.4583
# ROC AUC Score: 0.6535
# Confusion Matrix:
# [[16 25]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.39      0.55        41
#            1       0.31      0.92      0.46        12
#
#     accuracy                           0.51        53
#    macro avg       0.62      0.65      0.51        53
# weighted avg       0.80      0.51      0.53        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for SVM on RadiomicsOnly Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Aggregating Predictions for ClinicalRadiomics Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.0000
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Logistic Regression on ClinicalRadiomics Dataset:
# Accuracy: 0.4906
# Precision: 0.2581
# Recall: 0.6667
# F1 Score: 0.3721
# ROC AUC Score: 0.5528
# Confusion Matrix:
# [[18 23]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.44      0.57        41
#            1       0.26      0.67      0.37        12
#
#     accuracy                           0.49        53
#    macro avg       0.54      0.55      0.47        53
# weighted avg       0.69      0.49      0.53        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.2233
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Random Forest on ClinicalRadiomics Dataset:
# Accuracy: 0.3208
# Precision: 0.2500
# Recall: 1.0000
# F1 Score: 0.4000
# ROC AUC Score: 0.5610
# Confusion Matrix:
# [[ 5 36]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.12      0.22        41
#            1       0.25      1.00      0.40        12
#
#     accuracy                           0.32        53
#    macro avg       0.62      0.56      0.31        53
# weighted avg       0.83      0.32      0.26        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.7989
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for XGBoost on ClinicalRadiomics Dataset:
# Accuracy: 0.7925
# Precision: 1.0000
# Recall: 0.0833
# F1 Score: 0.1538
# ROC AUC Score: 0.5417
# Confusion Matrix:
# [[41  0]
#  [11  1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        41
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.4411
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on ClinicalRadiomics Dataset:
# Accuracy: 0.4717
# Precision: 0.2778
# Recall: 0.8333
# F1 Score: 0.4167
# ROC AUC Score: 0.5996
# Confusion Matrix:
# [[15 26]
#  [ 2 10]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.37      0.52        41
#            1       0.28      0.83      0.42        12
#
#     accuracy                           0.47        53
#    macro avg       0.58      0.60      0.47        53
# weighted avg       0.75      0.47      0.49        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for SVM on ClinicalRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Aggregating Predictions for CombinedRadiomics Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.0000
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Logistic Regression on CombinedRadiomics Dataset:
# Accuracy: 0.4528
# Precision: 0.2927
# Recall: 1.0000
# F1 Score: 0.4528
# ROC AUC Score: 0.6463
# Confusion Matrix:
# [[12 29]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.29      0.45        41
#            1       0.29      1.00      0.45        12
#
#     accuracy                           0.45        53
#    macro avg       0.65      0.65      0.45        53
# weighted avg       0.84      0.45      0.45        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.2893
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Random Forest on CombinedRadiomics Dataset:
# Accuracy: 0.8113
# Precision: 0.6667
# Recall: 0.3333
# F1 Score: 0.4444
# ROC AUC Score: 0.6423
# Confusion Matrix:
# [[39  2]
#  [ 8  4]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89        41
#            1       0.67      0.33      0.44        12
#
#     accuracy                           0.81        53
#    macro avg       0.75      0.64      0.67        53
# weighted avg       0.79      0.81      0.79        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for XGBoost on CombinedRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.2780
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on CombinedRadiomics Dataset:
# Accuracy: 0.7925
# Precision: 0.5556
# Recall: 0.4167
# F1 Score: 0.4762
# ROC AUC Score: 0.6596
# Confusion Matrix:
# [[37  4]
#  [ 7  5]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        41
#            1       0.56      0.42      0.48        12
#
#     accuracy                           0.79        53
#    macro avg       0.70      0.66      0.67        53
# weighted avg       0.78      0.79      0.78        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): inf
# Optimal Patient Threshold (Youden's J): inf
#
# Aggregated Test Results for SVM on CombinedRadiomics Dataset:
# Accuracy: 0.7736
# Precision: 0.0000
# Recall: 0.0000
# F1 Score: 0.0000
# ROC AUC Score: 0.5000
# Confusion Matrix:
# [[41  0]
#  [12  0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      1.00      0.87        41
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.77        53
#    macro avg       0.39      0.50      0.44        53
# weighted avg       0.60      0.77      0.67        53
#
#
# Aggregating Predictions for CombinedSelected Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3210
# Optimal Patient Threshold (Youden's J): 0.9000
#
# Aggregated Test Results for Logistic Regression on CombinedSelected Dataset:
# Accuracy: 0.7170
# Precision: 0.4286
# Recall: 0.7500
# F1 Score: 0.5455
# ROC AUC Score: 0.7144
# Confusion Matrix:
# [[29 12]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.71      0.79        41
#            1       0.43      0.75      0.55        12
#
#     accuracy                           0.72        53
#    macro avg       0.67      0.73      0.67        53
# weighted avg       0.80      0.72      0.74        53
#
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3780
# Optimal Patient Threshold (Youden's J): 0.3000
#
# Aggregated Test Results for Random Forest on CombinedSelected Dataset:
# Accuracy: 0.7547
# Precision: 0.4737
# Recall: 0.7500
# F1 Score: 0.5806
# ROC AUC Score: 0.7419
# Confusion Matrix:
# [[31 10]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83        41
#            1       0.47      0.75      0.58        12
#
#     accuracy                           0.75        53
#    macro avg       0.69      0.75      0.70        53
# weighted avg       0.81      0.75      0.77        53
#
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3570 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.4358
# Optimal Patient Threshold (Youden's J): 0.6000
#
# Aggregated Test Results for XGBoost on CombinedSelected Dataset:
# Accuracy: 0.7358
# Precision: 0.4500
# Recall: 0.7500
# F1 Score: 0.5625
# ROC AUC Score: 0.7276
# Confusion Matrix:
# [[30 11]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81        41
#            1       0.45      0.75      0.56        12
#
#     accuracy                           0.74        53
#    macro avg       0.68      0.74      0.69        53
# weighted avg       0.81      0.74      0.75        53
#
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5080
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for LightGBM on CombinedSelected Dataset:
# Accuracy: 0.8679
# Precision: 0.7778
# Recall: 0.5833
# F1 Score: 0.6667
# ROC AUC Score: 0.7226
# Confusion Matrix:
# [[39  2]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92        41
#            1       0.78      0.58      0.67        12
#
#     accuracy                           0.87        53
#    macro avg       0.83      0.77      0.79        53
# weighted avg       0.86      0.87      0.86        53
#
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3557
# Optimal Patient Threshold (Youden's J): 0.9000
#
# Aggregated Test Results for SVM on CombinedSelected Dataset:
# Accuracy: 0.7358
# Precision: 0.4500
# Recall: 0.7500
# F1 Score: 0.5625
# ROC AUC Score: 0.7236
# Confusion Matrix:
# [[30 11]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81        41
#            1       0.45      0.75      0.56        12
#
#     accuracy                           0.74        53
#    macro avg       0.68      0.74      0.69        53
# weighted avg       0.81      0.74      0.75        53

# %%
# Visualize Per-Patient Performance Metrics

import matplotlib.pyplot as plt
import seaborn as sns

# Function to plot metrics for each classifier in a dataset
def plot_metrics(dataset_name, classifiers_results):
    metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
    classifier_names = list(classifiers_results.keys())
    metric_values = {metric: [classifiers_results[clf][metric] for clf in classifier_names] for metric in metrics}
    
    df_metrics = pd.DataFrame(metric_values, index=classifier_names)
    df_metrics = df_metrics.reset_index().rename(columns={'index': 'Classifier'})
    
    df_melted = df_metrics.melt(id_vars='Classifier', var_name='Metric', value_name='Value')
    
    plt.figure(figsize=(14, 7))
    sns.barplot(x='Classifier', y='Value', hue='Metric', data=df_melted)
    plt.title(f'Per-Patient Aggregated Performance Metrics for {dataset_name} Dataset')
    plt.xticks(rotation=45)
    plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# Plot metrics for each dataset
for dataset_name, classifiers_results in test_results_per_patient.items():
    plot_metrics(dataset_name, classifiers_results)

# %%
# Bootstrap Confidence Intervals for Test Metrics

import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Number of bootstrap iterations
n_bootstraps = 1000
rng = np.random.RandomState(seed=42)  # For reproducibility

# Initialize a dictionary to store bootstrap results
bootstrap_results = {}

for dataset_name in data_splits.keys():
    print(f"\nBootstrapping Test Metrics for '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_test_full = data['X_test_full']
    y_test = data['y_test'].reset_index(drop=True)
    
    # Initialize dictionary for classifiers
    bootstrap_results[dataset_name] = {}
    
    for classifier_name in classifiers.keys():
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve the best hyperparameters from nested_cv_results
        nested_results = nested_cv_results[dataset_name]
        cv_results_all = nested_results['cv_results_all']
        cv_results = cv_results_all[classifier_name]
        
        # Find the hyperparameters with the best mean_test_score
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier with default parameters
        default_classifier = classifiers[classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)
        
        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)

        # Handle compatibility between solver and penalty for Logistic Regression
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        
        # Retrieve training data
        X_train_full = data['X_train_full']
        y_train_full = data['y_train_full']
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Initialize lists to store bootstrap metrics
        bootstrap_accuracies = []
        bootstrap_precisions = []
        bootstrap_recalls = []
        bootstrap_f1s = []
        bootstrap_roc_aucs = []
        
        # Convert y_test to numpy array
        y_test_array = y_test.values
        
        # Compute predicted probabilities once (since the model is fixed)
        if hasattr(pipeline.named_steps['classifier'], "predict_proba"):
            y_proba_full = pipeline.predict_proba(X_test_full)[:, 1]
        else:
            # For classifiers that do not have predict_proba, skip ROC AUC
            y_proba_full = None
        
        # Perform bootstrap resampling
        for i in range(n_bootstraps):
            # Sample indices with replacement
            indices = rng.choice(len(X_test_full), size=len(X_test_full), replace=True)
            X_test_bootstrap = X_test_full.iloc[indices]
            y_test_bootstrap = y_test_array[indices]
            
            # Make predictions on the bootstrap sample
            y_pred_bootstrap = pipeline.predict(X_test_bootstrap)
            
            # Compute metrics
            accuracy = accuracy_score(y_test_bootstrap, y_pred_bootstrap)
            precision = precision_score(y_test_bootstrap, y_pred_bootstrap, zero_division=0)
            recall = recall_score(y_test_bootstrap, y_pred_bootstrap)
            f1 = f1_score(y_test_bootstrap, y_pred_bootstrap)
            if y_proba_full is not None:
                y_proba_bootstrap = y_proba_full[indices]
                roc_auc = roc_auc_score(y_test_bootstrap, y_proba_bootstrap)
            else:
                roc_auc = np.nan  # Not available for this classifier
                
            # Append metrics
            bootstrap_accuracies.append(accuracy)
            bootstrap_precisions.append(precision)
            bootstrap_recalls.append(recall)
            bootstrap_f1s.append(f1)
            bootstrap_roc_aucs.append(roc_auc)
        
        # Compute confidence intervals (e.g., 95% CI)
        def compute_confidence_interval(metric_values):
            sorted_values = np.sort(metric_values)
            lower = np.percentile(sorted_values, 2.5)
            upper = np.percentile(sorted_values, 97.5)
            mean = np.mean(metric_values)
            return mean, lower, upper
        
        accuracy_mean, accuracy_lower, accuracy_upper = compute_confidence_interval(bootstrap_accuracies)
        precision_mean, precision_lower, precision_upper = compute_confidence_interval(bootstrap_precisions)
        recall_mean, recall_lower, recall_upper = compute_confidence_interval(bootstrap_recalls)
        f1_mean, f1_lower, f1_upper = compute_confidence_interval(bootstrap_f1s)
        roc_auc_mean, roc_auc_lower, roc_auc_upper = compute_confidence_interval(bootstrap_roc_aucs)
        
        # Store the bootstrap results
        bootstrap_results[dataset_name][classifier_name] = {
            'accuracy': (accuracy_mean, accuracy_lower, accuracy_upper),
            'precision': (precision_mean, precision_lower, precision_upper),
            'recall': (recall_mean, recall_lower, recall_upper),
            'f1': (f1_mean, f1_lower, f1_upper),
            'roc_auc': (roc_auc_mean, roc_auc_lower, roc_auc_upper),
        }
        
        # Print the results
        print(f"{classifier_name} Bootstrap Confidence Intervals:")
        print(f"Accuracy: {accuracy_mean:.4f} (95% CI: {accuracy_lower:.4f} - {accuracy_upper:.4f})")
        print(f"Precision: {precision_mean:.4f} (95% CI: {precision_lower:.4f} - {precision_upper:.4f})")
        print(f"Recall: {recall_mean:.4f} (95% CI: {recall_lower:.4f} - {recall_upper:.4f})")
        print(f"F1 Score: {f1_mean:.4f} (95% CI: {f1_lower:.4f} - {f1_upper:.4f})")
        if not np.isnan(roc_auc_mean):
            print(f"ROC AUC: {roc_auc_mean:.4f} (95% CI: {roc_auc_lower:.4f} - {roc_auc_upper:.4f})")
        else:
            print("ROC AUC: Not available for this classifier")
# Out:
# Bootstrapping Test Metrics for 'Combined' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.7082 (95% CI: 0.6692 - 0.7439)
# Precision: 0.4121 (95% CI: 0.3450 - 0.4815)
# Recall: 0.6849 (95% CI: 0.6000 - 0.7616)
# F1 Score: 0.5138 (95% CI: 0.4478 - 0.5769)
# ROC AUC: 0.7681 (95% CI: 0.7195 - 0.8090)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7533 (95% CI: 0.7178 - 0.7888)
# Precision: 0.4656 (95% CI: 0.3941 - 0.5404)
# Recall: 0.6365 (95% CI: 0.5462 - 0.7227)
# F1 Score: 0.5369 (95% CI: 0.4693 - 0.6035)
# ROC AUC: 0.7850 (95% CI: 0.7412 - 0.8275)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.6102 (95% CI: 0.5682 - 0.6505)
# Precision: 0.3549 (95% CI: 0.3023 - 0.4133)
# Recall: 0.8841 (95% CI: 0.8241 - 0.9392)
# F1 Score: 0.5059 (95% CI: 0.4462 - 0.5688)
# ROC AUC: 0.7977 (95% CI: 0.7552 - 0.8395)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.6272 (95% CI: 0.5850 - 0.6654)
# Precision: 0.3317 (95% CI: 0.2754 - 0.3858)
# Recall: 0.6379 (95% CI: 0.5530 - 0.7206)
# F1 Score: 0.4359 (95% CI: 0.3743 - 0.4929)
# ROC AUC: 0.7061 (95% CI: 0.6564 - 0.7545)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.6664 (95% CI: 0.6262 - 0.7028)
# Precision: 0.3837 (95% CI: 0.3255 - 0.4381)
# Recall: 0.7798 (95% CI: 0.7023 - 0.8495)
# F1 Score: 0.5137 (95% CI: 0.4514 - 0.5677)
# ROC AUC: 0.7834 (95% CI: 0.7372 - 0.8255)
#
# Bootstrapping Test Metrics for 'Clinical' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.7743 (95% CI: 0.6604 - 0.8868)
# Precision: 0.5010 (95% CI: 0.2353 - 0.7333)
# Recall: 0.6694 (95% CI: 0.3747 - 0.9232)
# F1 Score: 0.5636 (95% CI: 0.3157 - 0.7586)
# ROC AUC: 0.7110 (95% CI: 0.5082 - 0.8842)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7199 (95% CI: 0.6038 - 0.8302)
# Precision: 0.3656 (95% CI: 0.0998 - 0.6667)
# Recall: 0.3332 (95% CI: 0.0833 - 0.6004)
# F1 Score: 0.3386 (95% CI: 0.0952 - 0.5714)
# ROC AUC: 0.6442 (95% CI: 0.4556 - 0.8195)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.6024 (95% CI: 0.4717 - 0.7358)
# Precision: 0.3018 (95% CI: 0.1250 - 0.5000)
# Recall: 0.5810 (95% CI: 0.2857 - 0.8571)
# F1 Score: 0.3902 (95% CI: 0.1765 - 0.5854)
# ROC AUC: 0.6063 (95% CI: 0.4035 - 0.7917)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.6075 (95% CI: 0.4717 - 0.7358)
# Precision: 0.3043 (95% CI: 0.1303 - 0.5000)
# Recall: 0.5885 (95% CI: 0.2857 - 0.8753)
# F1 Score: 0.3939 (95% CI: 0.1935 - 0.5946)
# ROC AUC: 0.6467 (95% CI: 0.4614 - 0.8110)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.5915 (95% CI: 0.4528 - 0.7170)
# Precision: 0.3146 (95% CI: 0.1378 - 0.5162)
# Recall: 0.6723 (95% CI: 0.3750 - 0.9286)
# F1 Score: 0.4218 (95% CI: 0.2162 - 0.6190)
# ROC AUC: 0.7028 (95% CI: 0.5058 - 0.8773)
#
# Bootstrapping Test Metrics for 'Image' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.6436 (95% CI: 0.6037 - 0.6841)
# Precision: 0.3186 (95% CI: 0.2528 - 0.3837)
# Recall: 0.5128 (95% CI: 0.4167 - 0.6047)
# F1 Score: 0.3922 (95% CI: 0.3188 - 0.4606)
# ROC AUC: 0.6059 (95% CI: 0.5429 - 0.6639)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.6286 (95% CI: 0.5907 - 0.6711)
# Precision: 0.2507 (95% CI: 0.1842 - 0.3210)
# Recall: 0.3230 (95% CI: 0.2461 - 0.4060)
# F1 Score: 0.2816 (95% CI: 0.2154 - 0.3521)
# ROC AUC: 0.6120 (95% CI: 0.5596 - 0.6658)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.4716 (95% CI: 0.4280 - 0.5159)
# Precision: 0.2811 (95% CI: 0.2356 - 0.3278)
# Recall: 0.8619 (95% CI: 0.7937 - 0.9189)
# F1 Score: 0.4235 (95% CI: 0.3664 - 0.4798)
# ROC AUC: 0.6310 (95% CI: 0.5721 - 0.6834)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.5354 (95% CI: 0.4935 - 0.5757)
# Precision: 0.2650 (95% CI: 0.2101 - 0.3176)
# Recall: 0.5948 (95% CI: 0.5096 - 0.6814)
# F1 Score: 0.3660 (95% CI: 0.3030 - 0.4235)
# ROC AUC: 0.5959 (95% CI: 0.5428 - 0.6480)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.6762 (95% CI: 0.6355 - 0.7159)
# Precision: 0.3363 (95% CI: 0.2599 - 0.4167)
# Recall: 0.4458 (95% CI: 0.3565 - 0.5360)
# F1 Score: 0.3825 (95% CI: 0.3066 - 0.4564)
# ROC AUC: 0.6016 (95% CI: 0.5423 - 0.6621)
#
# Bootstrapping Test Metrics for 'RadiomicsOnly' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.2434 (95% CI: 0.1321 - 0.3585)
# Precision: 0.1496 (95% CI: 0.0476 - 0.2727)
# Recall: 0.4975 (95% CI: 0.1818 - 0.7778)
# F1 Score: 0.2267 (95% CI: 0.0784 - 0.3793)
# ROC AUC: 0.3332 (95% CI: 0.1667 - 0.4930)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7771 (95% CI: 0.6604 - 0.8868)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5436 (95% CI: 0.3351 - 0.7244)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.2259 (95% CI: 0.1321 - 0.3585)
# Precision: 0.2259 (95% CI: 0.1321 - 0.3585)
# Recall: 1.0000 (95% CI: 1.0000 - 1.0000)
# F1 Score: 0.3649 (95% CI: 0.2333 - 0.5278)
# ROC AUC: 0.3800 (95% CI: 0.2537 - 0.5102)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.7723 (95% CI: 0.6415 - 0.8684)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5731 (95% CI: 0.4015 - 0.7362)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.7717 (95% CI: 0.6415 - 0.8868)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Bootstrapping Test Metrics for 'ClinicalRadiomics' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.7715 (95% CI: 0.6599 - 0.8679)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.4771 (95% CI: 0.2908 - 0.6838)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7742 (95% CI: 0.6604 - 0.8868)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.4625 (95% CI: 0.2695 - 0.6501)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.4344 (95% CI: 0.3019 - 0.5660)
# Precision: 0.1746 (95% CI: 0.0400 - 0.3214)
# Recall: 0.4128 (95% CI: 0.1250 - 0.7143)
# F1 Score: 0.2406 (95% CI: 0.0606 - 0.4091)
# ROC AUC: 0.4129 (95% CI: 0.2298 - 0.6137)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.5295 (95% CI: 0.3962 - 0.6604)
# Precision: 0.2172 (95% CI: 0.0525 - 0.3889)
# Recall: 0.4140 (95% CI: 0.1538 - 0.7143)
# F1 Score: 0.2785 (95% CI: 0.0741 - 0.4706)
# ROC AUC: 0.4840 (95% CI: 0.3104 - 0.6698)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.7706 (95% CI: 0.6604 - 0.8868)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Bootstrapping Test Metrics for 'CombinedRadiomics' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.7732 (95% CI: 0.7364 - 0.8075)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5750 (95% CI: 0.5166 - 0.6283)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7562 (95% CI: 0.7196 - 0.7925)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5908 (95% CI: 0.5304 - 0.6532)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.7368 (95% CI: 0.7009 - 0.7776)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.3207 (95% CI: 0.2669 - 0.3713)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.7735 (95% CI: 0.7401 - 0.8093)
# Precision: 0.4901 (95% CI: 0.2778 - 0.7144)
# Recall: 0.0816 (95% CI: 0.0373 - 0.1328)
# F1 Score: 0.1389 (95% CI: 0.0671 - 0.2194)
# ROC AUC: 0.5694 (95% CI: 0.5042 - 0.6396)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.7748 (95% CI: 0.7383 - 0.8093)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Bootstrapping Test Metrics for 'CombinedSelected' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
# Logistic Regression Bootstrap Confidence Intervals:
# Accuracy: 0.6719 (95% CI: 0.6299 - 0.7140)
# Precision: 0.3683 (95% CI: 0.3051 - 0.4369)
# Recall: 0.6417 (95% CI: 0.5528 - 0.7227)
# F1 Score: 0.4672 (95% CI: 0.4013 - 0.5334)
# ROC AUC: 0.7222 (95% CI: 0.6729 - 0.7725)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
# Random Forest Bootstrap Confidence Intervals:
# Accuracy: 0.7403 (95% CI: 0.7046 - 0.7757)
# Precision: 0.4045 (95% CI: 0.3158 - 0.5000)
# Recall: 0.3357 (95% CI: 0.2564 - 0.4159)
# F1 Score: 0.3659 (95% CI: 0.2882 - 0.4426)
# ROC AUC: 0.6940 (95% CI: 0.6394 - 0.7466)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3570 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
# XGBoost Bootstrap Confidence Intervals:
# Accuracy: 0.7269 (95% CI: 0.6915 - 0.7627)
# Precision: 0.4223 (95% CI: 0.3491 - 0.4884)
# Recall: 0.6012 (95% CI: 0.5121 - 0.6909)
# F1 Score: 0.4953 (95% CI: 0.4255 - 0.5571)
# ROC AUC: 0.6835 (95% CI: 0.6198 - 0.7390)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
# LightGBM Bootstrap Confidence Intervals:
# Accuracy: 0.7199 (95% CI: 0.6822 - 0.7571)
# Precision: 0.4169 (95% CI: 0.3459 - 0.4897)
# Recall: 0.6259 (95% CI: 0.5403 - 0.7128)
# F1 Score: 0.4997 (95% CI: 0.4315 - 0.5677)
# ROC AUC: 0.6688 (95% CI: 0.6115 - 0.7226)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
# SVM Bootstrap Confidence Intervals:
# Accuracy: 0.6807 (95% CI: 0.6411 - 0.7234)
# Precision: 0.3792 (95% CI: 0.3190 - 0.4512)
# Recall: 0.6687 (95% CI: 0.5826 - 0.7481)
# F1 Score: 0.4832 (95% CI: 0.4175 - 0.5552)
# ROC AUC: 0.7371 (95% CI: 0.6857 - 0.7863)

# %%
# Bootstrap Confidence Intervals with Patient-Level and Slice-Level Thresholding

import numpy as np
import pandas as pd
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, confusion_matrix, classification_report
)
from sklearn.base import clone

# Number of bootstrap iterations
n_bootstraps = 1000
rng = np.random.RandomState(seed=42)  # For reproducibility

# Initialize a dictionary to store bootstrap results
bootstrap_results_per_patient = {}

for dataset_name in data_splits.keys():
    print(f"\nBootstrapping Test Metrics for '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_test_full = data['X_test_full'].reset_index(drop=True)
    y_test = data['y_test'].reset_index(drop=True)
    patient_ids_test = data['patient_ids_test'].reset_index(drop=True)
    
    # Combine test data into a single DataFrame
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test
    test_df['patient_id'] = patient_ids_test
    
    # Get unique patient IDs
    unique_patient_ids = test_df['patient_id'].unique()
    
    # Initialize dictionary for classifiers
    bootstrap_results_per_patient[dataset_name] = {}
    
    for classifier_name in classifiers.keys():
        print(f"\nClassifier: {classifier_name}")
        
        # Retrieve the best hyperparameters from nested_cv_results
        nested_results = nested_cv_results[dataset_name]
        cv_results_all = nested_results['cv_results_all']
        cv_results = cv_results_all[classifier_name]
        
        # Find the hyperparameters with the best mean_test_score
        max_mean_test_score = cv_results['mean_test_score'].max()
        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
        
        # If multiple rows have the same max score, pick the first one
        best_row = best_rows.iloc[0]
        
        # Extract the best hyperparameters from the pipeline parameters
        best_params = best_row['params']
        
        # The params are for the entire pipeline; extract classifier's hyperparameters
        classifier_params = {}
        for param_name, param_value in best_params.items():
            if param_name.startswith('classifier__'):
                # Remove 'classifier__' prefix to get the parameter name
                param_short = param_name.replace('classifier__', '')
                classifier_params[param_short] = param_value
        
        # Get the default classifier with default parameters
        default_classifier = classifiers[classifier_name]
        
        # Clone the default classifier to avoid modifying the original
        classifier = clone(default_classifier)
        
        # Update the classifier's parameters with the best hyperparameters
        classifier.set_params(**classifier_params)

        # **Compute scale_pos_weight for XGBoost and LightGBM**
        if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
            scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
            print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
            classifier.set_params(scale_pos_weight=scale_pos_weight)
        
        # Handle compatibility between solver and penalty for Logistic Regression
        if classifier_name == 'Logistic Regression':
            penalty = classifier.get_params().get('penalty', 'l2')
            solver = classifier.get_params().get('solver', 'lbfgs')
            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
                # Change solver to 'liblinear' if penalty is 'l1'
                classifier.set_params(solver='liblinear')
                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
            elif penalty == 'elasticnet' and solver != 'saga':
                # 'elasticnet' penalty requires 'saga' solver
                classifier.set_params(solver='saga')
                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
                # Dual formulation is only implemented for l2 penalty with liblinear solver
                classifier.set_params(dual=True)
            else:
                # Ensure dual is False for other solvers
                classifier.set_params(dual=False)
        
        # Retrieve training data
        X_train_full = data['X_train_full']
        y_train_full = data['y_train_full']
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', classifier)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Compute predicted probabilities on the full test set
        if hasattr(pipeline.named_steps['classifier'], "predict_proba"):
            y_proba_full = pipeline.predict_proba(X_test_full)[:, 1]
        else:
            print(f"Classifier '{classifier_name}' does not support probability estimates. Skipping.")
            continue
        
        # Add predicted probabilities to test_df
        test_df['y_proba'] = y_proba_full
        
        # Initialize lists to store bootstrap metrics
        bootstrap_accuracies = []
        bootstrap_precisions = []
        bootstrap_recalls = []
        bootstrap_f1s = []
        bootstrap_roc_aucs = []
        
        # Perform bootstrap resampling
        for i in range(n_bootstraps):
            # Sample patient IDs with replacement
            sampled_patient_ids = rng.choice(unique_patient_ids, size=len(unique_patient_ids), replace=True)
            
            # Get the indices of the slices corresponding to the sampled patient IDs
            sampled_indices = test_df[test_df['patient_id'].isin(sampled_patient_ids)].index
            
            # Create bootstrap sample
            test_df_bootstrap = test_df.loc[sampled_indices].reset_index(drop=True)
            
            # Get true labels and predicted probabilities
            y_true_bootstrap = test_df_bootstrap['y_true']
            y_proba_bootstrap = test_df_bootstrap['y_proba']
            
            # Slice-level thresholding using Youden's J statistic
            fpr, tpr, thresholds = roc_curve(y_true_bootstrap, y_proba_bootstrap)
            J = tpr - fpr
            ix = np.argmax(J)
            optimal_slice_threshold = thresholds[ix]
            # Apply optimal slice threshold
            test_df_bootstrap['y_pred_slice'] = (test_df_bootstrap['y_proba'] >= optimal_slice_threshold).astype(int)
            
            # Aggregate predictions per patient
            slice_proportions = test_df_bootstrap.groupby('patient_id')['y_pred_slice'].mean()
            y_true_per_patient_bootstrap = test_df_bootstrap.groupby('patient_id')['y_true'].first()
            
            # Patient-level thresholding using Youden's J statistic
            fpr_p, tpr_p, thresholds_p = roc_curve(y_true_per_patient_bootstrap, slice_proportions)
            J_p = tpr_p - fpr_p
            ix_p = np.argmax(J_p)
            optimal_patient_threshold = thresholds_p[ix_p]
            # Apply optimal patient threshold
            y_pred_per_patient_bootstrap = (slice_proportions >= optimal_patient_threshold).astype(int)
            
            # Compute performance metrics at the patient level
            accuracy = accuracy_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            precision = precision_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap, zero_division=0)
            recall = recall_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            f1 = f1_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            roc_auc = roc_auc_score(y_true_per_patient_bootstrap, slice_proportions)
            
            # Append metrics
            bootstrap_accuracies.append(accuracy)
            bootstrap_precisions.append(precision)
            bootstrap_recalls.append(recall)
            bootstrap_f1s.append(f1)
            bootstrap_roc_aucs.append(roc_auc)
        
        # Compute confidence intervals (e.g., 95% CI)
        def compute_confidence_interval(metric_values):
            sorted_values = np.sort(metric_values)
            lower = np.percentile(sorted_values, 2.5)
            upper = np.percentile(sorted_values, 97.5)
            mean = np.mean(metric_values)
            return mean, lower, upper
        
        accuracy_mean, accuracy_lower, accuracy_upper = compute_confidence_interval(bootstrap_accuracies)
        precision_mean, precision_lower, precision_upper = compute_confidence_interval(bootstrap_precisions)
        recall_mean, recall_lower, recall_upper = compute_confidence_interval(bootstrap_recalls)
        f1_mean, f1_lower, f1_upper = compute_confidence_interval(bootstrap_f1s)
        roc_auc_mean, roc_auc_lower, roc_auc_upper = compute_confidence_interval(bootstrap_roc_aucs)
        
        # Store the bootstrap results
        bootstrap_results_per_patient[dataset_name][classifier_name] = {
            'accuracy': (accuracy_mean, accuracy_lower, accuracy_upper),
            'precision': (precision_mean, precision_lower, precision_upper),
            'recall': (recall_mean, recall_lower, recall_upper),
            'f1': (f1_mean, f1_lower, f1_upper),
            'roc_auc': (roc_auc_mean, roc_auc_lower, roc_auc_upper),
        }
        
        # Print the results
        print(f"\n{classifier_name} Bootstrap Confidence Intervals (Patient-Level):")
        print(f"Accuracy: {accuracy_mean:.4f} (95% CI: {accuracy_lower:.4f} - {accuracy_upper:.4f})")
        print(f"Precision: {precision_mean:.4f} (95% CI: {precision_lower:.4f} - {precision_upper:.4f})")
        print(f"Recall: {recall_mean:.4f} (95% CI: {recall_lower:.4f} - {recall_upper:.4f})")
        print(f"F1 Score: {f1_mean:.4f} (95% CI: {f1_lower:.4f} - {f1_upper:.4f})")
        print(f"ROC AUC: {roc_auc_mean:.4f} (95% CI: {roc_auc_lower:.4f} - {roc_auc_upper:.4f})")
# Out:
# Bootstrapping Test Metrics for 'Combined' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
#
# Logistic Regression Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7440 (95% CI: 0.6111 - 0.8685)
# Precision: 0.4800 (95% CI: 0.2941 - 0.7000)
# Recall: 0.8540 (95% CI: 0.6250 - 1.0000)
# F1 Score: 0.6019 (95% CI: 0.4444 - 0.7368)
# ROC AUC: 0.7891 (95% CI: 0.6730 - 0.9037)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
#
# Random Forest Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7634 (95% CI: 0.6333 - 0.8750)
# Precision: 0.4955 (95% CI: 0.3077 - 0.7000)
# Recall: 0.9092 (95% CI: 0.7143 - 1.0000)
# F1 Score: 0.6340 (95% CI: 0.4706 - 0.7692)
# ROC AUC: 0.8116 (95% CI: 0.7173 - 0.9196)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
#
# XGBoost Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7875 (95% CI: 0.6364 - 0.9233)
# Precision: 0.5467 (95% CI: 0.3333 - 0.8571)
# Recall: 0.8761 (95% CI: 0.6250 - 1.0000)
# F1 Score: 0.6554 (95% CI: 0.5000 - 0.8235)
# ROC AUC: 0.8263 (95% CI: 0.7335 - 0.9430)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
#
# LightGBM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7023 (95% CI: 0.5805 - 0.8333)
# Precision: 0.4337 (95% CI: 0.2857 - 0.5837)
# Recall: 0.9477 (95% CI: 0.7778 - 1.0000)
# F1 Score: 0.5877 (95% CI: 0.4442 - 0.7202)
# ROC AUC: 0.7733 (95% CI: 0.6798 - 0.8750)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
#
# SVM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7659 (95% CI: 0.6111 - 0.9001)
# Precision: 0.5182 (95% CI: 0.2941 - 0.8333)
# Recall: 0.8310 (95% CI: 0.5714 - 1.0000)
# F1 Score: 0.6208 (95% CI: 0.4442 - 0.7778)
# ROC AUC: 0.8049 (95% CI: 0.6840 - 0.9207)
#
# Bootstrapping Test Metrics for 'Clinical' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
#
# Logistic Regression Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7866 (95% CI: 0.6943 - 0.8857)
# Precision: 0.5375 (95% CI: 0.3000 - 0.7507)
# Recall: 0.6625 (95% CI: 0.4286 - 1.0000)
# F1 Score: 0.5814 (95% CI: 0.3997 - 0.7500)
# ROC AUC: 0.7432 (95% CI: 0.6296 - 0.8831)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
#
# Random Forest Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7403 (95% CI: 0.6450 - 0.8333)
# Precision: 0.4605 (95% CI: 0.2727 - 0.6364)
# Recall: 0.6708 (95% CI: 0.4286 - 0.8889)
# F1 Score: 0.5386 (95% CI: 0.3529 - 0.7000)
# ROC AUC: 0.7162 (95% CI: 0.6071 - 0.8360)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3542 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
#
# XGBoost Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7188 (95% CI: 0.4412 - 0.8439)
# Precision: 0.4411 (95% CI: 0.2308 - 0.6667)
# Recall: 0.6009 (95% CI: 0.3333 - 1.0000)
# F1 Score: 0.4904 (95% CI: 0.3158 - 0.6316)
# ROC AUC: 0.6786 (95% CI: 0.5654 - 0.8125)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
#
# LightGBM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7108 (95% CI: 0.4333 - 0.8387)
# Precision: 0.4353 (95% CI: 0.2222 - 0.6250)
# Recall: 0.6491 (95% CI: 0.4279 - 1.0000)
# F1 Score: 0.5038 (95% CI: 0.3333 - 0.6667)
# ROC AUC: 0.6906 (95% CI: 0.5833 - 0.8167)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
#
# SVM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7822 (95% CI: 0.6969 - 0.8750)
# Precision: 0.5198 (95% CI: 0.3000 - 0.7500)
# Recall: 0.6707 (95% CI: 0.4286 - 1.0000)
# F1 Score: 0.5767 (95% CI: 0.3750 - 0.7368)
# ROC AUC: 0.7429 (95% CI: 0.6250 - 0.8662)
#
# Bootstrapping Test Metrics for 'Image' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
#
# Logistic Regression Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7510 (95% CI: 0.4239 - 0.8710)
# Precision: 0.5106 (95% CI: 0.2222 - 0.8008)
# Recall: 0.6063 (95% CI: 0.2857 - 1.0000)
# F1 Score: 0.5246 (95% CI: 0.3242 - 0.6675)
# ROC AUC: 0.6453 (95% CI: 0.5268 - 0.7863)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
#
# Random Forest Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5622 (95% CI: 0.4333 - 0.7576)
# Precision: 0.3413 (95% CI: 0.2174 - 0.5000)
# Recall: 0.9647 (95% CI: 0.7500 - 1.0000)
# F1 Score: 0.4983 (95% CI: 0.3570 - 0.6250)
# ROC AUC: 0.6639 (95% CI: 0.5577 - 0.7662)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
#
# XGBoost Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5982 (95% CI: 0.4375 - 0.8109)
# Precision: 0.3647 (95% CI: 0.2222 - 0.5556)
# Recall: 0.9213 (95% CI: 0.5993 - 1.0000)
# F1 Score: 0.5103 (95% CI: 0.3636 - 0.6250)
# ROC AUC: 0.6656 (95% CI: 0.5339 - 0.8000)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
#
# LightGBM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.6418 (95% CI: 0.4102 - 0.8286)
# Precision: 0.3936 (95% CI: 0.2308 - 0.6250)
# Recall: 0.7854 (95% CI: 0.5000 - 1.0000)
# F1 Score: 0.5023 (95% CI: 0.3683 - 0.6316)
# ROC AUC: 0.6890 (95% CI: 0.5837 - 0.8132)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
#
# SVM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7249 (95% CI: 0.4062 - 0.8611)
# Precision: 0.4774 (95% CI: 0.2308 - 0.8000)
# Recall: 0.6166 (95% CI: 0.3333 - 1.0000)
# F1 Score: 0.5073 (95% CI: 0.3333 - 0.6667)
# ROC AUC: 0.6482 (95% CI: 0.5317 - 0.7863)
#
# Bootstrapping Test Metrics for 'RadiomicsOnly' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
#
# Logistic Regression Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7577 (95% CI: 0.3143 - 0.8571)
# Precision: 0.0067 (95% CI: 0.0000 - 0.1923)
# Recall: 0.0289 (95% CI: 0.0000 - 0.8571)
# F1 Score: 0.0108 (95% CI: 0.0000 - 0.3125)
# ROC AUC: 0.5010 (95% CI: 0.5000 - 0.5027)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
#
# Random Forest Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5326 (95% CI: 0.3512 - 0.8235)
# Precision: 0.3526 (95% CI: 0.2000 - 1.0000)
# Recall: 0.7793 (95% CI: 0.1429 - 1.0000)
# F1 Score: 0.4226 (95% CI: 0.2500 - 0.5455)
# ROC AUC: 0.6177 (95% CI: 0.5471 - 0.7167)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
#
# XGBoost Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7103 (95% CI: 0.2059 - 0.8529)
# Precision: 0.0269 (95% CI: 0.0000 - 0.2434)
# Recall: 0.1168 (95% CI: 0.0000 - 1.0000)
# F1 Score: 0.0417 (95% CI: 0.0000 - 0.3889)
# ROC AUC: 0.5038 (95% CI: 0.5000 - 0.5400)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
#
# LightGBM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5179 (95% CI: 0.3636 - 0.6364)
# Precision: 0.3120 (95% CI: 0.1905 - 0.4286)
# Recall: 0.9162 (95% CI: 0.8000 - 1.0000)
# F1 Score: 0.4618 (95% CI: 0.3125 - 0.5882)
# ROC AUC: 0.6580 (95% CI: 0.5750 - 0.7420)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
#
# SVM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7733 (95% CI: 0.6875 - 0.8571)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Bootstrapping Test Metrics for 'ClinicalRadiomics' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
#
# Logistic Regression Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5897 (95% CI: 0.2352 - 0.8529)
# Precision: 0.4613 (95% CI: 0.1667 - 1.0000)
# Recall: 0.5642 (95% CI: 0.1000 - 1.0000)
# F1 Score: 0.3498 (95% CI: 0.1818 - 0.5000)
# ROC AUC: 0.5833 (95% CI: 0.5179 - 0.6886)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
#
# Random Forest Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5060 (95% CI: 0.2702 - 0.8183)
# Precision: 0.3282 (95% CI: 0.1786 - 0.6000)
# Recall: 0.7686 (95% CI: 0.2217 - 1.0000)
# F1 Score: 0.4043 (95% CI: 0.2630 - 0.5263)
# ROC AUC: 0.5979 (95% CI: 0.5385 - 0.6810)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.2857 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
#
# XGBoost Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5803 (95% CI: 0.2188 - 0.8667)
# Precision: 0.5713 (95% CI: 0.1026 - 1.0000)
# Recall: 0.5213 (95% CI: 0.0833 - 1.0000)
# F1 Score: 0.3036 (95% CI: 0.1532 - 0.4668)
# ROC AUC: 0.5646 (95% CI: 0.5072 - 0.6538)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
#
# LightGBM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5141 (95% CI: 0.3784 - 0.8065)
# Precision: 0.2960 (95% CI: 0.1667 - 0.5000)
# Recall: 0.7877 (95% CI: 0.1424 - 1.0000)
# F1 Score: 0.4118 (95% CI: 0.2000 - 0.5455)
# ROC AUC: 0.6091 (95% CI: 0.5129 - 0.7201)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
#
# SVM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7727 (95% CI: 0.6857 - 0.8572)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Bootstrapping Test Metrics for 'CombinedRadiomics' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
#
# Logistic Regression Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5361 (95% CI: 0.3636 - 0.8649)
# Precision: 0.3742 (95% CI: 0.1852 - 1.0000)
# Recall: 0.8760 (95% CI: 0.2857 - 1.0000)
# F1 Score: 0.4606 (95% CI: 0.3125 - 0.5882)
# ROC AUC: 0.6555 (95% CI: 0.5962 - 0.7242)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
#
# Random Forest Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7493 (95% CI: 0.3714 - 0.8889)
# Precision: 0.5778 (95% CI: 0.2067 - 1.0000)
# Recall: 0.4731 (95% CI: 0.2000 - 1.0000)
# F1 Score: 0.4579 (95% CI: 0.2759 - 0.6250)
# ROC AUC: 0.6542 (95% CI: 0.5536 - 0.7610)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3661 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
#
# XGBoost Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7350 (95% CI: 0.5143 - 0.8571)
# Precision: 0.1101 (95% CI: 0.0000 - 0.5000)
# Recall: 0.0941 (95% CI: 0.0000 - 0.5721)
# F1 Score: 0.0839 (95% CI: 0.0000 - 0.3478)
# ROC AUC: 0.5108 (95% CI: 0.5000 - 0.5641)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
#
# LightGBM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7904 (95% CI: 0.6450 - 0.8857)
# Precision: 0.5812 (95% CI: 0.2500 - 1.0000)
# Recall: 0.4365 (95% CI: 0.1667 - 0.7500)
# F1 Score: 0.4787 (95% CI: 0.2500 - 0.6667)
# ROC AUC: 0.6666 (95% CI: 0.5481 - 0.7905)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
#
# SVM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7731 (95% CI: 0.6875 - 0.8530)
# Precision: 0.0000 (95% CI: 0.0000 - 0.0000)
# Recall: 0.0000 (95% CI: 0.0000 - 0.0000)
# F1 Score: 0.0000 (95% CI: 0.0000 - 0.0000)
# ROC AUC: 0.5000 (95% CI: 0.5000 - 0.5000)
#
# Bootstrapping Test Metrics for 'CombinedSelected' Dataset
#
# Classifier: Logistic Regression
#
# Applying SMOTE to balance the classes in the training data...
#
# Logistic Regression Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7534 (95% CI: 0.4571 - 0.9091)
# Precision: 0.5246 (95% CI: 0.2590 - 0.8571)
# Recall: 0.7423 (95% CI: 0.5000 - 1.0000)
# F1 Score: 0.5849 (95% CI: 0.4000 - 0.7619)
# ROC AUC: 0.7249 (95% CI: 0.6025 - 0.8612)
#
# Classifier: Random Forest
#
# Applying SMOTE to balance the classes in the training data...
#
# Random Forest Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7590 (95% CI: 0.6174 - 0.8667)
# Precision: 0.4948 (95% CI: 0.3076 - 0.7143)
# Recall: 0.7513 (95% CI: 0.5000 - 1.0000)
# F1 Score: 0.5862 (95% CI: 0.4211 - 0.7273)
# ROC AUC: 0.7430 (95% CI: 0.6164 - 0.8691)
#
# Classifier: XGBoost
# Computed scale_pos_weight: 3.3570 for XGBoost
#
# Applying SMOTE to balance the classes in the training data...
#
# XGBoost Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7799 (95% CI: 0.6765 - 0.9000)
# Precision: 0.5215 (95% CI: 0.3333 - 0.7778)
# Recall: 0.7400 (95% CI: 0.5000 - 1.0000)
# F1 Score: 0.6024 (95% CI: 0.4286 - 0.7692)
# ROC AUC: 0.7359 (95% CI: 0.6000 - 0.8969)
#
# Classifier: LightGBM
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Applying SMOTE to balance the classes in the training data...
#
# LightGBM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.8161 (95% CI: 0.6571 - 0.9394)
# Precision: 0.6530 (95% CI: 0.3077 - 1.0000)
# Recall: 0.6774 (95% CI: 0.4286 - 1.0000)
# F1 Score: 0.6320 (95% CI: 0.4284 - 0.8235)
# ROC AUC: 0.7346 (95% CI: 0.5876 - 0.8852)
#
# Classifier: SVM
#
# Applying SMOTE to balance the classes in the training data...
#
# SVM Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7656 (95% CI: 0.6127 - 0.9062)
# Precision: 0.5246 (95% CI: 0.3076 - 1.0000)
# Recall: 0.7323 (95% CI: 0.4440 - 1.0000)
# F1 Score: 0.5880 (95% CI: 0.4211 - 0.7500)
# ROC AUC: 0.7313 (95% CI: 0.6093 - 0.8601)

# %%
# Prepare the base classifiers with their best hyperparameters
# Import necessary libraries
from sklearn.ensemble import StackingClassifier, VotingClassifier
from sklearn.base import clone
# Prepare the base classifiers with their best hyperparameters
def get_best_classifier(classifier_name, dataset_name):
    # Retrieve the best hyperparameters from nested_cv_results
    nested_results = nested_cv_results[dataset_name]
    cv_results_all = nested_results['cv_results_all']
    cv_results = cv_results_all[classifier_name]
    
    # Find the hyperparameters with the best mean_test_score
    max_mean_test_score = cv_results['mean_test_score'].max()
    best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
    
    # If multiple rows have the same max score, pick the first one
    best_row = best_rows.iloc[0]
    
    # Extract the best hyperparameters from the pipeline parameters
    best_params = best_row['params']
    
    # The params are for the entire pipeline; extract classifier's hyperparameters
    classifier_params = {}
    for param_name, param_value in best_params.items():
        if param_name.startswith('classifier__'):
            # Remove 'classifier__' prefix to get the parameter name
            param_short = param_name.replace('classifier__', '')
            classifier_params[param_short] = param_value
    
    # Get the default classifier with default parameters
    default_classifier = classifiers[classifier_name]
    
    # Clone the default classifier to avoid modifying the original
    classifier = clone(default_classifier)
    
    # Update the classifier's parameters with the best hyperparameters
    classifier.set_params(**classifier_params)

    # **Compute scale_pos_weight for XGBoost and LightGBM**
    if classifier_name == 'XGBoost' or classifier_name == 'LightGBM':
        scale_pos_weight = (y_train_full == 0).sum() / (y_train_full == 1).sum()
        print(f"Computed scale_pos_weight: {scale_pos_weight:.4f} for {classifier_name}")
        classifier.set_params(scale_pos_weight=scale_pos_weight)
    
    # Handle compatibility between solver and penalty for Logistic Regression
    if classifier_name == 'Logistic Regression':
        penalty = classifier.get_params().get('penalty', 'l2')
        solver = classifier.get_params().get('solver', 'lbfgs')
        if penalty == 'l1' and solver not in ['liblinear', 'saga']:
            # Change solver to 'liblinear' if penalty is 'l1'
            classifier.set_params(solver='liblinear')
            print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
        elif penalty == 'elasticnet' and solver != 'saga':
            # 'elasticnet' penalty requires 'saga' solver
            classifier.set_params(solver='saga')
            print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
        elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
            # Dual formulation is only implemented for l2 penalty with liblinear solver
            classifier.set_params(dual=True)
        else:
            # Ensure dual is False for other solvers
            classifier.set_params(dual=False)
    return classifier

# %%
# Function: Create the ensemble classifiers
def create_ensemble_classifiers(dataset_name):
    # Prepare base classifiers
    base_classifiers = []
    classifier_names = ['Logistic Regression', 'Random Forest', 'XGBoost', 'LightGBM']
    
    for clf_name in classifier_names:
        clf = get_best_classifier(clf_name, dataset_name)
        base_classifiers.append((clf_name.lower().replace(' ', '_'), clf))
    
    # Create the stacking classifier
    stacking_classifier = StackingClassifier(
        estimators=base_classifiers,
        final_estimator=LogisticRegression(random_state=42),
        passthrough=False,
        cv=5,
        n_jobs=-1
    )
    
    # Create the voting classifier
    voting_classifier = VotingClassifier(
        estimators=base_classifiers,
        voting='soft',  # Use 'hard' for majority voting
        n_jobs=-1
    )
    
    return stacking_classifier, voting_classifier

# %%
# Retrain and test on Ensemble Classifiers with Slice-Level and Patient-Level Thresholding

# Initialize a dictionary to store test results
test_results_ensemble = {}

for dataset_name in data_splits.keys():
    print(f"\nEvaluating Ensemble Classifiers on '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_train_full = data['X_train_full']
    y_train_full = data['y_train_full']
    X_test_full = data['X_test_full']
    y_test = data['y_test']
    patient_ids_test = data['patient_ids_test'].reset_index(drop=True)
    
    # Create a DataFrame for test data
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test.values
    test_df['patient_id'] = patient_ids_test.values
    
    # Get per-patient true labels (assuming all slices of a patient have the same label)
    y_true_per_patient = test_df.groupby('patient_id')['y_true'].first()
    
    # Create ensemble classifiers
    stacking_classifier, voting_classifier = create_ensemble_classifiers(dataset_name)
    
    ensemble_classifiers = {
        'Stacking Classifier': stacking_classifier,
        'Voting Classifier': voting_classifier
    }
    
    for ensemble_name, ensemble_clf in ensemble_classifiers.items():
        print(f"\nClassifier: {ensemble_name}")
        
        # Handle classifiers that do not support predict_proba
        if not hasattr(ensemble_clf, "predict_proba"):
            print(f"Classifier '{ensemble_name}' does not support probability estimates. Skipping.")
            continue
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', ensemble_clf)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Predict probabilities on the test set
        y_proba = pipeline.predict_proba(X_test_full)[:, 1]
        
        # Add predicted probabilities to test_df
        test_df[f'{ensemble_name}_proba'] = y_proba
        
        # Compute optimal slice_threshold using Youden's J
        fpr, tpr, thresholds = roc_curve(y_test, y_proba)
        J = tpr - fpr
        ix = np.argmax(J)
        slice_threshold = thresholds[ix]
        print(f"Optimal Slice Threshold (Youden's J): {slice_threshold:.4f}")
        
        # Assign per-slice predictions based on slice_threshold
        test_df[f'{ensemble_name}_pred_slice'] = (y_proba >= slice_threshold).astype(int)
        
        # Aggregate predictions per patient
        slice_proportions = test_df.groupby('patient_id')[f'{ensemble_name}_pred_slice'].mean()
        
        # Compute patient_threshold using Youden's J on slice proportions
        fpr_p, tpr_p, thresholds_p = roc_curve(y_true_per_patient, slice_proportions)
        J_p = tpr_p - fpr_p
        ix_p = np.argmax(J_p)
        patient_threshold = thresholds_p[ix_p]
        print(f"Optimal Patient Threshold (Youden's J): {patient_threshold:.4f}")
        
        # Assign patient-level predictions based on patient_threshold
        y_pred_per_patient = (slice_proportions >= patient_threshold).astype(int)
        
        # Align the true labels
        y_true = y_true_per_patient
        
        # Compute performance metrics
        accuracy = accuracy_score(y_true, y_pred_per_patient)
        precision = precision_score(y_true, y_pred_per_patient, zero_division=0)
        recall = recall_score(y_true, y_pred_per_patient)
        f1 = f1_score(y_true, y_pred_per_patient)
        try:
            roc_auc = roc_auc_score(y_true, slice_proportions)  # Using slice proportions for ROC AUC
        except ValueError:
            roc_auc = None  # Handle cases where ROC AUC is not defined
        
        conf_matrix = confusion_matrix(y_true, y_pred_per_patient)
        class_report = classification_report(y_true, y_pred_per_patient, zero_division=0)
        
        # Store the results
        test_results_ensemble[dataset_name] = test_results_ensemble.get(dataset_name, {})
        test_results_ensemble[dataset_name][ensemble_name + ' (Patient Aggregated)'] = {
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1': f1,
            'roc_auc': roc_auc,
            'confusion_matrix': conf_matrix,
            'classification_report': class_report
        }
        
        # Print the results
        print(f"\nAggregated Test Results for {ensemble_name} on {dataset_name} Dataset:")
        print(f"Accuracy: {accuracy:.4f}")
        print(f"Precision: {precision:.4f}")
        print(f"Recall: {recall:.4f}")
        print(f"F1 Score: {f1:.4f}")
        if roc_auc is not None:
            print(f"ROC AUC Score: {roc_auc:.4f}")
        print("Confusion Matrix:")
        print(conf_matrix)
        print("Classification Report:")
        print(class_report)
# Out:
# Evaluating Ensemble Classifiers on 'Combined' Dataset
# Computed scale_pos_weight: 3.3661 for XGBoost
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.0490
# Optimal Patient Threshold (Youden's J): 0.7000
#
# Aggregated Test Results for Stacking Classifier on Combined Dataset:
# Accuracy: 0.7170
# Precision: 0.4444
# Recall: 1.0000
# F1 Score: 0.6154
# ROC AUC Score: 0.7866
# Confusion Matrix:
# [[26 15]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.63      0.78        41
#            1       0.44      1.00      0.62        12
#
#     accuracy                           0.72        53
#    macro avg       0.72      0.82      0.70        53
# weighted avg       0.87      0.72      0.74        53
#
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.6456
# Optimal Patient Threshold (Youden's J): 0.3000
#
# Aggregated Test Results for Voting Classifier on Combined Dataset:
# Accuracy: 0.7925
# Precision: 0.5238
# Recall: 0.9167
# F1 Score: 0.6667
# ROC AUC Score: 0.8486
# Confusion Matrix:
# [[31 10]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.76      0.85        41
#            1       0.52      0.92      0.67        12
#
#     accuracy                           0.79        53
#    macro avg       0.75      0.84      0.76        53
# weighted avg       0.87      0.79      0.81        53
#
#
# Evaluating Ensemble Classifiers on 'Clinical' Dataset
# Computed scale_pos_weight: 3.3542 for XGBoost
# Computed scale_pos_weight: 3.3542 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.4592
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Stacking Classifier on Clinical Dataset:
# Accuracy: 0.7358
# Precision: 0.4375
# Recall: 0.5833
# F1 Score: 0.5000
# ROC AUC Score: 0.6819
# Confusion Matrix:
# [[32  9]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        41
#            1       0.44      0.58      0.50        12
#
#     accuracy                           0.74        53
#    macro avg       0.65      0.68      0.66        53
# weighted avg       0.77      0.74      0.75        53
#
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5805
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Voting Classifier on Clinical Dataset:
# Accuracy: 0.7736
# Precision: 0.5000
# Recall: 0.5833
# F1 Score: 0.5385
# ROC AUC Score: 0.7063
# Confusion Matrix:
# [[34  7]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85        41
#            1       0.50      0.58      0.54        12
#
#     accuracy                           0.77        53
#    macro avg       0.69      0.71      0.69        53
# weighted avg       0.79      0.77      0.78        53
#
#
# Evaluating Ensemble Classifiers on 'Image' Dataset
# Computed scale_pos_weight: 3.3661 for XGBoost
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.1339
# Optimal Patient Threshold (Youden's J): 0.8000
#
# Aggregated Test Results for Stacking Classifier on Image Dataset:
# Accuracy: 0.6226
# Precision: 0.3667
# Recall: 0.9167
# F1 Score: 0.5238
# ROC AUC Score: 0.6514
# Confusion Matrix:
# [[22 19]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.54      0.69        41
#            1       0.37      0.92      0.52        12
#
#     accuracy                           0.62        53
#    macro avg       0.66      0.73      0.61        53
# weighted avg       0.82      0.62      0.65        53
#
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3300
# Optimal Patient Threshold (Youden's J): 0.8000
#
# Aggregated Test Results for Voting Classifier on Image Dataset:
# Accuracy: 0.5472
# Precision: 0.3333
# Recall: 1.0000
# F1 Score: 0.5000
# ROC AUC Score: 0.6311
# Confusion Matrix:
# [[17 24]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.41      0.59        41
#            1       0.33      1.00      0.50        12
#
#     accuracy                           0.55        53
#    macro avg       0.67      0.71      0.54        53
# weighted avg       0.85      0.55      0.57        53
#
#
# Evaluating Ensemble Classifiers on 'RadiomicsOnly' Dataset
# Computed scale_pos_weight: 3.2857 for XGBoost
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.1822
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Stacking Classifier on RadiomicsOnly Dataset:
# Accuracy: 0.4151
# Precision: 0.2683
# Recall: 0.9167
# F1 Score: 0.4151
# ROC AUC Score: 0.5925
# Confusion Matrix:
# [[11 30]
#  [ 1 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.27      0.42        41
#            1       0.27      0.92      0.42        12
#
#     accuracy                           0.42        53
#    macro avg       0.59      0.59      0.42        53
# weighted avg       0.77      0.42      0.42        53
#
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.3506
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Voting Classifier on RadiomicsOnly Dataset:
# Accuracy: 0.3019
# Precision: 0.2449
# Recall: 1.0000
# F1 Score: 0.3934
# ROC AUC Score: 0.5488
# Confusion Matrix:
# [[ 4 37]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.10      0.18        41
#            1       0.24      1.00      0.39        12
#
#     accuracy                           0.30        53
#    macro avg       0.62      0.55      0.29        53
# weighted avg       0.83      0.30      0.23        53
#
#
# Evaluating Ensemble Classifiers on 'ClinicalRadiomics' Dataset
# Computed scale_pos_weight: 3.2857 for XGBoost
# Computed scale_pos_weight: 3.2857 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.0814
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Stacking Classifier on ClinicalRadiomics Dataset:
# Accuracy: 0.3208
# Precision: 0.2500
# Recall: 1.0000
# F1 Score: 0.4000
# ROC AUC Score: 0.5610
# Confusion Matrix:
# [[ 5 36]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.12      0.22        41
#            1       0.25      1.00      0.40        12
#
#     accuracy                           0.32        53
#    macro avg       0.62      0.56      0.31        53
# weighted avg       0.83      0.32      0.26        53
#
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.2281
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Voting Classifier on ClinicalRadiomics Dataset:
# Accuracy: 0.3396
# Precision: 0.2553
# Recall: 1.0000
# F1 Score: 0.4068
# ROC AUC Score: 0.5732
# Confusion Matrix:
# [[ 6 35]
#  [ 0 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.15      0.26        41
#            1       0.26      1.00      0.41        12
#
#     accuracy                           0.34        53
#    macro avg       0.63      0.57      0.33        53
# weighted avg       0.83      0.34      0.29        53
#
#
# Evaluating Ensemble Classifiers on 'CombinedRadiomics' Dataset
# Computed scale_pos_weight: 3.3661 for XGBoost
# Computed scale_pos_weight: 3.3661 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.0072
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Stacking Classifier on CombinedRadiomics Dataset:
# Accuracy: 0.7170
# Precision: 0.4000
# Recall: 0.5000
# F1 Score: 0.4444
# ROC AUC Score: 0.6402
# Confusion Matrix:
# [[32  9]
#  [ 6  6]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81        41
#            1       0.40      0.50      0.44        12
#
#     accuracy                           0.72        53
#    macro avg       0.62      0.64      0.63        53
# weighted avg       0.74      0.72      0.73        53
#
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.2089
# Optimal Patient Threshold (Youden's J): 1.0000
#
# Aggregated Test Results for Voting Classifier on CombinedRadiomics Dataset:
# Accuracy: 0.6981
# Precision: 0.3889
# Recall: 0.5833
# F1 Score: 0.4667
# ROC AUC Score: 0.6575
# Confusion Matrix:
# [[30 11]
#  [ 5  7]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79        41
#            1       0.39      0.58      0.47        12
#
#     accuracy                           0.70        53
#    macro avg       0.62      0.66      0.63        53
# weighted avg       0.75      0.70      0.72        53
#
#
# Evaluating Ensemble Classifiers on 'CombinedSelected' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.0450
# Optimal Patient Threshold (Youden's J): 0.5000
#
# Aggregated Test Results for Stacking Classifier on CombinedSelected Dataset:
# Accuracy: 0.7358
# Precision: 0.4500
# Recall: 0.7500
# F1 Score: 0.5625
# ROC AUC Score: 0.7205
# Confusion Matrix:
# [[30 11]
#  [ 3  9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81        41
#            1       0.45      0.75      0.56        12
#
#     accuracy                           0.74        53
#    macro avg       0.68      0.74      0.69        53
# weighted avg       0.81      0.74      0.75        53
#
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
# Optimal Slice Threshold (Youden's J): 0.5038
# Optimal Patient Threshold (Youden's J): 0.7000
#
# Aggregated Test Results for Voting Classifier on CombinedSelected Dataset:
# Accuracy: 0.8113
# Precision: 0.5714
# Recall: 0.6667
# F1 Score: 0.6154
# ROC AUC Score: 0.7652
# Confusion Matrix:
# [[35  6]
#  [ 4  8]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88        41
#            1       0.57      0.67      0.62        12
#
#     accuracy                           0.81        53
#    macro avg       0.73      0.76      0.75        53
# weighted avg       0.82      0.81      0.82        53

# %%
# Bootstrap Confidence Intervals for Ensemble Classifiers

import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve

# Number of bootstrap iterations
n_bootstraps = 1000
rng = np.random.RandomState(seed=42)  # For reproducibility

# Initialize a dictionary to store bootstrap results
bootstrap_results_ensemble = {}

for dataset_name in data_splits.keys():
    print(f"\nBootstrapping Test Metrics for Ensemble Classifiers on '{dataset_name}' Dataset")
    
    # Retrieve data splits for the current dataset
    data = data_splits[dataset_name]
    X_test_full = data['X_test_full'].reset_index(drop=True)
    y_test = data['y_test'].reset_index(drop=True)
    patient_ids_test = data['patient_ids_test'].reset_index(drop=True)
    
    # Combine test data into a single DataFrame
    test_df = X_test_full.copy()
    test_df['y_true'] = y_test
    test_df['patient_id'] = patient_ids_test
    
    # Get unique patient IDs
    unique_patient_ids = test_df['patient_id'].unique()
    
    # Create ensemble classifiers
    stacking_classifier, voting_classifier = create_ensemble_classifiers(dataset_name)
    
    ensemble_classifiers = {
        'Stacking Classifier': stacking_classifier,
        'Voting Classifier': voting_classifier
    }
    
    for ensemble_name, ensemble_clf in ensemble_classifiers.items():
        print(f"\nClassifier: {ensemble_name}")
        
        # Handle classifiers that do not support predict_proba
        if not hasattr(ensemble_clf, "predict_proba"):
            print(f"Classifier '{ensemble_name}' does not support probability estimates. Skipping.")
            continue
        
        # Apply SMOTE to training data only
        print("\nApplying SMOTE to balance the classes in the training data...")
        smote = SMOTE(random_state=42)
        X_train_resampled, y_train_resampled = smote.fit_resample(data['X_train_full'], data['y_train_full'])
        
        # Define the pipeline without SMOTE
        pipeline = Pipeline(steps=[
            ('scaler', MinMaxScaler()),
            ('classifier', ensemble_clf)
        ])
        
        # Fit the pipeline on the entire training set
        pipeline.fit(X_train_resampled, y_train_resampled)
        
        # Compute predicted probabilities on the full test set
        y_proba_full = pipeline.predict_proba(X_test_full)[:, 1]
        
        # Add predicted probabilities to test_df
        test_df['y_proba'] = y_proba_full
        
        # Initialize lists to store bootstrap metrics
        bootstrap_accuracies = []
        bootstrap_precisions = []
        bootstrap_recalls = []
        bootstrap_f1s = []
        bootstrap_roc_aucs = []
        
        # Perform bootstrap resampling
        for i in range(n_bootstraps):
            # Sample patient IDs with replacement
            sampled_patient_ids = rng.choice(unique_patient_ids, size=len(unique_patient_ids), replace=True)
            
            # Get the indices of the slices corresponding to the sampled patient IDs
            sampled_indices = test_df[test_df['patient_id'].isin(sampled_patient_ids)].index
            
            # Create bootstrap sample
            test_df_bootstrap = test_df.loc[sampled_indices].reset_index(drop=True)
            
            # Get true labels and predicted probabilities
            y_true_bootstrap = test_df_bootstrap['y_true']
            y_proba_bootstrap = test_df_bootstrap['y_proba']
            
            # Slice-level thresholding using Youden's J statistic
            fpr, tpr, thresholds = roc_curve(y_true_bootstrap, y_proba_bootstrap)
            J = tpr - fpr
            ix = np.argmax(J)
            optimal_slice_threshold = thresholds[ix]
            # Apply optimal slice threshold
            test_df_bootstrap['y_pred_slice'] = (test_df_bootstrap['y_proba'] >= optimal_slice_threshold).astype(int)
            
            # Aggregate predictions per patient
            slice_proportions = test_df_bootstrap.groupby('patient_id')['y_pred_slice'].mean()
            y_true_per_patient_bootstrap = test_df_bootstrap.groupby('patient_id')['y_true'].first()
            
            # Patient-level thresholding using Youden's J statistic
            fpr_p, tpr_p, thresholds_p = roc_curve(y_true_per_patient_bootstrap, slice_proportions)
            J_p = tpr_p - fpr_p
            ix_p = np.argmax(J_p)
            optimal_patient_threshold = thresholds_p[ix_p]
            # Apply optimal patient threshold
            y_pred_per_patient_bootstrap = (slice_proportions >= optimal_patient_threshold).astype(int)
            
            # Compute performance metrics at the patient level
            accuracy = accuracy_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            precision = precision_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap, zero_division=0)
            recall = recall_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            f1 = f1_score(y_true_per_patient_bootstrap, y_pred_per_patient_bootstrap)
            roc_auc = roc_auc_score(y_true_per_patient_bootstrap, slice_proportions)
            
            # Append metrics
            bootstrap_accuracies.append(accuracy)
            bootstrap_precisions.append(precision)
            bootstrap_recalls.append(recall)
            bootstrap_f1s.append(f1)
            bootstrap_roc_aucs.append(roc_auc)
        
        # Compute confidence intervals (e.g., 95% CI)
        def compute_confidence_interval(metric_values):
            sorted_values = np.sort(metric_values)
            lower = np.percentile(sorted_values, 2.5)
            upper = np.percentile(sorted_values, 97.5)
            mean = np.mean(metric_values)
            return mean, lower, upper
        
        accuracy_mean, accuracy_lower, accuracy_upper = compute_confidence_interval(bootstrap_accuracies)
        precision_mean, precision_lower, precision_upper = compute_confidence_interval(bootstrap_precisions)
        recall_mean, recall_lower, recall_upper = compute_confidence_interval(bootstrap_recalls)
        f1_mean, f1_lower, f1_upper = compute_confidence_interval(bootstrap_f1s)
        roc_auc_mean, roc_auc_lower, roc_auc_upper = compute_confidence_interval(bootstrap_roc_aucs)
        
        # Store the bootstrap results
        bootstrap_results_ensemble[dataset_name] = bootstrap_results_ensemble.get(dataset_name, {})
        bootstrap_results_ensemble[dataset_name][ensemble_name] = {
            'accuracy': (accuracy_mean, accuracy_lower, accuracy_upper),
            'precision': (precision_mean, precision_lower, precision_upper),
            'recall': (recall_mean, recall_lower, recall_upper),
            'f1': (f1_mean, f1_lower, f1_upper),
            'roc_auc': (roc_auc_mean, roc_auc_lower, roc_auc_upper),
        }
        
        # Print the results
        print(f"\n{ensemble_name} Bootstrap Confidence Intervals (Patient-Level):")
        print(f"Accuracy: {accuracy_mean:.4f} (95% CI: {accuracy_lower:.4f} - {accuracy_upper:.4f})")
        print(f"Precision: {precision_mean:.4f} (95% CI: {precision_lower:.4f} - {precision_upper:.4f})")
        print(f"Recall: {recall_mean:.4f} (95% CI: {recall_lower:.4f} - {recall_upper:.4f})")
        print(f"F1 Score: {f1_mean:.4f} (95% CI: {f1_lower:.4f} - {f1_upper:.4f})")
        print(f"ROC AUC: {roc_auc_mean:.4f} (95% CI: {roc_auc_lower:.4f} - {roc_auc_upper:.4f})")
# Out:
# Bootstrapping Test Metrics for Ensemble Classifiers on 'Combined' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Stacking Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7574 (95% CI: 0.6471 - 0.8750)
# Precision: 0.4888 (95% CI: 0.3333 - 0.6923)
# Recall: 0.9671 (95% CI: 0.8000 - 1.0000)
# F1 Score: 0.6421 (95% CI: 0.5000 - 0.7826)
# ROC AUC: 0.8136 (95% CI: 0.7199 - 0.9143)
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Voting Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7795 (95% CI: 0.6667 - 0.8824)
# Precision: 0.5138 (95% CI: 0.3333 - 0.7143)
# Recall: 0.9105 (95% CI: 0.7500 - 1.0000)
# F1 Score: 0.6499 (95% CI: 0.4706 - 0.8000)
# ROC AUC: 0.8286 (95% CI: 0.7057 - 0.9421)
#
# Bootstrapping Test Metrics for Ensemble Classifiers on 'Clinical' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Stacking Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7353 (95% CI: 0.5172 - 0.8439)
# Precision: 0.4534 (95% CI: 0.2308 - 0.6667)
# Recall: 0.6140 (95% CI: 0.3750 - 1.0000)
# F1 Score: 0.5087 (95% CI: 0.3077 - 0.6667)
# ROC AUC: 0.6935 (95% CI: 0.5721 - 0.8149)
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Voting Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7609 (95% CI: 0.4857 - 0.8571)
# Precision: 0.4952 (95% CI: 0.2500 - 0.7143)
# Recall: 0.5970 (95% CI: 0.3750 - 1.0000)
# F1 Score: 0.5289 (95% CI: 0.3333 - 0.6667)
# ROC AUC: 0.7042 (95% CI: 0.5866 - 0.8286)
#
# Bootstrapping Test Metrics for Ensemble Classifiers on 'Image' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Stacking Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.5817 (95% CI: 0.4375 - 0.7242)
# Precision: 0.3501 (95% CI: 0.2273 - 0.4707)
# Recall: 0.9377 (95% CI: 0.7494 - 1.0000)
# F1 Score: 0.5040 (95% CI: 0.3702 - 0.6207)
# ROC AUC: 0.6678 (95% CI: 0.5600 - 0.7867)
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Voting Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.6271 (95% CI: 0.4642 - 0.8529)
# Precision: 0.3988 (95% CI: 0.2307 - 0.7004)
# Recall: 0.8907 (95% CI: 0.5000 - 1.0000)
# F1 Score: 0.5249 (95% CI: 0.3749 - 0.6667)
# ROC AUC: 0.6633 (95% CI: 0.5543 - 0.8014)
#
# Bootstrapping Test Metrics for Ensemble Classifiers on 'RadiomicsOnly' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Stacking Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.4767 (95% CI: 0.3056 - 0.8066)
# Precision: 0.3096 (95% CI: 0.1874 - 0.5042)
# Recall: 0.8542 (95% CI: 0.1429 - 1.0000)
# F1 Score: 0.4184 (95% CI: 0.2222 - 0.5295)
# ROC AUC: 0.6078 (95% CI: 0.5408 - 0.7000)
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Voting Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.3222 (95% CI: 0.2187 - 0.5000)
# Precision: 0.2449 (95% CI: 0.1429 - 0.3333)
# Recall: 0.9799 (95% CI: 0.7143 - 1.0000)
# F1 Score: 0.3895 (95% CI: 0.2498 - 0.5000)
# ROC AUC: 0.5544 (95% CI: 0.5185 - 0.5962)
#
# Bootstrapping Test Metrics for Ensemble Classifiers on 'ClinicalRadiomics' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Stacking Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.4405 (95% CI: 0.2500 - 0.8388)
# Precision: 0.3530 (95% CI: 0.1667 - 1.0000)
# Recall: 0.8195 (95% CI: 0.1111 - 1.0000)
# F1 Score: 0.3744 (95% CI: 0.2000 - 0.5128)
# ROC AUC: 0.5725 (95% CI: 0.5357 - 0.6401)
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Voting Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.4269 (95% CI: 0.2581 - 0.8438)
# Precision: 0.3278 (95% CI: 0.1665 - 1.0000)
# Recall: 0.8680 (95% CI: 0.1250 - 1.0000)
# F1 Score: 0.3890 (95% CI: 0.2000 - 0.5143)
# ROC AUC: 0.5809 (95% CI: 0.5370 - 0.6400)
#
# Bootstrapping Test Metrics for Ensemble Classifiers on 'CombinedRadiomics' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Stacking Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.6833 (95% CI: 0.3548 - 0.8486)
# Precision: 0.4410 (95% CI: 0.2143 - 0.7143)
# Recall: 0.6635 (95% CI: 0.3750 - 1.0000)
# F1 Score: 0.4927 (95% CI: 0.3426 - 0.6667)
# ROC AUC: 0.6781 (95% CI: 0.5952 - 0.7933)
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Voting Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.6864 (95% CI: 0.3610 - 0.8485)
# Precision: 0.4315 (95% CI: 0.2083 - 0.6667)
# Recall: 0.6689 (95% CI: 0.3750 - 1.0000)
# F1 Score: 0.4960 (95% CI: 0.3426 - 0.6364)
# ROC AUC: 0.6814 (95% CI: 0.5926 - 0.7950)
#
# Bootstrapping Test Metrics for Ensemble Classifiers on 'CombinedSelected' Dataset
# Computed scale_pos_weight: 3.3570 for XGBoost
# Computed scale_pos_weight: 3.3570 for LightGBM
#
# Classifier: Stacking Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Stacking Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.7626 (95% CI: 0.6667 - 0.8667)
# Precision: 0.4930 (95% CI: 0.3077 - 0.7143)
# Recall: 0.7445 (95% CI: 0.5542 - 1.0000)
# F1 Score: 0.5847 (95% CI: 0.4211 - 0.7273)
# ROC AUC: 0.7279 (95% CI: 0.6040 - 0.8704)
#
# Classifier: Voting Classifier
#
# Applying SMOTE to balance the classes in the training data...
#
# Voting Classifier Bootstrap Confidence Intervals (Patient-Level):
# Accuracy: 0.8063 (95% CI: 0.6969 - 0.9091)
# Precision: 0.5804 (95% CI: 0.3333 - 0.8333)
# Recall: 0.7141 (95% CI: 0.5000 - 1.0000)
# F1 Score: 0.6257 (95% CI: 0.4444 - 0.7778)
# ROC AUC: 0.7667 (95% CI: 0.6454 - 0.9239)

# %%
# Visualize Ensemble Classifier Performance

import matplotlib.pyplot as plt
import seaborn as sns

# Update your plotting function to include ensemble classifiers
def plot_metrics_with_ensembles(dataset_name, classifiers_results, ensemble_results):
    metrics = ['accuracy', 'precision', 'recall', 'f1', 'roc_auc']
    classifier_names = list(classifiers_results.keys()) + list(ensemble_results.keys())
    metric_values = {metric: [] for metric in metrics}
    
    for clf_name in classifier_names:
        if clf_name in classifiers_results:
            results = classifiers_results[clf_name]
        else:
            results = ensemble_results[clf_name]
        for metric in metrics:
            metric_values[metric].append(results[metric])
    
    df_metrics = pd.DataFrame(metric_values, index=classifier_names)
    df_metrics = df_metrics.reset_index().rename(columns={'index': 'Classifier'})
    
    df_melted = df_metrics.melt(id_vars='Classifier', var_name='Metric', value_name='Value')
    
    plt.figure(figsize=(14, 7))
    sns.barplot(x='Classifier', y='Value', hue='Metric', data=df_melted)
    plt.title(f'Per-Patient Aggregated Performance Metrics for {dataset_name} Dataset')
    plt.xticks(rotation=45)
    plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# Plot metrics for each dataset
for dataset_name in data_splits.keys():
    classifiers_results = test_results_per_patient[dataset_name]
    ensemble_results = test_results_ensemble.get(dataset_name, {})
    plot_metrics_with_ensembles(dataset_name, classifiers_results, ensemble_results)

# %%
# SHAP Analysis

#import shap
#import matplotlib.pyplot as plt
#
## For computational efficiency, we can sample a subset of data
## Number of samples to use for SHAP analysis
#n_samples = 100
#
#for dataset_name in data_splits.keys():
#    print(f"\nPerforming SHAP Analysis for '{dataset_name}' Dataset")
#    
#    # Retrieve data splits for the current dataset
#    data = data_splits[dataset_name]
#    X_train_full = data['X_train_full']
#    y_train_full = data['y_train_full']
#    X_test_full = data['X_test_full']
#    y_test = data['y_test']
#    
#    # For SHAP analysis, we'll use a small sample of the test data
#    if len(X_test_full) > n_samples:
#        X_test_sample = X_test_full.sample(n=n_samples, random_state=42)
#    else:
#        X_test_sample = X_test_full.copy()
#    
#    for classifier_name in classifiers.keys():
#        print(f"\nClassifier: {classifier_name}")
#        
#        # Retrieve the best hyperparameters from nested_cv_results
#        nested_results = nested_cv_results[dataset_name]
#        cv_results_all = nested_results['cv_results_all']
#        cv_results = cv_results_all[classifier_name]
#        
#        # Find the hyperparameters with the best mean_test_score
#        max_mean_test_score = cv_results['mean_test_score'].max()
#        best_rows = cv_results[cv_results['mean_test_score'] == max_mean_test_score]
#        
#        # If multiple rows have the same max score, pick the first one
#        best_row = best_rows.iloc[0]
#        
#        # Extract the best hyperparameters from the pipeline parameters
#        best_params = best_row['params']
#        
#        # The params are for the entire pipeline; extract classifier's hyperparameters
#        classifier_params = {}
#        for param_name, param_value in best_params.items():
#            if param_name.startswith('classifier__'):
#                # Remove 'classifier__' prefix to get the parameter name
#                param_short = param_name.replace('classifier__', '')
#                classifier_params[param_short] = param_value
#        
#        # Get the default classifier with default parameters
#        default_classifier = classifiers[classifier_name]
#        
#        # Clone the default classifier to avoid modifying the original
#        classifier = clone(default_classifier)
#        
#        # Update the classifier's parameters with the best hyperparameters
#        classifier.set_params(**classifier_params)
#        
#        # Handle compatibility between solver and penalty for Logistic Regression
#        if classifier_name == 'Logistic Regression':
#            penalty = classifier.get_params().get('penalty', 'l2')
#            solver = classifier.get_params().get('solver', 'lbfgs')
#            if penalty == 'l1' and solver not in ['liblinear', 'saga']:
#                # Change solver to 'liblinear' if penalty is 'l1'
#                classifier.set_params(solver='liblinear')
#                print(f"Adjusted solver to 'liblinear' for 'l1' penalty.")
#            elif penalty == 'elasticnet' and solver != 'saga':
#                # 'elasticnet' penalty requires 'saga' solver
#                classifier.set_params(solver='saga')
#                print(f"Adjusted solver to 'saga' for 'elasticnet' penalty.")
#            elif penalty == 'l2' and solver == 'liblinear' and classifier.get_params().get('dual', False):
#                # Dual formulation is only implemented for l2 penalty with liblinear solver
#                classifier.set_params(dual=True)
#            else:
#                # Ensure dual is False for other solvers
#                classifier.set_params(dual=False)
#        
#        # Apply SMOTE to training data only
#        print("\nApplying SMOTE to balance the classes in the training data...")
#        smote = SMOTE(random_state=42)
#        X_train_resampled, y_train_resampled = smote.fit_resample(X_train_full, y_train_full)
#        
#        # Define the pipeline without SMOTE
#        pipeline = Pipeline(steps=[
#            ('scaler', MinMaxScaler()),
#            ('classifier', classifier)
#        ])
#        
#        # Fit the pipeline on the entire training set
#        pipeline.fit(X_train_resampled, y_train_resampled)
#        
#        # Extract the classifier from the pipeline
#        trained_classifier = pipeline.named_steps['classifier']
#        
#        # Prepare the data (after scaling)
#        X_train_scaled = pipeline.named_steps['scaler'].transform(X_train_resampled)
#        X_test_scaled = pipeline.named_steps['scaler'].transform(X_test_sample)
#        
#        # For SHAP, we need to use the model and data
#        # Use appropriate SHAP explainer based on the model
#        if classifier_name in ['Random Forest', 'XGBoost', 'LightGBM']:
#            # Use TreeExplainer
#            explainer = shap.TreeExplainer(trained_classifier)
#        elif classifier_name == 'Logistic Regression':
#            explainer = shap.LinearExplainer(trained_classifier, X_train_scaled)
#        elif classifier_name == 'SVM':
#            # For SVM, use KernelExplainer (may be slow)
#            print("KernelExplainer may be slow for SVM. Using a small sample of background data.")
#            X_train_small = X_train_scaled[:100]  # Use a small subset as background
#            def model_predict(data):
#                return trained_classifier.decision_function(data)
#            explainer = shap.KernelExplainer(model_predict, X_train_small)
#        else:
#            print(f"SHAP analysis not implemented for classifier '{classifier_name}'.")
#            continue
#        
#        # Compute SHAP values
#        print("Computing SHAP values...")
#        shap_values = explainer.shap_values(X_test_scaled)
#        
#        # For multi-class classifiers, shap_values is a list
#        if isinstance(shap_values, list):
#            # For binary classification, take the SHAP values for the positive class
#            shap_values = shap_values[1]
#        
#        # Get feature names
#        feature_names = X_test_full.columns
#        
#        # Create a summary plot
#        shap.summary_plot(shap_values, X_test_scaled, feature_names=feature_names)
